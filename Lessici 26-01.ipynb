# %%
# !pip install NRCLex
# Out:
# Collecting NRCLex
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Downloading NRCLex-4.0-py3-none-any.whl (4.4 kB)
#   Downloading NRCLex-3.0.0.tar.gz (396 kB)
#      ------------------------------------ 396.4/396.4 kB 398.5 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting textblob
#   Downloading textblob-0.17.1-py2.py3-none-any.whl (636 kB)
#      ------------------------------------ 636.8/636.8 kB 421.9 kB/s eta 0:00:00
# Requirement already satisfied: nltk>=3.1 in c:\users\crist\appdata\local\programs\python\python310\lib\site-packages (from textblob->NRCLex) (3.7)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\crist\appdata\local\programs\python\python310\lib\site-packages (from nltk>=3.1->textblob->NRCLex) (2022.9.13)
# Requirement already satisfied: click in c:\users\crist\appdata\local\programs\python\python310\lib\site-packages (from nltk>=3.1->textblob->NRCLex) (8.0.4)
# Requirement already satisfied: tqdm in c:\users\crist\appdata\local\programs\python\python310\lib\site-packages (from nltk>=3.1->textblob->NRCLex) (4.64.1)
# Requirement already satisfied: joblib in c:\users\crist\appdata\local\programs\python\python310\lib\site-packages (from nltk>=3.1->textblob->NRCLex) (1.2.0)
# Requirement already satisfied: colorama in c:\users\crist\appdata\local\programs\python\python310\lib\site-packages (from click->nltk>=3.1->textblob->NRCLex) (0.4.5)
# Building wheels for collected packages: NRCLex
#   Building wheel for NRCLex (setup.py): started
#   Building wheel for NRCLex (setup.py): finished with status 'done'
#   Created wheel for NRCLex: filename=NRCLex-3.0.0-py3-none-any.whl size=43319 sha256=5c39dcc8c491143d89b3b14e15aa3b16c0edbd30aa01e71a803b52be851adfa3
#   Stored in directory: c:\users\crist\appdata\local\pip\cache\wheels\d2\10\44\6abfb1234298806a145fd6bcaec8cbc712e88dd1cd6cb242fa
# Successfully built NRCLex
# Installing collected packages: textblob, NRCLex
# Successfully installed NRCLex-3.0.0 textblob-0.17.1

# %%
import numpy as np
import pandas as pd

# %%
from nrclex import NRCLex

# %%
text = dataset['clearedtext'].unique()

# %%
for i in range(len(text)):
    # creating objects
    emotion = NRCLex(text[i])

# %%
# Import module
from nrclex import NRCLex

# Assign list of strings
text = dataset['clearedtext'].unique()

# Iterate through list
for i in range(len(text)):

	# Create object
	emotion = NRCLex(text[i])

	# Classify emotion
	print('\n\n', text[i], ': ', emotion.top_emotions)
	print('\n\n', text[i], ': ', emotion.words)
	print('\n\n', text[i], ': ', emotion.sentences)    
	print('\n\n', text[i], ': ', emotion.affect_list)    
	print('\n\n', text[i], ': ', emotion.affect_dict)    

    
print('\n', emotion.raw_emotion_scores)
print('\n', emotion.top_emotions)
print('\n', emotion.affect_frequencies)
# Out:
#  like,fact,answer,accurately,n't,see,real,need,household,though,good,bargain,day,deal :  [('trust', 0.3125), ('positive', 0.3125)]
#
#
#  sound,terrible,want,good,music,get,bose :  [('positive', 0.15384615384615385), ('sadness', 0.15384615384615385), ('joy', 0.15384615384615385)]
#
#
#  not,much,feature :  [('positive', 1.0)]
#
#
#  stop,work,week,precede,command,really,fun,work :  [('positive', 0.5)]
#
#
#  sad,joke,worthless :  [('negative', 0.4)]
#
#
#  really,disappointed,plug-in,wall,socket,time,fault,disagree,make,assumption,company,technologically,advance,would,sell,product,rechargeable,battery,could,return,would,apple,music,boom,speaker,give,flexibility :  [('negative', 0.2)]
#
#
#  get,great,sound,bass,idle,time,still,hot,miss,recognize,thing :  [('anger', 0.5), ('anticipation', 0.5)]
#
#
#  not,super,impress,lapse,would,tightness,anything,stupid,enough,differentiate,among,spotify,account,n't,use,either,randomly,speak,nobody,talk,today,unplug,unsure,'ll,ever,use :  [('positive', 0.3333333333333333), ('negative', 0.3333333333333333)]
#
#
#  difficult,set,keep,time,enter,password :  [('fear', 0.5), ('anticipation', 0.5)]
#
#
#  hardly,come :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  item,unretentive,work,month,use,unplug,wifi,unresponsive,reset,request :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  thing,barely,work,select,party,apps,stuff,think,could,box,send,mine,back,asap,waste,money :  [('anger', 0.125), ('trust', 0.125), ('surprise', 0.125), ('positive', 0.125), ('negative', 0.125), ('disgust', 0.125), ('joy', 0.125), ('anticipation', 0.125)]
#
#
#  return,get,refund,return,one,package,want,refund,package,not,see :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  malfunction :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  fan,one,idle :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#   :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  never,respond,speak,promp,word,think,would,connect,upstairs,use,like,intercom,differ,able :  [('trust', 0.5), ('positive', 0.5)]
#
#
#  work,month,stop,'ve,try,everything,try,make,work,nothing,work,want,refund :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  poor,quality,give,away :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  never,could,get,work,techie,friend,look,say,adapter,impotent,enough,power,look,like,buy,dollar,store,replace,adapter,hope,work :  [('positive', 0.2727272727272727)]
#
#
#  initially,work,well,time,stop,respond,'alexa,unless,within,one,foot,yell,echos/echo,room,would,respond,without,response,would,not,recommend,buying,refurbish :  [('positive', 0.25)]
#
#
#  buy,refurbish,stop,whatever,function,performing,quite,often,cause_to_sleep,every,time,randomly,turn,nothing,sell,refurbished :  [('surprise', 0.3333333333333333), ('positive', 0.3333333333333333), ('anticipation', 0.3333333333333333)]
#
#
#  dont,trust,.... :  [('trust', 1.0)]
#
#
#  want,use,radio,intercom,get,terrible,reception,live,speech,recognition,software,horrible,wife,native,american,whose,language,english,north,texas,neither,accent,birth,area,yet,unmake,good,job,understand,buy,two,thing,additionally,wifi,reception,poor,marginal,buy,wifi,range,extender,office,ten,foot,router,problem,switch,around,sameness,disconnect,dust,collector :  [('positive', 0.17857142857142858), ('negative', 0.17857142857142858)]
#
#
#  item,never,work,box,break,spent,several,day,try,get,work,run,fix,thing,accomplish,never,order,another,refurbish,device :  [('positive', 0.4)]
#
#
#  great,product,return,new,refurbish,already,give,problem,connection :  [('fear', 0.25), ('positive', 0.25), ('negative', 0.25), ('sadness', 0.25)]
#
#
#  never,buy,certified,refurbished,buy,certify,refurbish,unit,poor,receive,command,sometimes,odd,acknowledge,command,never,buy,refurbished,unit,receive,probably,never,certify,refurbish,indicated,also,buy,new,work,perfectly.very,disappointed :  [('trust', 0.25), ('positive', 0.25)]
#
#
#  item,idle,certify,refurbish,mean,work,advertised,instead,item,crash,soon,turn,plug,try,connect,phone,crash,not,would,disconnect,orange,light,would,freeze,thing,would,reboot,blue,light,would,tell,ready,connect,freeze,mid,sentence,try,hold,action,button,second,anything,return,immediately,hope,actually,fix,item,next,buyer,purchase :  [('negative', 0.1724137931034483), ('sadness', 0.1724137931034483)]
#
#
#  none :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  idle,time :  [('anticipation', 1.0)]
#
#
#  've,already,return :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  weary,pick,conversation,passively,use,heard,happen,news,concern,wish,would,release,something,widespread,push,firmware,prevent,not,hear,yet :  [('positive', 0.3333333333333333)]
#
#
#  something,wrong,first,one,odd,rep,speak,could,fix,replacement,register,someone,else,price,price,refurbished,one,buy,brand,spank,new,one,problem,new,one :  [('negative', 0.375)]
#
#
#  two,week,set,unretentive,work,connection,dark,silence,guess,lack,purchase,refurbished :  [('surprise', 0.3333333333333333), ('negative', 0.3333333333333333), ('sadness', 0.3333333333333333)]
#
#
#  not,good :  [('trust', 0.2), ('surprise', 0.2), ('positive', 0.2), ('joy', 0.2), ('anticipation', 0.2)]
#
#
#  bad,purchase,make,big,fan,love,brand,unlimited,digital,music,video,even,buy,online,game,music,movie,app,try,use,make,simple,purchase,anything,useless :  [('positive', 0.26666666666666666)]
#
#
#  disconnect,speaker,time,day,sell,refurbished,product,effort :  [('positive', 0.25), ('negative', 0.25), ('sadness', 0.25), ('anticipation', 0.25)]
#
#
#  cant,seem,get,thing,sink,wireless,unsure,return,try,one,time :  [('anticipation', 0.4)]
#
#
#  product,stop,work,return,time,run :  [('anticipation', 1.0)]
#
#
#  stop,work,month,warranty,good,month,would,assume,product,sell,would,high,standard,guarantee,would,work,whole,month,mean,product,suppose,piece,junk,offer,discount,want,buy,another,one,would,want,buy,another,one :  [('positive', 0.36363636363636365)]
#
#
#  buy,son,work,return :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  bought,quit,connect,wifi,respond,voice,within,month,hard,soft,reset,unfasten,problem :  [('negative', 0.5)]
#
#
#  second,one,refurbished,model,work-at,least,not,home :  [('positive', 1.0)]
#
#
#  bad,device,know,refurbish,activate,nobody,talk,activate,start,talk,talk,yell,super,laud :  [('positive', 0.2857142857142857)]
#
#
#  far,not,impress,not,save,group,correctly,not,understand,time,unsure,excitement,alexas,voice,sound,like,water,suppose,understand,return,try,home :  [('positive', 0.3333333333333333)]
#
#
#  great,product,useless,overall,many,unnecessary,feature,unless,smart,home,obviate :  [('positive', 0.5), ('negative', 0.5)]
#
#
#  cant,figure,use :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  always,work :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  new,product,great,everything,buy,refurbish,complete,garbage,never,purchase,refurbish,total,dissatisfaction :  [('positive', 0.4), ('negative', 0.4)]
#
#
#  extremely,low,volume :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  bring,replace,one,move,lack,range,previous,non,refurbish,unit,would,seldom,able,find,wi-fi,could,unplug,get,tired,hear,message,trouble,connecting,check,app,unplug,troubleshooting,reconnected,several,time,not,strong :  [('negative', 0.5)]
#
#
#  want,listen,music,come,several,echo/dot,unit,simultaneously,must,pay,monthly,fee,think,not,apple,pay,many,could,one,room,not,enough,money :  [('positive', 0.21052631578947367), ('joy', 0.21052631578947367)]
#
#
#  work,half,time,not,respond,say,wake,name,work,fine :  [('anticipation', 1.0)]
#
#
#  want,white,white,bathroom,top,black,show,knew,not,realize,cord,plug,also,black,want,white,cord,plug :  [('trust', 0.25)]
#
#
#  set,work,hour,die,completely,not,buy,refurbished,send,back,return,day,receive :  [('fear', 0.25), ('positive', 0.25), ('negative', 0.25), ('sadness', 0.25)]
#
#
#  horrible,volume,phone,loud,device,bos,one,not,case :  [('fear', 0.2857142857142857), ('negative', 0.2857142857142857)]
#
#
#  speaker,pretty,terrible,home,good,product :  [('trust', 0.14285714285714285), ('positive', 0.14285714285714285), ('joy', 0.14285714285714285), ('anticipation', 0.14285714285714285)]
#
#
#  first,one,quit,work,shortly,get,next,one,become,unresponsive,voice,time,way,get,work,app,unsure,way :  [('anticipation', 0.6666666666666666)]
#
#
#  device,malfunction,follow,instruction,upsetting :  [('trust', 0.5), ('positive', 0.5)]
#
#
#  send,back,due,crackle,noise,turn,expect,refurbished,item :  [('trust', 0.2), ('surprise', 0.2), ('positive', 0.2), ('negative', 0.2), ('anticipation', 0.2)]
#
#
#  honestly,like,time,could,buy,small,one,exact,thing,less,half,buy,video,chat,never,really,use :  [('negative', 0.5), ('anticipation', 0.5)]
#
#
#  slow,compare :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  device,work,well,product,unfortunately,be_born,ability,play,video,limited,not,play,play,video,cropping,screen,make,look,strange,quite,selection,clock,face,control,displays,one,glaring,annoying,exception,unbend,thing,try,screen,turn,screen,scroll,defeat,purpose,screen,obviate,remind,every,second,thing,obviate,advertising,especially,cost,device,overall,expensive,device,screen,not,useful,annoy,would,not,recommend,people,get,act,together,come,screen,actually,useful :  [('negative', 0.3333333333333333)]
#
#
#  returnef,item,not,speak,spanish :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  first,receive,product,great,however,week,ago,device,serve,video,advertisement,around,night,scar,family,want,make,sure,protect,deny,video,directly,home,spot,not,device,keep,safe :  [('negative', 0.23076923076923078)]
#
#
#  couple,day,question,disconnect,see,good,reconnecting :  [('positive', 0.25)]
#
#
#  want,use,clock,bedroom,font,small,see,distance,apparently,stay :  [('negative', 0.5), ('anticipation', 0.5)]
#
#
#  meh :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  product,currently,two,relate,software,flaw,make,completely,unusable,card,homescreen,call,thing,try,service,try,turn,homescreen,card,not,one,default,homescreen,card,cycle,automatically,incredibly,annoy,set,opt,card,cycle,instead,cycle,continuously,critically,setting,idle,unit,set,cycle,card,still,continue,cycle,time,reboot,device,re-set,etc,etc.until,two,obvious,software,issue,fix,opinion,product,useless :  [('negative', 0.23529411764705882)]
#
#
#  need,harvard,law,degree,operate,thing,back,soon :  [('trust', 0.5), ('positive', 0.5)]
#
#
#  product,turn,randomly,sometimes,night :  [('surprise', 1.0)]
#
#
#  would,love,way,stop,screen,constantly,scroll,thing,try,would,make,setting,would,change,review :  [('fear', 0.25), ('trust', 0.25), ('positive', 0.25), ('joy', 0.25)]
#
#
#  n't,figure,make,receive,call,device,tell,need,register,ignore :  [('negative', 1.0)]
#
#
#  great,product,would,give,n't,scroll,face,card,lack,stupid,try,ask,suggestion,pop,yes,scroll,stay,clock,like,card,well,god,bad,irritating,get,super,cheap,face,screen,toward,wall,treat,like,instead,spot,dumb,move,amazons​,part :  [('negative', 0.26666666666666666)]
#
#
#  product,complete,waste,money,ask,question,either,ignore,answer,give,wrong,answer,find,information,wikipedia :  [('positive', 0.25), ('negative', 0.25)]
#
#
#  honestly,already,occasionally,see,lyric,song,listen,really,n't,see,difference :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  switch,helper,shopping,task,assistant :  [('positive', 0.375)]
#
#
#  not,smart,not,cancel,snooze,alarm,cancel,pre-set,alarm,weekday :  [('negative', 0.4)]
#
#
#  great,product,except,actual,way,act,clock,display,time,permanently,'clock,mode,screen,rotate,clock,face,'things,try,screen,intend,buy,several,unit,house,obviate,screen,house,permanently,try,upset,act,clock,basic,feature,spot,could,get,wrong,fail :  [('anticipation', 0.36363636363636365)]
#
#
#  want,use,bedside,clock,ability,play,music,podcasts,sadly,continuously,scroll,thing,try,depart,clock,face,get,one,back :  [('sadness', 0.3), ('anticipation', 0.3)]
#
#
#  not,happy,spot,reset,numerous,time,seem,slow,mode,practically,top,hear,even,talk,support,still,lack,theme,menu,choose :  [('positive', 0.3), ('anticipation', 0.3)]
#
#
#  fine,spot,exact,one,massive,failing,order,turn,repeat,alarm,morning,pretty,much,talk,not,thing,usually,want,first,wake,bed,partner,definitely,dislike,yes,manually,swipe,alarm,face,dismiss,swipe,rather,touch,screen,half,asleep,difficult,result,set,snooze,half,time,even,really,try,swipe,dismiss,manage,swipe,dismiss,completely,delete,recur,alarm.this,especially,annoy,could,easily,fix,simply,make,touch,screen,turn,alarm,not,delete,least,make,set,decide,whether,touch,screen,recur,alarm,snooze,turn,clock,year,still,subtract,setting,clearly,be_born,happen,may,big,product,design,screw,ever,make :  [('negative', 0.21052631578947367)]
#
#
#  item,return,repair,receivded,item,back,repair,part,miss,powerlessness,cord,included.please,advise :  [('trust', 0.5), ('positive', 0.5)]
#
#
#  awesome,spot,disappointment,little,control,screen,show,clock,look,like,order,thing,show,etc,point,n't,throw,box,away,immediately,would,send,back,get,another,full,size :  [('trust', 0.2), ('positive', 0.2), ('negative', 0.2), ('anticipation', 0.2)]
#
#
#  product,force,user,review,thing,try,way,disable :  [('fear', 0.3333333333333333), ('negative', 0.3333333333333333)]
#
#
#  use,baby,monitor,purchase,realize,read,review,skill,sync,nest,cam,consider,poor,review,fact,simple,fix,surprised,upgrade,software,allow,minute,view,alert,like,get,nest,app :  [('trust', 0.5)]
#
#
#  ignore,customer,use,device,marketing,tool,customize,screen,content,unbend,advertising,thing,try,people,suggest,turn,content,change,not,acceptable,option.moreover,increase,size,slightly,improve,audio,speaker,would,give,device.right,debate,whether,return,device,wife,say :  [('positive', 0.4117647058823529)]
#
#
#  disconnect,often :  [('negative', 0.5), ('sadness', 0.5)]
#
#
#  get,rid,thong,try,screen,numb,nut :  [('negative', 1.0)]
#
#
#  work,fine,get,indundated,thing,try,not,year,old,need,stimulus,tell,thing,find,way,turn,except,....,turn,screen,lose,suitable,fix,back :  [('fear', 0.14285714285714285), ('anger', 0.14285714285714285), ('surprise', 0.14285714285714285), ('positive', 0.14285714285714285), ('negative', 0.14285714285714285), ('sadness', 0.14285714285714285), ('disgust', 0.14285714285714285)]
#
#
#  unbend,thing,try,screen,scroll,big,promotion,device,pack,send,back,really,want,get,head,enough,already :  [('positive', 1.0)]
#
#
#  thing,wake,middle,night,say,ready,setup,already,setup,simple,thing,check,time,ask,wife,unhappy :  [('anticipation', 0.3333333333333333)]
#
#
#  product,attractive,somewhat,useful,choose,force,user,view,thing,try,trend,greatly,depreciate,value,product,sell,unless,willing,view,billboard :  [('anger', 0.2857142857142857), ('negative', 0.2857142857142857)]
#
#
#  not,good,still,positive,great,play,music,set,alarm,personally,felt,pay,much,product,nearly,half,day,literally,day,purchase,pretty,disappointed,might,still,return,get,money,back :  [('positive', 0.1724137931034483), ('joy', 0.1724137931034483)]
#
#
#  fairly,useless :  [('trust', 0.3333333333333333), ('positive', 0.3333333333333333), ('negative', 0.3333333333333333)]
#
#
#  buy,spot,love,within,month,start,act,funny,would,stop,working—called,determine,overheat,tell,unplug,technical,support,would,call,within,hour,wait,hour,without,response,reply,email,ask,wait,week,week,absolutely,response,inline,chat,per,instruction,tell,wait,long,really,unacceptable—expected,find,funny,always,thank,member,issue,arise,odd,get,assistance :  [('anticipation', 0.38461538461538464)]
#
#
#  size,screen,thing :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  invasive,scar,crap,speak,write,creapy :  [('negative', 0.2857142857142857), ('disgust', 0.2857142857142857)]
#
#
#  love,product,disappointed,realize,unretentive,play,videos,past,day,return,date,realize,expensive,alarm,clock,hop,come,back,look,buy,show,kitchen,day,glad,n't :  [('positive', 0.14285714285714285), ('negative', 0.14285714285714285), ('joy', 0.14285714285714285), ('anticipation', 0.14285714285714285)]
#
#
#  waste,money,really,get,anything,video,chat,device,would,not,cycle,picture,put,slideshow,mode,first,photo,disinherit,matter,even,look,online,research,article,lose,solution,also,problem,device,shut,lack,problem,device,price,difference,worthlessness :  [('negative', 0.22727272727272727)]
#
#
#  tube,would,lack,buy,know :  [('negative', 1.0)]
#
#
#  conserve,money,gen,gen,far,good,job,voice,recognition,show,fact,bad,virtually,useless,also,speaker,incredibly,bass,heavy,....,much,hard,understand,voice,'ve,work,adjust,bass,punch,mids,treble,still,sound,awful,finally,screen,subtract,much,n't,see,across,room,rarely,activate,meaningful,way,n't,distraction,help,use,much,practicalthan,use,show,surprised,break,little,useful,perhaps,future,waste,time,money :  [('trust', 0.13725490196078433), ('surprise', 0.13725490196078433), ('negative', 0.13725490196078433)]
#
#
#  thought,would,powerful,lot,functionality,not,much,good,not,worth,money :  [('positive', 0.2), ('anticipation', 0.2)]
#
#
#  not,understand,excitement,device,one,either,rarely,get,say,correct,unrestraint,dish,receiver,yes,set,correctly,use,app,phone,get,good,deal,definately,worthlessness,price,though,maybe,another,month,get,well,either,one,deaf,dumb,really,not,recommend,item,current,time :  [('positive', 0.21052631578947367), ('anticipation', 0.21052631578947367)]
#
#
#  disappointed,hear,respond,request :  [('anger', 0.25), ('negative', 0.25), ('sadness', 0.25), ('disgust', 0.25)]
#
#
#  show,break,anything,screen,lose,line,resolution,timer,reminder,hour,late,reminder,trigger,try,set,reminder,lack,issue,show,would,nice,could,get,act,together,actually,fix,thing :  [('negative', 0.25)]
#
#
#  pretty,dumb :  [('trust', 0.2), ('positive', 0.2), ('negative', 0.2), ('joy', 0.2), ('anticipation', 0.2)]
#
#
#  much,price,pair,speaker :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  intrusive,turn :  [('fear', 0.2), ('anger', 0.2), ('surprise', 0.2), ('negative', 0.2), ('disgust', 0.2)]
#
#
#  like,another,kid,house,constantly,repeat,myself.i,tell,something,clear,day,accord,history,hear,something,comeletely,different.the,device,really,cool,like,concept,get,two,however,idle,intended.i,find,irritate,often,not,use,device :  [('trust', 0.5), ('positive', 0.5)]
#
#
#  way,music,sound,poor,quality :  [('positive', 0.3333333333333333), ('sadness', 0.3333333333333333), ('joy', 0.3333333333333333)]
#
#
#  device,stop,communicate,properly,sonos,device,upon,connect,show,account,ask,device,play,music,sonos,baffle,system,previously,work,flawlessly,two,week,eventually,solve,problem,neither,sonos,could,figure :  [('trust', 0.36363636363636365)]
#
#
#  suck :  [('negative', 1.0)]
#
#
#  always,want,one,till,get,one,not,crack,hard,navigate,actually,like,well :  [('negative', 1.0)]
#
#
#  show,say,work,certain,apps,not,cozi,state,work,show,cozi,family,well,need,back,draw,board,would,needed,piece,technology,lack,essential,please,fix,cost,show,marvelous,get,show,take,shop,list,far,add,item,list,long,lag,not,router,slow,provider,speed,speed,not,problem,new,item,update,cozi,slow,help,need,get,updated,work,conditioning :  [('trust', 0.26666666666666666)]
#
#
#  disappoint,device,unable,access,dec,aware,purchase,problem,device,voice,stop,work,throughout,day,see,try,respond,window,open,contain,info,ask,like,device,get,process,stop,work,blue,bar,flash,keep,unplug,restart,device,start,work,irritating,device,could,really,great,device,would,act,like,grownup :  [('negative', 0.2857142857142857), ('sadness', 0.2857142857142857)]
#
#
#  return,repair,repair,problem,require,defective,part,show,itself.i,sent,repair,get,back,nonbeing,fix,site,give,option,complain,page.i,spot,work,perfectly,position :  [('negative', 0.3)]
#
#
#  great,device,feature,awesome,interaction,fantastic,home,automation,work,perfect,link,account,correctly,issue,show,send,repair,screen,glitching,less,month,old,already,issue,first,repair,send,update,firmware,get,device,back,nothing,work,update,new,firmware,work,week,later,glitch,start,love,show,get,really,frustrate,glitching :  [('trust', 0.26666666666666666)]
#
#
#  buy,product,hop,would,pretty,well,developed,far,enough,along,therefore,expect,responsive,piece,crap,doesnt,even,know,respond,question,tell,ask,button,manual,see,step,device,potential,give,big,screen,decent,sound,buck,would,never,reccomend,even,spent,feel,like,get,short,lastly,device,pretty,useless,without,membership,link,personal,account,thing,literally,decorate,bluetooth,speaker,family,account,one,get,work,minimal,even,membership,music,pas,something,extra,month,leave,item,subscription,nightmare,overpriced,decorate,bluetooth,speaker,eye,would,give,zero,could :  [('positive', 0.21428571428571427)]
#
#
#  family,buy,several,help,communicate,old,parent,grandparent,need,simple,device,full-fledged,tablet,fantastic,potential,digital,photo,screen,video,call,easy,access,music,audio,book,etc,however,setup,discover,huge,lurking,negative,force,view,continous,spam,home,screen,promote,feature,turn,many,thing,settins,unbend,thing,try,instead,beautiful,digital,photo,screen,weather,time,constantly,spam,across,home,screen,say,try,......,please,listen,customer,offer,setting,turn,spam :  [('positive', 0.3333333333333333)]
#
#
#  work,fine,realize,need,use :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  need,able,connect,party,viceo,apps :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  tech,understand,common,word,basically,glorified,radio :  [('positive', 0.6666666666666666)]
#
#
#  sound,terrible,like,tin,love,item,awful :  [('fear', 0.16666666666666666), ('anger', 0.16666666666666666), ('negative', 0.16666666666666666), ('sadness', 0.16666666666666666), ('disgust', 0.16666666666666666)]
#
#
#  device,show,seem,huge,potential,really,want,like,soon,find,quite,limited,bit,disappointing,not,end,world,use,like,use,screenless,....,little,month,screen,start,flickering,mostly,bottom,screen,inequitable,quick,look,forum,make,understand,pointless,ask,replacement,people,device,replace,start,flicker,shortly,not,provide,serious,answer,quite,time,apparently.long,story,short,move,hallway,use,expensive,bulky,voice,activate,light,switch,hue,light,like,headline,suggest,meh :  [('negative', 0.2777777777777778)]
#
#
#  know,answer,many,question,ask,example,ask,many,cup,pound,say,pound,form,money :  [('anger', 0.2727272727272727)]
#
#
#  decide,buy,smart,door,lock,decide,get,plus,control,choose,kwikset,say,compatible,buy,pose,question,somebody,community,say,work,ignore,z-wave,lock,zigbee,incompatible,body,know,lock,work,seamlessly,plus,not,guess,choice,exchange,plus,regular,buy,separate,like,wink.,return,whole,system,get,something,else.i,n't,want,buy,another,use,along,side,plus,'ll,back,ask,integrate,two,hubs.the,reason,keep,buy,smart,system,point,afraid,would,malfunction,seamlessly,unfortunately,enough,research,something,idle :  [('positive', 0.3333333333333333)]
#
#
#  habla,espanol :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  broke,leave,help,fixing,replace :  [('negative', 0.3333333333333333), ('sadness', 0.3333333333333333)]
#
#
#  still,unable,connect,device,although,say,build,buy,bridge,connect,device,think,everything,would,sync,device,still,not,discover,via,plus,look,forward,feature,able,play,music,check,weather,etc,fine :  [('positive', 0.5)]
#
#
#  terrible,stop,work,one,day :  [('fear', 0.2), ('anger', 0.2), ('negative', 0.2), ('sadness', 0.2), ('disgust', 0.2)]
#
#
#  not,speak,spanish,buy,grandmother,someone,talk,not,around,spanish :  [('positive', 1.0)]
#
#
#  get,excite,device,good,sound,control,hue,bulbs.what,n't,realize,also,meagerly,communicate,n't,use,hue,bulb,full,potential,device,turn,light,set,number,preset,color,also,not,update,bulb,new,firmare,security,concern,me.do,sell,want,full,featured,new,iot,device,end,need,update,standalone,make,inside,device,redundant,pointless.i,still,love,zero,complaint,functionality,sound,quality,device,disappointed,functionality :  [('positive', 0.25)]
#
#
#  disappointed,product,try,install,two,different,unit,neither,one,successfully,complete,hour,technician,reset,app,unplug,plus,internet,connection,try,use,application,phone,tablet,chromebook,luck,unclean,direction,application,probably,send,back,mark,not,ready,time :  [('anticipation', 0.3076923076923077)]
#
#
#  awesome,rcieved,light,buld,ignore,need,another,adapter,light,buld,work,unmindful,disappoint :  [('negative', 0.4)]
#
#
#  wish,battery,describe,well,plug,item :  [('anger', 0.5), ('negative', 0.5)]
#
#
#  hard,setup,think,reason,default,twice,thru,many,step,setup,find,device,would,nice,could,interact,xfinity,cable,cable,box,also,idle,xfinity,alarm,house,camera,nice,set,disarm,alarm,install,skill,app,setup,bulb,whats,ship,product,say,setup,bulb,find,new,bulb,setup,nest,fine,use,third,party,apps,work :  [('surprise', 0.25)]
#
#
#  part,work,fine,hue,disaster,work,month,nothing,spent,hour,phone,tech,support,one,send,repair,try,reconnect,light,pain,reset,light,bulb,take,time,get,reset,spend,hour,say,customer,service,friendly,try,helpful,smart,plug,lamp :  [('positive', 0.15789473684210525), ('negative', 0.15789473684210525)]
#
#
#  suppose,come,free,hue,lightbulb,day,light,bulb,arrive,false,advertising :  [('anticipation', 1.0)]
#
#
#  lack,week,already,unplug,network,try,reconnecting,manually,never,appear,list,device,connect,way,back :  [('negative', 0.5), ('anticipation', 0.5)]
#
#
#  'll,return,nothing,annoy,differ,turn,obviate,interfere,hue,bridge,odd,install,light,unless,unplug,plenty,review,depth,issue,bottom,line,suck,negate,z-wave,zigbee,fairness,know,advance,one,protocol,support,unmake,many,function,dedicated,one,point,notice,right,away,hue,bridge,support,firmware,upgrade,light,bulb,n't,find,rather,interest :  [('positive', 0.2), ('negative', 0.2)]
#
#
#  disconnect,direct,even,though,say,would,spend,multiple,hour,make,phone,call,text,also,miss,free,bulb :  [('negative', 0.5), ('sadness', 0.5)]
#
#
#  n't,use,apple,music,worthless,without,sound,quality,also,poor :  [('sadness', 0.2857142857142857)]
#
#
#  sure,cool,everyone,say,....,leave,try,one,even,though,large,cover,porch,.....,package,leave,top,step,day,forecast,chance,rain,.....,rain,soak,package,odd,open,see,bad,damage,order,curse,beginning,order,birthday,gift,delivery,unmake,scheduled,day,get,rain-soaked :  [('negative', 0.15384615384615385)]
#
#
#  not,tec,smart,enough,make,work,send,back,cant,get,help,eco,work,fine,complacated.i,want,big,speaker :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  product,not,light,bar,never,orange,reset,instruction,actually,differ,package,instruction,try,product,defective :  [('trust', 0.3333333333333333), ('positive', 0.3333333333333333)]
#
#
#  think,get,long,time,excite,arrive,bundle,hue,bulb,excited,end,quickly,spend,total,hour,attempt,add,bulb,plus,everything,try,end,discovery,fail,message,try,set,watch,video,read,set,website,poster,child,insanity,thing,expect,different,result,.the,next,day,onto,get,tech,support,hop,something,would,make,thing,work,also,problem,nonbeing,operator,error,well,tech,support,staff,min,phone,still,idle,product,test,patience,far,experience,shift,mindset,smart,home,kick,old,school.the,reason,give,two,send,different,plus,light,bulb,problem,n't,bulb,pack,item,purchase,another,bulb,still,could,n't,locate,device.i,pray,next,attempt,successful,revise,rating,odds,ship,defective,support,person,thought,maybe,explore,device,leave,look,look,like,defuser.i,disbelieve,lose,video,show,problem,everything,look,simple,seamless,not,experience,review,spend,enough,wasted,time,weekend,already :  [('anticipation', 0.21428571428571427)]
#
#
#  receive,wrong,product,excited,install,excitement,thank :  [('anticipation', 0.2727272727272727)]
#
#
#  need,buy,get,work,samsung,many,device,want,money,back,thing,odd,turn,unless,buy,another,point,negate,half,device,n't,buy,thing,unless,want,spend,another,another,idle,many,device,must,not,good,yet,get,device,actually,understand,talk :  [('positive', 0.25)]
#
#
#  purchase,plus,build,come,free,hue,bulb,get,everything,set,realize,plus,win,allow,full,functionality,bulb,turn,light,on/off,dim,stay,color,still,hue,bridge,full,function,feature,bulb,wish,buy,bulb,bridge,separately,use,already,since,build,essentially,useless,buy,hue,bridge,get,full,benefit,light :  [('positive', 0.875)]
#
#
#  volume,setting,half,less,speaker,sound,like,something,rattle,crackle,vibrate,understand,volume,set,high,speaker,get,distort,over-driven,silence,like,over-driven,case,sound,like,rattle/crackle,possibly,bass,high,learn,inability,adjust,sound,characteristic,volume,attempt,exchange,assume,isolated,problem :  [('negative', 0.26666666666666666), ('sadness', 0.26666666666666666)]
#
#
#  buy,realize,plug,work,convenient,make,always,connect,wall,clear,buy :  [('positive', 1.0)]
#
#
#  would,like,tell,reason,hate,like,speaker,suck,color,shape,even,way,smell,honestly,say,number,reason,hate,device,try,set,avail,device,already,set,use,quite,regularly,reset,phone,galaxy,check,app,update,cycle,power,unit,attempt,work,network/technology,industry,living,year,lack,experience,knowledge,not,problem,use,app,device,even,tell,connect,follow,app,continue,set,set,screen,continue,roll,around,screen,minute,app,lock,phone,force,app,close,restart,phone,try,figure,enough,differ,hard,techie,imagine,bad,prove,people,clue,technology,....,hope,put_option,'ll,tell,send,product,back :  [('positive', 0.2)]
#
#
#  unit,come,wrong,plug,send,back :  [('negative', 1.0)]
#
#
#  sound,quality,not,good,especially,price,pay,would,recommend,get,buy,good,speaker,instead,maybe,sonos,use :  [('trust', 0.25), ('positive', 0.25)]
#
#
#  return,piece,garbage,soon,possible,lifetime,spending,approach,nearly,sure,small,customer,rarely,disappointed,hundred,not,thousand,purchases.i,home,automation,buy,plus,specifically,built-in,along,approximately,zigbee,light,switch,voice,control,subpar,even,work,rarity,often,nothing,could,differ,disappointed,product,strongly,discourage,invest,amazon/zigbee,ecosystem,value,money,expect,working,product,need,look,elsewhere :  [('positive', 0.17857142857142858), ('negative', 0.17857142857142858)]
#
#
#  really,work,smooth,make,seem,like :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  great,good,sound,quality,functionality,smart,home,suck,automation,geo-fencing,music,sync,hue,z-wave,turn,thing,voice,end,buy,smartthing,transfer,everything :  [('positive', 0.2222222222222222), ('joy', 0.2222222222222222)]
#
#
#  get,month,ago,idea,help,control,smart,bulb,useful,answer,question,get,daily,weather,updates.it,far,useful.half,time,wake,device,ask,question,initiate,command,hear,say,turn,basically,ignore,often,unable,answer,basic,questions.it,frustrating,work,rather,make,life,easier.i,would,return,past,return,period,......,zzzz :  [('positive', 0.2857142857142857), ('negative', 0.2857142857142857), ('anticipation', 0.2857142857142857)]
#
#
#  much,difficult,use,chromecast :  [('fear', 1.0)]
#
#
#  fast,load,keep,reboot,middle,show :  [('trust', 1.0)]
#
#
#  think,darn,confuse,part,would,try,would,idle,dislike,not,think,would :  [('negative', 0.5)]
#
#
#  never,buy,anything,make,odd,year,old,nothing,restart,freeze,constantly,warranty,first,clue,horrible,device,never,buy,anything,build :  [('trust', 0.2222222222222222), ('positive', 0.2222222222222222)]
#
#
#  love,start,june,stop,work,crunchyroll,work,either,probably,switch,something,else,soon :  [('positive', 0.3333333333333333), ('joy', 0.3333333333333333), ('anticipation', 0.3333333333333333)]
#
#
#  still,work,bet,call,let,know,charge,time,ridiculous :  [('anger', 0.25), ('negative', 0.25), ('disgust', 0.25), ('anticipation', 0.25)]
#
#
#  unhappy,every,time,change,program,channel,within,program,long,delay,work,fine,quick :  [('fear', 0.16666666666666666), ('anger', 0.16666666666666666), ('negative', 0.16666666666666666), ('sadness', 0.16666666666666666), ('disgust', 0.16666666666666666), ('anticipation', 0.16666666666666666)]
#
#
#  return,idle,device,keep,come,error,app,nonbeing,able,open,time,hit,miss,time,stop,work,right,middle,show,movie,plus,slow,open,apps :  [('negative', 0.2857142857142857), ('anticipation', 0.2857142857142857)]
#
#
#  send,work,voice,remote,win,even,turn,troubleshoot,step,work,contact,send,new,one,remote/no,way,control,give,get,work,great :  [('positive', 1.0)]
#
#
#  old,keep,crash,use,sling,tv.i,buy,one,think,old,one,defective.this,one,thing,back,sling,start,leave,program :  [('surprise', 0.25), ('negative', 0.25), ('sadness', 0.25)]
#
#
#  order,deal,day,work,day :  [('trust', 0.2), ('surprise', 0.2), ('positive', 0.2), ('joy', 0.2), ('anticipation', 0.2)]
#
#
#  dislike,not,load,account,also,slow,know,not,internet,connection,xbox,one,work,fine,take,forever,load,anything :  [('anger', 0.25), ('trust', 0.25), ('negative', 0.25), ('disgust', 0.25)]
#
#
#  constantly,buffering,point,n't,watch,anything,without,interruption,purchase,day,plus,use,reward,pay,end,pay,next,nothing,pay,full,price,might,want,money,back,stop,try,use,back,old,streaming,device,know,internet,service,not,issue,lack,problem,device,stream :  [('trust', 0.1935483870967742), ('positive', 0.1935483870967742), ('anticipation', 0.1935483870967742)]
#
#
#  like,sleep,mode,minute,inactivity,wake,finish,watch,show :  [('fear', 0.25), ('trust', 0.25), ('negative', 0.25), ('anticipation', 0.25)]
#
#
#  like,day,year,unretentive,work,would,powerlessness,past,logo,buy,second,one,sell,third,one,first,longer,.... :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  show,nothing :  [('trust', 1.0)]
#
#
#  disappointed,mandatory,upgrade,final,get,upload,lose,local,charlotte,channel,pur,news,weather,also,cbs,nbc,abc,day,later,day,discount,order :  [('anger', 0.2), ('negative', 0.2), ('sadness', 0.2), ('disgust', 0.2)]
#
#
#  garbage,even,try,watch,video,piece,garbage,loos,internet,connection,half,way,thru,show,cheap,work,time,well,conserve,time,money,piece,garbage :  [('negative', 0.21052631578947367), ('anticipation', 0.21052631578947367)]
#
#
#  would,not,recommend,anyone,n't,load,rare,occasion,idle,program,way,thru,tell,unable,process,title,time,try,later,not,site,cause,stream,fine,computer,disappointing :  [('trust', 0.2222222222222222), ('positive', 0.2222222222222222), ('negative', 0.2222222222222222), ('sadness', 0.2222222222222222)]
#
#
#  películas,tiene,pueden,cambiar,español,títulos,español :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  excite,try,new,element,unfortunately,even,though,foot,away,router,get,madden,disconnection,buffer,think,little,device,suppose,take,care,issue :  [('fear', 0.2), ('anger', 0.2), ('negative', 0.2)]
#
#
#  menu,work,say,connect,network :  [('anticipation', 1.0)]
#
#
#  would,love,remote,wasnt,spend,much,money,replace,battery,upsetting,spend,money,great,device,battery,not,last :  [('anger', 0.2222222222222222)]
#
#
#  purchase,use,road,semi,idle,application :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  seem,work,really,disbelieve,would,ban,app,many,people,want,use,really,want,like,could,n't,install,particular,app,become,almost,useless,almost,stuff,fine,'ll :  [('negative', 0.75)]
#
#
#  quite,disappointed,product.there,clearly,bug,half,time,ask,newsflash,two,second,start,whole,thing,stop,reboots,couple,minute,ask,play,radio,also,many,time,get,confused,ask,switch,light,item,also,name,false,clearly,natural,language,'beta,stage,still,not,impressed :  [('anticipation', 0.2727272727272727)]
#
#
#  nope,still,lot,improve,thing,ask,say,hmmmm,dont,know :  [('trust', 0.25), ('positive', 0.25), ('joy', 0.25), ('anticipation', 0.25)]
#
#
#  reach,device,want,sync,phone,number,would,deny,say,number,already,use,customer,service,could,n't,help,basically,tell,contact,sprint,assist,bare,minimum,without,access,phone,set,kind,pointless,pay :  [('positive', 0.3125)]
#
#
#  dislike,almost,everytime,ask,question,would,say,dont,know,havent,learn :  [('positive', 0.4)]
#
#
#  volume,low :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  cheap,cheap,sound :  [('negative', 1.0)]
#
#
#  price,product,nice,quality,nice,feature,definitely,complaint,reason,give,not,think,may,buyer,error,first,know,product,plug,time,work,really,like,not,stand,alone,device,also,speaker,not,loud,buy,bluetooth,speaker,lastly,sure,lot,quite,figure,use,fully,kind,seem,like,unnecessary,device,plus,set,awful,would,definitely,save,money,buy,nicer,one,actually :  [('positive', 0.23076923076923078)]
#
#
#  use,twice,malfunction :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  device,not,interact,home,fill,apple,device,disappointing :  [('trust', 0.3333333333333333), ('negative', 0.3333333333333333), ('sadness', 0.3333333333333333)]
#
#
#  not,happy,speaker,great,reason,lot,time,play,music,start,make,weird,noise,stop,son,home,much,good :  [('positive', 0.2222222222222222), ('anticipation', 0.2222222222222222)]
#
#
#  think,really,much,play,music,answer,stupid,question,finally,able,hook,thermostat,see,price,drop,like,rock :  [('positive', 0.3333333333333333)]
#
#
#  work,well,month,stop,connect,internet,wifi,none,trouble,shoot,effort,work,customer,service,could,n't,help,far,tell,warranty,month,disappointing,disinherit,replace :  [('positive', 0.3333333333333333)]
#
#
#  ask,play,motown,radio,pandora,keep,ask,want,add,salsa,station,motown,close,salsa,phonetically :  [('positive', 1.0)]
#
#
#  sound,terrible,not,pair,play,simultaneously,must,upgrade,music,want,play,one,device,time :  [('sadness', 0.2222222222222222)]
#
#
#  real,difficulty,work,alexi,not,smart,question,ask,get,unsure,half,time,still,ask,question,alexi,say,unsure,music,great,work,well,far,frustrating,experience :  [('positive', 0.3333333333333333)]
#
#
#  really,happy,original,thought,get,use,bedroom,really,disappointed,audio,quality,connect,external,speaker,via,bluetooth,audio,much,good,start,problem,loose,connection,wifi,presumably,due,interference,bluetooth,connect,speaker,via,auxiliary,jack,auxiliary,jack,pick,interference,wifi,wake,middle,night,horrible,buzzing,sound,hop,take,thing,back,give,good,deal,spot,hope,good,nightstand,device :  [('anticipation', 0.17777777777777778)]
#
#
#  weak,sound,compare,home,mini,sound,bad,also,need,small,selection,music,need,music,play,everything,also,get,two,need,family,music,play,music,think,lame,need,family,plan,use,multiple,device :  [('sadness', 0.2631578947368421)]
#
#
#  responds,odd,talk,'ve,unplug,feel,like,spy :  [('positive', 1.0)]
#
#
#  not,connect,phone,playlist :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  negative,product,terrible,sound,quality,massive,difference,big,reason,want,purchase,this.won,buy,another,speaker,sound,quality,improve :  [('positive', 0.16666666666666666), ('negative', 0.16666666666666666), ('sadness', 0.16666666666666666)]
#
#
#  order :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  product,sound,emoji,speaker,five,sister,even,one,bluetooth,need,plug,good,thing,speak :  [('trust', 0.2), ('surprise', 0.2), ('positive', 0.2), ('joy', 0.2), ('anticipation', 0.2)]
#
#
#  love :  [('positive', 0.5), ('joy', 0.5)]
#
#
#  sometimes,play,game,answer,question,correctly,say,get,wrong,answer,like,able,turn,light,away,home :  [('positive', 0.5), ('negative', 0.5)]
#
#
#  lot,fun,thing,old,learns,dinosaur,control,light,play,game,like,category,nice,sound,play,music,well :  [('positive', 0.2857142857142857), ('joy', 0.2857142857142857)]
#
#
#  music :  [('positive', 0.3333333333333333), ('sadness', 0.3333333333333333), ('joy', 0.3333333333333333)]
#
#
#  receive,gift,need,another,bluetooth,something,play,music,easily,accessible,find,smart,speaker,wait,see,else :  [('positive', 0.3)]
#
#
#  think,one,'ve,purchase,work,get,one,every,room,house,really,like,feature,offer,specifily,play,music,control,light,throughout,house :  [('positive', 0.6)]
#
#
#  look,great :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  love,listen,song,heard,since,childhood,get,news,weather,information,great :  [('positive', 0.6)]
#
#
#  send,year,old,dad,talk,constantly :  [('trust', 0.5), ('positive', 0.5)]
#
#
#  love,learn,know,thing,eveyday,still,figure,everything,work,far,easy,use,understand,make,laugh,time :  [('positive', 0.42857142857142855)]
#
#
#  purchase,mother,knee,problem,give,something,try,come,leave,around,fast,like,did.she,enjoy,little,big,thing,play,song,time,cook :  [('negative', 0.17647058823529413), ('sadness', 0.17647058823529413), ('anticipation', 0.17647058823529413)]
#
#
#  love,love,love :  [('positive', 0.5), ('joy', 0.5)]
#
#
#  expect,.... :  [('trust', 0.25), ('surprise', 0.25), ('positive', 0.25), ('anticipation', 0.25)]
#
#
#  love,wife,hate :  [('fear', 0.14285714285714285), ('anger', 0.14285714285714285), ('positive', 0.14285714285714285), ('negative', 0.14285714285714285), ('sadness', 0.14285714285714285), ('disgust', 0.14285714285714285), ('joy', 0.14285714285714285)]
#
#
#  really,happy,purchase,great,speaker,easy,set :  [('trust', 0.25), ('positive', 0.25), ('joy', 0.25), ('anticipation', 0.25)]
#
#
#  use,couple,day,lot,fun,new,toy,like,new,household,member,try,learn,different,featues,benefit,come :  [('positive', 0.6666666666666666)]
#
#
#  love,size,still,need,little,improvement,sound :  [('positive', 0.4), ('joy', 0.4)]
#
#
#  like,original,short,great,fabric/color,choice,miss,volume,ring,top,plus/minus,button,not,big,deal,ring,comforting,well,like,use,standard,usb,charger,/port,instead,previous,round,pin,guess,sound,seem,work,still,answer,alexa/echo/computer,not,like :  [('positive', 0.36363636363636365)]
#
#
#  love,good,music,sound,play,understand,command,difficult,time,find,specific,playlist,song,spotify,good,music,lack,major,program :  [('positive', 0.2727272727272727)]
#
#
#  love,use,play,music,play,radio,itunes,play,podcasts,anypod,set,reminder,listen,flash,briefing,news,weather,every,morning,rely,custom,list,like,able,voice,control,volume,'re,sure,'ll,continue,find,new,uses.sometimes,bit,frustrate,n't,understand,'re,say :  [('positive', 0.3076923076923077)]
#
#
#  set,day,still,add,smart,home,device,speaker,great,play,music,like,size,station,kitchen,counter,unintrusive,look :  [('positive', 0.3333333333333333), ('sadness', 0.3333333333333333), ('joy', 0.3333333333333333)]
#
#
#  love,play,sleep,sound,immediately,ask :  [('positive', 0.4)]
#
#
#  amazing,product :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  love,easy,operate,load,fun.it,everything,advertised,use,mainly,play,favorite,tune,test,knowledge :  [('positive', 0.5)]
#
#
#  sound,great,love :  [('positive', 0.5), ('joy', 0.5)]
#
#
#  fun,item,play,get,use,use,sometimes,hard,time,answer,question,ask,think,good :  [('positive', 0.3), ('anticipation', 0.3)]
#
#
#  like,one :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  still,learn,capability,far,pretty,pretty,pretty,good :  [('positive', 0.2777777777777778)]
#
#
#  like :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  work,well,need,learning,command,unique,owner,user,like,learn,tasha,birthday,learn,definition,fine,etc,great :  [('positive', 0.5555555555555556)]
#
#
#  device,awesome :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  buy,compare,speaker,quality,first,speaker,like,sound,well,ship,daughter,though,like,fact,first,chargeable,base,buy,keep,mobile,need,good,sound :  [('trust', 0.21428571428571427), ('anticipation', 0.21428571428571427)]
#
#
#  love,still,learn,thing,able,follow,instruction,include,package,find,great,one,u-tube :  [('positive', 0.6666666666666666)]
#
#
#  speaker,good :  [('trust', 0.2), ('surprise', 0.2), ('positive', 0.2), ('joy', 0.2), ('anticipation', 0.2)]
#
#
#  thing,way,cool,get,one,want,cool :  [('positive', 1.0)]
#
#
#  first,digital,assistant,give,good,review,speaker,really,good,cheap,price,day,fun,play,use,alarm,clock,get,first,place,end,lack,one,definitely,try,like,best,number,device,connect,purchase,come,smart,plug,connect,lamp,turn,light :  [('anticipation', 0.21052631578947367)]
#
#
#  husband,like,able,use,listen,music,wish,know,capability :  [('positive', 0.3333333333333333), ('sadness', 0.3333333333333333), ('joy', 0.3333333333333333)]
#
#
#  android,would,deny,connect,fortunately,sister,apple,cell,hour+,tech,support,fix,glitch,run :  [('anger', 0.5), ('negative', 0.5)]
#
#
# ...
#
#
#  always,easy,set :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  intelligent,love,song,.... :  [('positive', 0.5)]
#
#
#  review :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  love,price,pay,day,comparable,buy,new,digital,clock,bell,whistle,much,play,music,set,alarm,call,friend,play,game,set,timer,list,definitely,worth,money :  [('positive', 0.2608695652173913)]
#
#
#  easy,installation,set,good,sound,smart,speaker,satisified,purchase :  [('trust', 0.2), ('surprise', 0.2), ('positive', 0.2), ('joy', 0.2), ('anticipation', 0.2)]
#
#
#  spoil,one,downstairs,get,one,upstairs,listen,music,etc,walk,treadmill :  [('positive', 0.16666666666666666), ('negative', 0.16666666666666666), ('sadness', 0.16666666666666666), ('disgust', 0.16666666666666666), ('joy', 0.16666666666666666), ('anticipation', 0.16666666666666666)]
#
#
#  handy,hell,recommend :  [('positive', 0.25)]
#
#
#  still,discovery,phase,far,enjoy,smart,home,feature,instal :  [('positive', 0.5)]
#
#
#  totally,get,sense,humour :  [('positive', 1.0)]
#
#
#  put,one,bedroom,play,music,tell,weather,also,alarm,wake,morning,well,clock,radio,play,type,music,want,radio,station,favorite,even,tell,joke,ignore,get,along,without,amazing :  [('positive', 0.29411764705882354)]
#
#
#  love,get,boyfriend,birthday,kid,blast,ask,kind,question,tell,silly,joke,love :  [('positive', 0.2631578947368421), ('joy', 0.2631578947368421)]
#
#
#  good,sound :  [('trust', 0.2), ('surprise', 0.2), ('positive', 0.2), ('joy', 0.2), ('anticipation', 0.2)]
#
#
#  listens,well,way,expect,love :  [('positive', 0.3333333333333333)]
#
#
#  still,test,one,far,like,hesitant,put,voice,activate,device,home,would,first,unfortunately,sometimes,get,wifi,light,bulb,mix,unbend,'ve,able,manage,fix,mean,convenient,especially,unable,reach,turn,light,electronics,could,hook,like,play,music,reminder,alarm,etc,still,get,use,fact,man,always,listen :  [('positive', 0.25)]
#
#
#  work,great.having,fun,play,music,check,weather,king,question :  [('positive', 0.5)]
#
#
#  small,convenient,dependable,cutie,job,ask.my,issue,fidelity,expect,small,speaker :  [('positive', 0.36363636363636365)]
#
#
#  perfect,people,like,live,alone,least,someone,talk,keep,sanity,though,wish,powerful,speaker,obviate,connect,bluetooth,speaker :  [('positive', 0.25)]
#
#
#  small,footprint,nice,clarity :  [('negative', 1.0)]
#
#
#  great,addition,base,use,guest,bedroom,music,clock,info.dot,speaker,not,strong,base,great,value :  [('trust', 0.3333333333333333)]
#
#
#  build,thermostat,idle,well,stand,right,next,hear,music,play,choppy,decide,try,since,day,differ,disappointed,hear,fine,music,play,problem,really,like,bluetooth,connect,bose,speaker,quality,sound :  [('sadness', 0.2857142857142857)]
#
#
#  connect,whole,home,sound,system,play,music,home,mini,unmake,work,well :  [('trust', 0.25), ('positive', 0.25), ('sadness', 0.25), ('joy', 0.25)]
#
#
#  much,fun,play,ask,set,alarm,wake,morning,tell,turn,learn,question,ask,play,music,ask,play,music,domain,wake,middle,night,lack,turn,light,ask,time,want,current,weather,tell,ask,city,know,call,friend,dial,misuse,one,yet,say,could,contact :  [('positive', 0.3333333333333333)]
#
#
#  easy,set,everything,poster,despite,small,size,speaker,adequate,understands,instruction,across,room,happy,purchase :  [('trust', 0.2857142857142857), ('positive', 0.2857142857142857)]
#
#
#  great,product,price,work,well :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  perfect,home,office :  [('trust', 0.25), ('positive', 0.25), ('joy', 0.25), ('anticipation', 0.25)]
#
#
#  suppose,great,product :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  love,item,able,hear,kind,music,enjoy,much,order,another :  [('positive', 0.3333333333333333), ('joy', 0.3333333333333333)]
#
#
#  great,item,glad,make,purchase,day :  [('positive', 0.3333333333333333), ('joy', 0.3333333333333333), ('anticipation', 0.3333333333333333)]
#
#
#  still,learn,use,figure,read,kindle,book,real,bonus :  [('positive', 0.42857142857142855)]
#
#
#  love,one,bedroom,kitchen,great,drop,family,around,house :  [('positive', 0.5), ('joy', 0.5)]
#
#
#  far,good,not,tech,savvy,still,try,figure,easy,set,far,easy,use,lot,apps,use,play,fun :  [('positive', 0.3333333333333333)]
#
#
#  put,awhile,finally,get,around,buying,home,wife,legally,blind,not,use,computer,godsend,music,listen,music,check,weather,get,phone,number,make,call,etc.,etc,still,learn,tell,absolutely,amazing,purchase,extended,family,grandchild,absolutely,love,play,music,wifi,direct,cable,capability,speaker/stereo,option,choosing,well,worth,money,n't,regret :  [('positive', 0.30303030303030304)]
#
#
#  perfect,fast,shipment,packaging,work,intend :  [('trust', 0.4)]
#
#
#  addict,thing :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  love,hop,add,couple,around,apartment,reason,starve,wish,speaker,would,little,good,know,probably,want,keep,cost,item,really,like,play,music,around,apartment,busy,thing,would,add,speaker,little,wattage,bass,response,would,something,great,put,bathroom,kitchen,might,differ,lot,space,full,size,would,willing,pay,dollar,good,speaker,well,still,love,find,bluetooth,speaker,sound,good,disclaim,whole,lot,space :  [('positive', 0.28125)]
#
#
#  far,all.i,say,love :  [('positive', 0.5), ('joy', 0.5)]
#
#
#  love,easy,use,two,plus,spot,one,favorite,feature,ability,listen,music,iheart,radio,pandora :  [('positive', 0.5454545454545454)]
#
#
#  great,play,music,throughout,house,great,easily,fit,decor,home :  [('positive', 0.3333333333333333), ('sadness', 0.3333333333333333), ('joy', 0.3333333333333333)]
#
#
#  obsess,tell,weather,every,morning,play,game,love,guess,song,one,one,upstairs,turn,downstairs,cool,walk,stair :  [('positive', 0.5)]
#
#
#  easy,setup,easy,use,work,smart,product,always,learn :  [('positive', 1.0)]
#
#
#  much,fun,easy,use,even,four,year,old,love,talk :  [('positive', 0.5)]
#
#
#  love,new,right,mainly,use,play,music,night,get,job :  [('positive', 0.5)]
#
#
#  love,thing,wish,would,get,sooner,certainly,want,setting,lock,kid,great,additional,even,unexpected,thing,like,help,kid,homework,load,skill,happy,purchase,especially,since,get,day,almost,half,price :  [('positive', 0.23076923076923078), ('joy', 0.23076923076923078)]
#
#
#  super,easy,hook,program,use,music,feature,love,set,reminder,phone,remind,set,time,great,news,update :  [('positive', 0.42857142857142855)]
#
#
#  work,like :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  set,simple,recognize,voice,well,seam,intuitive,enjoy,ease,use :  [('positive', 0.5)]
#
#
#  like,ability,multiple,different,thing,like,create,list,set,alarm,play,song,think,much,wish,sound,could,tad,louder :  [('positive', 0.3333333333333333)]
#
#
#  soon,still,learn :  [('positive', 1.0)]
#
#
#  enjoy,still,learn,command,run,one,frustrating,issue,not,user,friendly,try,set,voice,recognition,household :  [('positive', 0.4)]
#
#
#  love,option,play,music,everywhere,house,multiple,device :  [('positive', 0.5)]
#
#
#  like,almost,everything :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  amaze,help,become,well,organize,give,traffic,update,weather,update,help,maintain,good,fast,morning,routine :  [('positive', 0.3333333333333333)]
#
#
#  kid,love,skill,amazing,would,like,see,get,little,smarter,answer,basic,question :  [('positive', 0.6666666666666666)]
#
#
#  great,definitely,get,little,old,n't,really,regret,love,hook,speaker,via,bluetooth,wake,smith :  [('trust', 0.2), ('positive', 0.2), ('negative', 0.2), ('sadness', 0.2), ('joy', 0.2)]
#
#
#  love,add,upstairs,bedroom :  [('positive', 0.5), ('joy', 0.5)]
#
#
#  get,love,everything,around,house :  [('positive', 0.5), ('joy', 0.5)]
#
#
#  device,easy,set,work,perfectly :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  easy,set,start,use,work,advertised :  [('anticipation', 1.0)]
#
#
#  love,little,know,original,large,unmake,pleased,capability :  [('positive', 0.5), ('joy', 0.5)]
#
#
#  work,expect,one,son,love,room,easy,set,alarm,play,music :  [('positive', 0.25)]
#
#
#  dislike,volume,silence,loud,enough :  [('anger', 0.3333333333333333), ('negative', 0.3333333333333333), ('disgust', 0.3333333333333333)]
#
#
#  love,give,one,gift,huge,hit :  [('positive', 0.25), ('joy', 0.25)]
#
#
#  expect :  [('trust', 0.25), ('surprise', 0.25), ('positive', 0.25), ('anticipation', 0.25)]
#
#
#  love,technology,old,easy,set,use,bedroom,use,everything,use,living,room :  [('positive', 0.6666666666666666)]
#
#
#  use,buy,husband,would,able,contact,someone,fall,lack,access,phone :  [('negative', 0.5)]
#
#
#  amazing,product,still,learnimg,thing :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  friend :  [('trust', 0.3333333333333333), ('positive', 0.3333333333333333), ('joy', 0.3333333333333333)]
#
#
#  easy,thing :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  good,device :  [('trust', 0.2), ('surprise', 0.2), ('positive', 0.2), ('joy', 0.2), ('anticipation', 0.2)]
#
#
#  overall,love,command,ineffective,may,part,user,error,become,accustom,ask :  [('negative', 0.4)]
#
#
#  additional,base,device,make,access,well,part,home,rather,try,shout,question,instruction,house,lol,would,differ,without,variety,function,perform :  [('trust', 0.3333333333333333), ('positive', 0.3333333333333333)]
#
#
#  work,great,love,fact,play,music,group,device :  [('positive', 0.3333333333333333), ('joy', 0.3333333333333333)]
#
#
#  love,think,would,addicted :  [('positive', 0.5), ('joy', 0.5)]
#
#
#  work,beautifully,excellent,sound :  [('trust', 0.3333333333333333), ('positive', 0.3333333333333333), ('joy', 0.3333333333333333)]
#
#
#  still,learn,everything,good,room,volume,pretty,good,without,additional,speaker :  [('positive', 0.26666666666666666)]
#
#
#  neat,tool,enjoy,family :  [('trust', 0.25), ('positive', 0.25), ('joy', 0.25), ('anticipation', 0.25)]
#
#
#  easy,connect,skill,create,gen,work,fine :  [('positive', 0.5), ('joy', 0.5)]
#
#
#  live,alone,best,companion :  [('trust', 0.3333333333333333), ('positive', 0.3333333333333333), ('joy', 0.3333333333333333)]
#
#
#  easy,set,connect,smart,device,need :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  love,personally,prefer,spotify,music,great,able,set,default,not,day,without,music,home,also,reason,get,keep,pup,calm,leave,tell,play,classical,music,jazz,work,wonder,lot,calmer,bark,lock,door,start,walk,away,must :  [('positive', 0.3076923076923077)]
#
#
#  love,work,great,still,problem,get,well,every,day,not,expert,think,sound,quality,fine,not,perfect,good :  [('positive', 0.25)]
#
#
#  second,purchase,price,cheap,seriously,thinking,buy,use,everything,next,best,thing,internet :  [('negative', 1.0)]
#
#
#  love,buy,one,daughter,one :  [('positive', 0.5), ('joy', 0.5)]
#
#
#  not,loud,think :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  enjoy,still,discover,new :  [('trust', 0.25), ('positive', 0.25), ('joy', 0.25), ('anticipation', 0.25)]
#
#
#  able,add,speaker,plus,take,deck,outside,love,big,bedroom :  [('positive', 0.5), ('joy', 0.5)]
#
#
#  excellent,device,work,great,problem,concern :  [('fear', 0.16666666666666666), ('trust', 0.16666666666666666), ('positive', 0.16666666666666666), ('negative', 0.16666666666666666), ('sadness', 0.16666666666666666), ('joy', 0.16666666666666666)]
#
#
#  pretty,fun,nice,speaker,respond,question,n't,understand,command,time :  [('positive', 0.3333333333333333), ('anticipation', 0.3333333333333333)]
#
#
#  like,hand,free,operation,tap,use,control,smart,plug :  [('fear', 0.5), ('trust', 0.5)]
#
#
#  love,actually,throughout,house,favorite,function,list,great,time,management,course,music :  [('positive', 0.36363636363636365)]
#
#
#  product,easy,use,entertaining,yet,hook,light,look,forward :  [('positive', 0.5)]
#
#
#  work,great,speaker,not,good,music,need,get,bluetooth,speaker :  [('positive', 0.25), ('joy', 0.25)]
#
#
#  outstanding,product,easy,use,work,great :  [('positive', 0.3333333333333333), ('negative', 0.3333333333333333), ('joy', 0.3333333333333333)]
#
#
#  six,throughout,home,great,time,music,talk,happens,randomly,may,sensitive,listening,option,change,name,engagement,command,computer,little,annoying,color,black,white,would,also,good,thing :  [('positive', 0.23809523809523808)]
#
#
#  use,product,music,great :  [('positive', 0.3333333333333333), ('sadness', 0.3333333333333333), ('joy', 0.3333333333333333)]
#
#
#  easy,set-up,use :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  like,device,house,sale,price,day,tempting :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  love,exactly,say :  [('positive', 0.5), ('joy', 0.5)]
#
#
#  use,control,smart,home,device,work,great :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  convenient :  [('positive', 1.0)]
#
#
#  este,producto,llegó,semana,quedó,sin,olor,perdió,toda,escencia,huele,solo,alcohol :  [('fear', 0.2), ('anger', 0.2), ('negative', 0.2), ('sadness', 0.2), ('disgust', 0.2)]
#
#
#  easy,set,ready,use,minute :  [('anticipation', 1.0)]
#
#
#  barry :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  three,year,old,love,good,basic,household,task,'re,add,smart,outlet,bulb :  [('positive', 0.4444444444444444)]
#
#
#  awesome,device,wish,buy,one,age,ago :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  perfect,kid,adult,everyone :  [('trust', 0.25), ('positive', 0.25), ('joy', 0.25), ('anticipation', 0.25)]
#
#
#  listen,music,search,location,check,time,look,weather,many,task,learn,simple,set :  [('positive', 0.5)]
#
#
#  love,thing,run,entire,home,light,thermostat,front,door,dead,bolt,camera,love,listen,npr,thing,well,worth,value,really,shine,stat,add,smart,device,control,entire,home,like,right,trek,....,name,mine,computer,get,feel,amazing,device,smart,system :  [('positive', 0.5714285714285714)]
#
#
#  complaint,sound,quality,n't,great,mostly,use,command,though,another,hook,stereo,system,play,music,couple,friends,forget,audio,quality,'re,bother,kind,thing,full,size,make,sure,hook,large,speaker :  [('positive', 0.25), ('negative', 0.25)]
#
#
#  nice,little,unit,recall :  [('fear', 0.0), ('anger', 0.0), ('anticip', 0.0), ('trust', 0.0), ('surprise', 0.0), ('positive', 0.0), ('negative', 0.0), ('sadness', 0.0), ('disgust', 0.0), ('joy', 0.0)]
#
#
#  easy,set,use,help,provide,music,etc,small,space,look :  [('positive', 0.3333333333333333)]

# %%
# Import module
from nrclex import NRCLex

# Assign list of strings
text = dataset['clearedtext'].unique()

# Iterate through list
for i in range(len(text)):

	# Create object
	emotion = NRCLex(text[i])
dataset['emotion'] = ('\n\n', text[i], ': ', emotion.top_emotions)
	# Classify emotion
	#print('\n\n', text[i], ': ', emotion.top_emotions)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1000\101130849.py in <module>
#      10         # Create object
#      11         emotion = NRCLex(text[i])
# ---> 12 dataset['emotion'] = ('\n\n', text[i], ': ', emotion.top_emotions)
#      13         # Classify emotion
#      14         #print('\n\n', text[i], ': ', emotion.top_emotions)
#
# D:\Nuova cartella (2)\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3653         else:
#    3654             # set column
# -> 3655             self._set_item(key, value)
#    3656
#    3657     def _setitem_slice(self, key: slice, value):
#
# D:\Nuova cartella (2)\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3830         ensure homogeneity.
#    3831         """
# -> 3832         value = self._sanitize_column(value)
#    3833
#    3834         if (
#
# D:\Nuova cartella (2)\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, value)
#    4536
#    4537         if is_list_like(value):
# -> 4538             com.require_length_match(value, self.index)
#    4539         return sanitize_array(value, self.index, copy=True, allow_2d=True)
#    4540
#
# D:\Nuova cartella (2)\lib\site-packages\pandas\core\common.py in require_length_match(data, index)
#     555     """
#     556     if len(data) != len(index):
# --> 557         raise ValueError(
#     558             "Length of values "
#     559             f"({len(data)}) "
#
# ValueError: Length of values (4) does not match length of index (2453)

# %%
# Import module
from nrclex import NRCLex

# Assign list of strings
text = dataset['clearedtext'].unique()

# Iterate through list
for i in range(len(text)):

	# Create object
	emotion = NRCLex(text[i])

	# Classify emotion

	print('\n\n' text[i], ': ', emotion.affect_frequencies)
# Out:
#  like,fact,answer,accurately,n't,see,real,need,household,though,good,bargain,day,deal :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.3125, 'surprise': 0.125, 'positive': 0.3125, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.125, 'anticipation': 0.125}
#
#
#  sound,terrible,want,good,music,get,bose :  {'fear': 0.07692307692307693, 'anger': 0.07692307692307693, 'anticip': 0.0, 'trust': 0.07692307692307693, 'surprise': 0.07692307692307693, 'positive': 0.15384615384615385, 'negative': 0.07692307692307693, 'sadness': 0.15384615384615385, 'disgust': 0.07692307692307693, 'joy': 0.15384615384615385, 'anticipation': 0.07692307692307693}
#
#
#  not,much,feature :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 1.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  stop,work,week,precede,command,really,fun,work :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.5, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.25, 'anticipation': 0.25}
#
#
#  sad,joke,worthless :  {'fear': 0.0, 'anger': 0.2, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.4, 'sadness': 0.2, 'disgust': 0.2, 'joy': 0.0}
#
#
#  really,disappointed,plug-in,wall,socket,time,fault,disagree,make,assumption,company,technologically,advance,would,sell,product,rechargeable,battery,could,return,would,apple,music,boom,speaker,give,flexibility :  {'fear': 0.05, 'anger': 0.15, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.05, 'positive': 0.15, 'negative': 0.2, 'sadness': 0.15, 'disgust': 0.05, 'joy': 0.1, 'anticipation': 0.1}
#
#
#  get,great,sound,bass,idle,time,still,hot,miss,recognize,thing :  {'fear': 0.0, 'anger': 0.5, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0, 'anticipation': 0.5}
#
#
#  not,super,impress,lapse,would,tightness,anything,stupid,enough,differentiate,among,spotify,account,n't,use,either,randomly,speak,nobody,talk,today,unplug,unsure,'ll,ever,use :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.16666666666666666, 'surprise': 0.16666666666666666, 'positive': 0.3333333333333333, 'negative': 0.3333333333333333, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  difficult,set,keep,time,enter,password :  {'fear': 0.5, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0, 'anticipation': 0.5}
#
#
#  hardly,come :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  item,unretentive,work,month,use,unplug,wifi,unresponsive,reset,request :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  thing,barely,work,select,party,apps,stuff,think,could,box,send,mine,back,asap,waste,money :  {'fear': 0.0, 'anger': 0.125, 'anticip': 0.0, 'trust': 0.125, 'surprise': 0.125, 'positive': 0.125, 'negative': 0.125, 'sadness': 0.0, 'disgust': 0.125, 'joy': 0.125, 'anticipation': 0.125}
#
#
#  return,get,refund,return,one,package,want,refund,package,not,see :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  malfunction :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  fan,one,idle :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#   :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  never,respond,speak,promp,word,think,would,connect,upstairs,use,like,intercom,differ,able :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.5, 'surprise': 0.0, 'positive': 0.5, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  work,month,stop,'ve,try,everything,try,make,work,nothing,work,want,refund :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  poor,quality,give,away :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  never,could,get,work,techie,friend,look,say,adapter,impotent,enough,power,look,like,buy,dollar,store,replace,adapter,hope,work :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.18181818181818182, 'surprise': 0.09090909090909091, 'positive': 0.2727272727272727, 'negative': 0.09090909090909091, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.18181818181818182, 'anticipation': 0.18181818181818182}
#
#
#  initially,work,well,time,stop,respond,'alexa,unless,within,one,foot,yell,echos/echo,room,would,respond,without,response,would,not,recommend,buying,refurbish :  {'fear': 0.125, 'anger': 0.125, 'anticip': 0.0, 'trust': 0.125, 'surprise': 0.125, 'positive': 0.25, 'negative': 0.125, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0, 'anticipation': 0.125}
#
#
#  buy,refurbish,stop,whatever,function,performing,quite,often,cause_to_sleep,every,time,randomly,turn,nothing,sell,refurbished :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.3333333333333333, 'positive': 0.3333333333333333, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0, 'anticipation': 0.3333333333333333}
#
#
#  dont,trust,.... :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 1.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  want,use,radio,intercom,get,terrible,reception,live,speech,recognition,software,horrible,wife,native,american,whose,language,english,north,texas,neither,accent,birth,area,yet,unmake,good,job,understand,buy,two,thing,additionally,wifi,reception,poor,marginal,buy,wifi,range,extender,office,ten,foot,router,problem,switch,around,sameness,disconnect,dust,collector :  {'fear': 0.14285714285714285, 'anger': 0.07142857142857142, 'anticip': 0.0, 'trust': 0.07142857142857142, 'surprise': 0.03571428571428571, 'positive': 0.17857142857142858, 'negative': 0.17857142857142858, 'sadness': 0.10714285714285714, 'disgust': 0.07142857142857142, 'joy': 0.07142857142857142, 'anticipation': 0.07142857142857142}
#
#
#  item,never,work,box,break,spent,several,day,try,get,work,run,fix,thing,accomplish,never,order,another,refurbish,device :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.2, 'positive': 0.4, 'negative': 0.2, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.2}
#
#
#  great,product,return,new,refurbish,already,give,problem,connection :  {'fear': 0.25, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.25, 'negative': 0.25, 'sadness': 0.25, 'disgust': 0.0, 'joy': 0.0}
#
#
#  never,buy,certified,refurbished,buy,certify,refurbish,unit,poor,receive,command,sometimes,odd,acknowledge,command,never,buy,refurbished,unit,receive,probably,never,certify,refurbish,indicated,also,buy,new,work,perfectly.very,disappointed :  {'fear': 0.0, 'anger': 0.125, 'anticip': 0.0, 'trust': 0.25, 'surprise': 0.0, 'positive': 0.25, 'negative': 0.125, 'sadness': 0.125, 'disgust': 0.125, 'joy': 0.0}
#
#
#  item,idle,certify,refurbish,mean,work,advertised,instead,item,crash,soon,turn,plug,try,connect,phone,crash,not,would,disconnect,orange,light,would,freeze,thing,would,reboot,blue,light,would,tell,ready,connect,freeze,mid,sentence,try,hold,action,button,second,anything,return,immediately,hope,actually,fix,item,next,buyer,purchase :  {'fear': 0.10344827586206896, 'anger': 0.034482758620689655, 'anticip': 0.0, 'trust': 0.06896551724137931, 'surprise': 0.10344827586206896, 'positive': 0.13793103448275862, 'negative': 0.1724137931034483, 'sadness': 0.1724137931034483, 'disgust': 0.034482758620689655, 'joy': 0.034482758620689655, 'anticipation': 0.13793103448275862}
#
#
#  none :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  idle,time :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0, 'anticipation': 1.0}
#
#
#  've,already,return :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  weary,pick,conversation,passively,use,heard,happen,news,concern,wish,would,release,something,widespread,push,firmware,prevent,not,hear,yet :  {'fear': 0.16666666666666666, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.3333333333333333, 'negative': 0.16666666666666666, 'sadness': 0.16666666666666666, 'disgust': 0.0, 'joy': 0.0, 'anticipation': 0.16666666666666666}
#
#
#  something,wrong,first,one,odd,rep,speak,could,fix,replacement,register,someone,else,price,price,refurbished,one,buy,brand,spank,new,one,problem,new,one :  {'fear': 0.25, 'anger': 0.125, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.375, 'sadness': 0.25, 'disgust': 0.0, 'joy': 0.0}
#
#
#  two,week,set,unretentive,work,connection,dark,silence,guess,lack,purchase,refurbished :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.3333333333333333, 'positive': 0.0, 'negative': 0.3333333333333333, 'sadness': 0.3333333333333333, 'disgust': 0.0, 'joy': 0.0}
#
#
#  not,good :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.2, 'surprise': 0.2, 'positive': 0.2, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.2, 'anticipation': 0.2}
#
#
#  bad,purchase,make,big,fan,love,brand,unlimited,digital,music,video,even,buy,online,game,music,movie,app,try,use,make,simple,purchase,anything,useless :  {'fear': 0.06666666666666667, 'anger': 0.06666666666666667, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.26666666666666666, 'negative': 0.13333333333333333, 'sadness': 0.2, 'disgust': 0.06666666666666667, 'joy': 0.2}
#
#
#  disconnect,speaker,time,day,sell,refurbished,product,effort :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.25, 'negative': 0.25, 'sadness': 0.25, 'disgust': 0.0, 'joy': 0.0, 'anticipation': 0.25}
#
#
#  cant,seem,get,thing,sink,wireless,unsure,return,try,one,time :  {'fear': 0.0, 'anger': 0.2, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.2, 'positive': 0.2, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0, 'anticipation': 0.4}
#
#
#  product,stop,work,return,time,run :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0, 'anticipation': 1.0}
#
#
#  stop,work,month,warranty,good,month,would,assume,product,sell,would,high,standard,guarantee,would,work,whole,month,mean,product,suppose,piece,junk,offer,discount,want,buy,another,one,would,want,buy,another,one :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.2727272727272727, 'surprise': 0.09090909090909091, 'positive': 0.36363636363636365, 'negative': 0.09090909090909091, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.09090909090909091, 'anticipation': 0.09090909090909091}
#
#
#  buy,son,work,return :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  bought,quit,connect,wifi,respond,voice,within,month,hard,soft,reset,unfasten,problem :  {'fear': 0.25, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.5, 'sadness': 0.25, 'disgust': 0.0, 'joy': 0.0}
#
#
#  second,one,refurbished,model,work-at,least,not,home :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 1.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  bad,device,know,refurbish,activate,nobody,talk,activate,start,talk,talk,yell,super,laud :  {'fear': 0.14285714285714285, 'anger': 0.14285714285714285, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.07142857142857142, 'positive': 0.2857142857142857, 'negative': 0.14285714285714285, 'sadness': 0.07142857142857142, 'disgust': 0.07142857142857142, 'joy': 0.0, 'anticipation': 0.07142857142857142}
#
#
#  far,not,impress,not,save,group,correctly,not,understand,time,unsure,excitement,alexas,voice,sound,like,water,suppose,understand,return,try,home :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.1111111111111111, 'surprise': 0.1111111111111111, 'positive': 0.3333333333333333, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.2222222222222222, 'anticipation': 0.2222222222222222}
#
#
#  great,product,useless,overall,many,unnecessary,feature,unless,smart,home,obviate :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.5, 'negative': 0.5, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  cant,figure,use :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  always,work :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  new,product,great,everything,buy,refurbish,complete,garbage,never,purchase,refurbish,total,dissatisfaction :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.4, 'negative': 0.4, 'sadness': 0.0, 'disgust': 0.2, 'joy': 0.0}
#
#
#  extremely,low,volume :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  bring,replace,one,move,lack,range,previous,non,refurbish,unit,would,seldom,able,find,wi-fi,could,unplug,get,tired,hear,message,trouble,connecting,check,app,unplug,troubleshooting,reconnected,several,time,not,strong :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.25, 'negative': 0.5, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0, 'anticipation': 0.25}
#
#
#  want,listen,music,come,several,echo/dot,unit,simultaneously,must,pay,monthly,fee,think,not,apple,pay,many,could,one,room,not,enough,money :  {'fear': 0.0, 'anger': 0.10526315789473684, 'anticip': 0.0, 'trust': 0.15789473684210525, 'surprise': 0.05263157894736842, 'positive': 0.21052631578947367, 'negative': 0.05263157894736842, 'sadness': 0.05263157894736842, 'disgust': 0.0, 'joy': 0.21052631578947367, 'anticipation': 0.15789473684210525}
#
#
#  work,half,time,not,respond,say,wake,name,work,fine :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0, 'anticipation': 1.0}
#
#
#  want,white,white,bathroom,top,black,show,knew,not,realize,cord,plug,also,black,want,white,cord,plug :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.25, 'surprise': 0.0, 'positive': 0.2, 'negative': 0.1, 'sadness': 0.1, 'disgust': 0.0, 'joy': 0.15, 'anticipation': 0.2}
#
#
#  set,work,hour,die,completely,not,buy,refurbished,send,back,return,day,receive :  {'fear': 0.25, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.25, 'negative': 0.25, 'sadness': 0.25, 'disgust': 0.0, 'joy': 0.0}
#
#
#  horrible,volume,phone,loud,device,bos,one,not,case :  {'fear': 0.2857142857142857, 'anger': 0.14285714285714285, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.2857142857142857, 'sadness': 0.14285714285714285, 'disgust': 0.14285714285714285, 'joy': 0.0}
#
#
#  speaker,pretty,terrible,home,good,product :  {'fear': 0.07142857142857142, 'anger': 0.07142857142857142, 'anticip': 0.0, 'trust': 0.14285714285714285, 'surprise': 0.07142857142857142, 'positive': 0.14285714285714285, 'negative': 0.07142857142857142, 'sadness': 0.07142857142857142, 'disgust': 0.07142857142857142, 'joy': 0.14285714285714285, 'anticipation': 0.14285714285714285}
#
#
#  first,one,quit,work,shortly,get,next,one,become,unresponsive,voice,time,way,get,work,app,unsure,way :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.3333333333333333, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0, 'anticipation': 0.6666666666666666}
#
#
#  device,malfunction,follow,instruction,upsetting :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.5, 'surprise': 0.0, 'positive': 0.5, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  send,back,due,crackle,noise,turn,expect,refurbished,item :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.2, 'surprise': 0.2, 'positive': 0.2, 'negative': 0.2, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0, 'anticipation': 0.2}
#
#
#  honestly,like,time,could,buy,small,one,exact,thing,less,half,buy,video,chat,never,really,use :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.5, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0, 'anticipation': 0.5}
#
#
#  slow,compare :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  device,work,well,product,unfortunately,be_born,ability,play,video,limited,not,play,play,video,cropping,screen,make,look,strange,quite,selection,clock,face,control,displays,one,glaring,annoying,exception,unbend,thing,try,screen,turn,screen,scroll,defeat,purpose,screen,obviate,remind,every,second,thing,obviate,advertising,especially,cost,device,overall,expensive,device,screen,not,useful,annoy,would,not,recommend,people,get,act,together,come,screen,actually,useful :  {'fear': 0.0, 'anger': 0.26666666666666666, 'anticip': 0.0, 'trust': 0.06666666666666667, 'surprise': 0.0, 'positive': 0.13333333333333333, 'negative': 0.3333333333333333, 'sadness': 0.06666666666666667, 'disgust': 0.06666666666666667, 'joy': 0.0, 'anticipation': 0.06666666666666667}
#
#
#  returnef,item,not,speak,spanish :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  first,receive,product,great,however,week,ago,device,serve,video,advertisement,around,night,scar,family,want,make,sure,protect,deny,video,directly,home,spot,not,device,keep,safe :  {'fear': 0.07692307692307693, 'anger': 0.15384615384615385, 'anticip': 0.0, 'trust': 0.15384615384615385, 'surprise': 0.0, 'positive': 0.15384615384615385, 'negative': 0.23076923076923078, 'sadness': 0.07692307692307693, 'disgust': 0.07692307692307693, 'joy': 0.07692307692307693}
#
#
#  couple,day,question,disconnect,see,good,reconnecting :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.125, 'surprise': 0.125, 'positive': 0.25, 'negative': 0.125, 'sadness': 0.125, 'disgust': 0.0, 'joy': 0.125, 'anticipation': 0.125}
#
#
#  want,use,clock,bedroom,font,small,see,distance,apparently,stay :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.5, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0, 'anticipation': 0.5}
#
#
#  meh :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  product,currently,two,relate,software,flaw,make,completely,unusable,card,homescreen,call,thing,try,service,try,turn,homescreen,card,not,one,default,homescreen,card,cycle,automatically,incredibly,annoy,set,opt,card,cycle,instead,cycle,continuously,critically,setting,idle,unit,set,cycle,card,still,continue,cycle,time,reboot,device,re-set,etc,etc.until,two,obvious,software,issue,fix,opinion,product,useless :  {'fear': 0.058823529411764705, 'anger': 0.058823529411764705, 'anticip': 0.0, 'trust': 0.11764705882352941, 'surprise': 0.0, 'positive': 0.17647058823529413, 'negative': 0.23529411764705882, 'sadness': 0.11764705882352941, 'disgust': 0.11764705882352941, 'joy': 0.0, 'anticipation': 0.11764705882352941}
#
#
#  need,harvard,law,degree,operate,thing,back,soon :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.5, 'surprise': 0.0, 'positive': 0.5, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  product,turn,randomly,sometimes,night :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 1.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  would,love,way,stop,screen,constantly,scroll,thing,try,would,make,setting,would,change,review :  {'fear': 0.25, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.25, 'surprise': 0.0, 'positive': 0.25, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.25}
#
#
#  n't,figure,make,receive,call,device,tell,need,register,ignore :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 1.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  great,product,would,give,n't,scroll,face,card,lack,stupid,try,ask,suggestion,pop,yes,scroll,stay,clock,like,card,well,god,bad,irritating,get,super,cheap,face,screen,toward,wall,treat,like,instead,spot,dumb,move,amazons​,part :  {'fear': 0.1, 'anger': 0.1, 'anticip': 0.0, 'trust': 0.06666666666666667, 'surprise': 0.06666666666666667, 'positive': 0.06666666666666667, 'negative': 0.26666666666666666, 'sadness': 0.06666666666666667, 'disgust': 0.1, 'joy': 0.06666666666666667, 'anticipation': 0.1}
#
#
#  product,complete,waste,money,ask,question,either,ignore,answer,give,wrong,answer,find,information,wikipedia :  {'fear': 0.0, 'anger': 0.08333333333333333, 'anticip': 0.0, 'trust': 0.08333333333333333, 'surprise': 0.08333333333333333, 'positive': 0.25, 'negative': 0.25, 'sadness': 0.0, 'disgust': 0.08333333333333333, 'joy': 0.08333333333333333, 'anticipation': 0.08333333333333333}
#
#
#  honestly,already,occasionally,see,lyric,song,listen,really,n't,see,difference :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  switch,helper,shopping,task,assistant :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.25, 'surprise': 0.125, 'positive': 0.375, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.125, 'anticipation': 0.125}
#
#
#  not,smart,not,cancel,snooze,alarm,cancel,pre-set,alarm,weekday :  {'fear': 0.2, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.2, 'positive': 0.0, 'negative': 0.4, 'sadness': 0.2, 'disgust': 0.0, 'joy': 0.0}
#
#
#  great,product,except,actual,way,act,clock,display,time,permanently,'clock,mode,screen,rotate,clock,face,'things,try,screen,intend,buy,several,unit,house,obviate,screen,house,permanently,try,upset,act,clock,basic,feature,spot,could,get,wrong,fail :  {'fear': 0.0, 'anger': 0.09090909090909091, 'anticip': 0.0, 'trust': 0.09090909090909091, 'surprise': 0.0, 'positive': 0.18181818181818182, 'negative': 0.18181818181818182, 'sadness': 0.09090909090909091, 'disgust': 0.0, 'joy': 0.0, 'anticipation': 0.36363636363636365}
#
#
#  want,use,bedside,clock,ability,play,music,podcasts,sadly,continuously,scroll,thing,try,depart,clock,face,get,one,back :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.2, 'negative': 0.1, 'sadness': 0.3, 'disgust': 0.0, 'joy': 0.1, 'anticipation': 0.3}
#
#
#  not,happy,spot,reset,numerous,time,seem,slow,mode,practically,top,hear,even,talk,support,still,lack,theme,menu,choose :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.2, 'surprise': 0.0, 'positive': 0.3, 'negative': 0.1, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.1, 'anticipation': 0.3}
#
#
#  fine,spot,exact,one,massive,failing,order,turn,repeat,alarm,morning,pretty,much,talk,not,thing,usually,want,first,wake,bed,partner,definitely,dislike,yes,manually,swipe,alarm,face,dismiss,swipe,rather,touch,screen,half,asleep,difficult,result,set,snooze,half,time,even,really,try,swipe,dismiss,manage,swipe,dismiss,completely,delete,recur,alarm.this,especially,annoy,could,easily,fix,simply,make,touch,screen,turn,alarm,not,delete,least,make,set,decide,whether,touch,screen,recur,alarm,snooze,turn,clock,year,still,subtract,setting,clearly,be_born,happen,may,big,product,design,screw,ever,make :  {'fear': 0.15789473684210525, 'anger': 0.07894736842105263, 'anticip': 0.0, 'trust': 0.05263157894736842, 'surprise': 0.10526315789473684, 'positive': 0.13157894736842105, 'negative': 0.21052631578947367, 'sadness': 0.02631578947368421, 'disgust': 0.05263157894736842, 'joy': 0.02631578947368421, 'anticipation': 0.15789473684210525}
#
#
#  item,return,repair,receivded,item,back,repair,part,miss,powerlessness,cord,included.please,advise :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.5, 'surprise': 0.0, 'positive': 0.5, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  awesome,spot,disappointment,little,control,screen,show,clock,look,like,order,thing,show,etc,point,n't,throw,box,away,immediately,would,send,back,get,another,full,size :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.2, 'surprise': 0.0, 'positive': 0.2, 'negative': 0.2, 'sadness': 0.1, 'disgust': 0.1, 'joy': 0.0, 'anticipation': 0.2}
#
#
#  product,force,user,review,thing,try,way,disable :  {'fear': 0.3333333333333333, 'anger': 0.16666666666666666, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.3333333333333333, 'sadness': 0.16666666666666666, 'disgust': 0.0, 'joy': 0.0}
#
#
#  use,baby,monitor,purchase,realize,read,review,skill,sync,nest,cam,consider,poor,review,fact,simple,fix,surprised,upgrade,software,allow,minute,view,alert,like,get,nest,app :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.5, 'surprise': 0.16666666666666666, 'positive': 0.16666666666666666, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.16666666666666666}
#
#
#  ignore,customer,use,device,marketing,tool,customize,screen,content,unbend,advertising,thing,try,people,suggest,turn,content,change,not,acceptable,option.moreover,increase,size,slightly,improve,audio,speaker,would,give,device.right,debate,whether,return,device,wife,say :  {'fear': 0.058823529411764705, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.23529411764705882, 'surprise': 0.0, 'positive': 0.4117647058823529, 'negative': 0.058823529411764705, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.17647058823529413, 'anticipation': 0.058823529411764705}
#
#
#  disconnect,often :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.5, 'sadness': 0.5, 'disgust': 0.0, 'joy': 0.0}
#
#
#  get,rid,thong,try,screen,numb,nut :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 1.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  work,fine,get,indundated,thing,try,not,year,old,need,stimulus,tell,thing,find,way,turn,except,....,turn,screen,lose,suitable,fix,back :  {'fear': 0.14285714285714285, 'anger': 0.14285714285714285, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.14285714285714285, 'positive': 0.14285714285714285, 'negative': 0.14285714285714285, 'sadness': 0.14285714285714285, 'disgust': 0.14285714285714285, 'joy': 0.0}
#
#
#  unbend,thing,try,screen,scroll,big,promotion,device,pack,send,back,really,want,get,head,enough,already :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 1.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  thing,wake,middle,night,say,ready,setup,already,setup,simple,thing,check,time,ask,wife,unhappy :  {'fear': 0.0, 'anger': 0.16666666666666666, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.16666666666666666, 'sadness': 0.16666666666666666, 'disgust': 0.16666666666666666, 'joy': 0.0, 'anticipation': 0.3333333333333333}
#
#
#  product,attractive,somewhat,useful,choose,force,user,view,thing,try,trend,greatly,depreciate,value,product,sell,unless,willing,view,billboard :  {'fear': 0.14285714285714285, 'anger': 0.2857142857142857, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.14285714285714285, 'negative': 0.2857142857142857, 'sadness': 0.0, 'disgust': 0.14285714285714285, 'joy': 0.0}
#
#
#  not,good,still,positive,great,play,music,set,alarm,personally,felt,pay,much,product,nearly,half,day,literally,day,purchase,pretty,disappointed,might,still,return,get,money,back :  {'fear': 0.034482758620689655, 'anger': 0.06896551724137931, 'anticip': 0.0, 'trust': 0.13793103448275862, 'surprise': 0.10344827586206896, 'positive': 0.1724137931034483, 'negative': 0.06896551724137931, 'sadness': 0.06896551724137931, 'disgust': 0.034482758620689655, 'joy': 0.1724137931034483, 'anticipation': 0.13793103448275862}
#
#
#  fairly,useless :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.3333333333333333, 'surprise': 0.0, 'positive': 0.3333333333333333, 'negative': 0.3333333333333333, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  buy,spot,love,within,month,start,act,funny,would,stop,working—called,determine,overheat,tell,unplug,technical,support,would,call,within,hour,wait,hour,without,response,reply,email,ask,wait,week,week,absolutely,response,inline,chat,per,instruction,tell,wait,long,really,unacceptable—expected,find,funny,always,thank,member,issue,arise,odd,get,assistance :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.07692307692307693, 'surprise': 0.0, 'positive': 0.23076923076923078, 'negative': 0.23076923076923078, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.07692307692307693, 'anticipation': 0.38461538461538464}
#
#
#  size,screen,thing :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  invasive,scar,crap,speak,write,creapy :  {'fear': 0.14285714285714285, 'anger': 0.14285714285714285, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.2857142857142857, 'sadness': 0.14285714285714285, 'disgust': 0.2857142857142857, 'joy': 0.0}
#
#
#  love,product,disappointed,realize,unretentive,play,videos,past,day,return,date,realize,expensive,alarm,clock,hop,come,back,look,buy,show,kitchen,day,glad,n't :  {'fear': 0.07142857142857142, 'anger': 0.07142857142857142, 'anticip': 0.0, 'trust': 0.07142857142857142, 'surprise': 0.07142857142857142, 'positive': 0.14285714285714285, 'negative': 0.14285714285714285, 'sadness': 0.07142857142857142, 'disgust': 0.07142857142857142, 'joy': 0.14285714285714285, 'anticipation': 0.14285714285714285}
#
#
#  waste,money,really,get,anything,video,chat,device,would,not,cycle,picture,put,slideshow,mode,first,photo,disinherit,matter,even,look,online,research,article,lose,solution,also,problem,device,shut,lack,problem,device,price,difference,worthlessness :  {'fear': 0.13636363636363635, 'anger': 0.09090909090909091, 'anticip': 0.0, 'trust': 0.045454545454545456, 'surprise': 0.09090909090909091, 'positive': 0.09090909090909091, 'negative': 0.22727272727272727, 'sadness': 0.13636363636363635, 'disgust': 0.09090909090909091, 'joy': 0.045454545454545456, 'anticipation': 0.045454545454545456}
#
#
#  tube,would,lack,buy,know :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 1.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  conserve,money,gen,gen,far,good,job,voice,recognition,show,fact,bad,virtually,useless,also,speaker,incredibly,bass,heavy,....,much,hard,understand,voice,'ve,work,adjust,bass,punch,mids,treble,still,sound,awful,finally,screen,subtract,much,n't,see,across,room,rarely,activate,meaningful,way,n't,distraction,help,use,much,practicalthan,use,show,surprised,break,little,useful,perhaps,future,waste,time,money :  {'fear': 0.058823529411764705, 'anger': 0.09803921568627451, 'anticip': 0.0, 'trust': 0.13725490196078433, 'surprise': 0.13725490196078433, 'positive': 0.11764705882352941, 'negative': 0.13725490196078433, 'sadness': 0.058823529411764705, 'disgust': 0.0784313725490196, 'joy': 0.0784313725490196, 'anticipation': 0.09803921568627451}
#
#
#  thought,would,powerful,lot,functionality,not,much,good,not,worth,money :  {'fear': 0.05, 'anger': 0.1, 'anticip': 0.0, 'trust': 0.15, 'surprise': 0.1, 'positive': 0.2, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.05, 'joy': 0.15, 'anticipation': 0.2}
#
#
#  not,understand,excitement,device,one,either,rarely,get,say,correct,unrestraint,dish,receiver,yes,set,correctly,use,app,phone,get,good,deal,definately,worthlessness,price,though,maybe,another,month,get,well,either,one,deaf,dumb,really,not,recommend,item,current,time :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.15789473684210525, 'surprise': 0.15789473684210525, 'positive': 0.21052631578947367, 'negative': 0.10526315789473684, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.15789473684210525, 'anticipation': 0.21052631578947367}
#
#
#  disappointed,hear,respond,request :  {'fear': 0.0, 'anger': 0.25, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.25, 'sadness': 0.25, 'disgust': 0.25, 'joy': 0.0}
#
#
#  show,break,anything,screen,lose,line,resolution,timer,reminder,hour,late,reminder,trigger,try,set,reminder,lack,issue,show,would,nice,could,get,act,together,actually,fix,thing :  {'fear': 0.08333333333333333, 'anger': 0.08333333333333333, 'anticip': 0.0, 'trust': 0.16666666666666666, 'surprise': 0.16666666666666666, 'positive': 0.0, 'negative': 0.25, 'sadness': 0.16666666666666666, 'disgust': 0.08333333333333333, 'joy': 0.0}
#
#
#  pretty,dumb :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.2, 'surprise': 0.0, 'positive': 0.2, 'negative': 0.2, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.2, 'anticipation': 0.2}
#
#
#  much,price,pair,speaker :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  intrusive,turn :  {'fear': 0.2, 'anger': 0.2, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.2, 'positive': 0.0, 'negative': 0.2, 'sadness': 0.0, 'disgust': 0.2, 'joy': 0.0}
#
#
#  like,another,kid,house,constantly,repeat,myself.i,tell,something,clear,day,accord,history,hear,something,comeletely,different.the,device,really,cool,like,concept,get,two,however,idle,intended.i,find,irritate,often,not,use,device :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.5, 'surprise': 0.0, 'positive': 0.5, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  way,music,sound,poor,quality :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.3333333333333333, 'negative': 0.0, 'sadness': 0.3333333333333333, 'disgust': 0.0, 'joy': 0.3333333333333333}
#
#
#  device,stop,communicate,properly,sonos,device,upon,connect,show,account,ask,device,play,music,sonos,baffle,system,previously,work,flawlessly,two,week,eventually,solve,problem,neither,sonos,could,figure :  {'fear': 0.09090909090909091, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.36363636363636365, 'surprise': 0.0, 'positive': 0.18181818181818182, 'negative': 0.09090909090909091, 'sadness': 0.18181818181818182, 'disgust': 0.0, 'joy': 0.09090909090909091}
#
#
#  suck :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 1.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  always,want,one,till,get,one,not,crack,hard,navigate,actually,like,well :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 1.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  show,say,work,certain,apps,not,cozi,state,work,show,cozi,family,well,need,back,draw,board,would,needed,piece,technology,lack,essential,please,fix,cost,show,marvelous,get,show,take,shop,list,far,add,item,list,long,lag,not,router,slow,provider,speed,speed,not,problem,new,item,update,cozi,slow,help,need,get,updated,work,conditioning :  {'fear': 0.06666666666666667, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.26666666666666666, 'surprise': 0.0, 'positive': 0.2, 'negative': 0.2, 'sadness': 0.06666666666666667, 'disgust': 0.0, 'joy': 0.06666666666666667, 'anticipation': 0.13333333333333333}
#
#
#  disappoint,device,unable,access,dec,aware,purchase,problem,device,voice,stop,work,throughout,day,see,try,respond,window,open,contain,info,ask,like,device,get,process,stop,work,blue,bar,flash,keep,unplug,restart,device,start,work,irritating,device,could,really,great,device,would,act,like,grownup :  {'fear': 0.07142857142857142, 'anger': 0.14285714285714285, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.2857142857142857, 'sadness': 0.2857142857142857, 'disgust': 0.14285714285714285, 'joy': 0.0, 'anticipation': 0.07142857142857142}
#
#
#  return,repair,repair,problem,require,defective,part,show,itself.i,sent,repair,get,back,nonbeing,fix,site,give,option,complain,page.i,spot,work,perfectly,position :  {'fear': 0.1, 'anger': 0.1, 'anticip': 0.0, 'trust': 0.1, 'surprise': 0.0, 'positive': 0.1, 'negative': 0.3, 'sadness': 0.2, 'disgust': 0.1, 'joy': 0.0}
#
#
#  great,device,feature,awesome,interaction,fantastic,home,automation,work,perfect,link,account,correctly,issue,show,send,repair,screen,glitching,less,month,old,already,issue,first,repair,send,update,firmware,get,device,back,nothing,work,update,new,firmware,work,week,later,glitch,start,love,show,get,really,frustrate,glitching :  {'fear': 0.0, 'anger': 0.06666666666666667, 'anticip': 0.0, 'trust': 0.26666666666666666, 'surprise': 0.0, 'positive': 0.2, 'negative': 0.06666666666666667, 'sadness': 0.06666666666666667, 'disgust': 0.06666666666666667, 'joy': 0.13333333333333333, 'anticipation': 0.13333333333333333}
#
#
#  buy,product,hop,would,pretty,well,developed,far,enough,along,therefore,expect,responsive,piece,crap,doesnt,even,know,respond,question,tell,ask,button,manual,see,step,device,potential,give,big,screen,decent,sound,buck,would,never,reccomend,even,spent,feel,like,get,short,lastly,device,pretty,useless,without,membership,link,personal,account,thing,literally,decorate,bluetooth,speaker,family,account,one,get,work,minimal,even,membership,music,pas,something,extra,month,leave,item,subscription,nightmare,overpriced,decorate,bluetooth,speaker,eye,would,give,zero,could :  {'fear': 0.047619047619047616, 'anger': 0.023809523809523808, 'anticip': 0.0, 'trust': 0.19047619047619047, 'surprise': 0.07142857142857142, 'positive': 0.21428571428571427, 'negative': 0.16666666666666666, 'sadness': 0.07142857142857142, 'disgust': 0.047619047619047616, 'joy': 0.07142857142857142, 'anticipation': 0.09523809523809523}
#
#
#  family,buy,several,help,communicate,old,parent,grandparent,need,simple,device,full-fledged,tablet,fantastic,potential,digital,photo,screen,video,call,easy,access,music,audio,book,etc,however,setup,discover,huge,lurking,negative,force,view,continous,spam,home,screen,promote,feature,turn,many,thing,settins,unbend,thing,try,instead,beautiful,digital,photo,screen,weather,time,constantly,spam,across,home,screen,say,try,......,please,listen,customer,offer,setting,turn,spam :  {'fear': 0.05555555555555555, 'anger': 0.05555555555555555, 'anticip': 0.0, 'trust': 0.1111111111111111, 'surprise': 0.0, 'positive': 0.3333333333333333, 'negative': 0.16666666666666666, 'sadness': 0.1111111111111111, 'disgust': 0.0, 'joy': 0.1111111111111111, 'anticipation': 0.05555555555555555}
#
#
#  work,fine,realize,need,use :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  need,able,connect,party,viceo,apps :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  tech,understand,common,word,basically,glorified,radio :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.3333333333333333, 'surprise': 0.0, 'positive': 0.6666666666666666, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  sound,terrible,like,tin,love,item,awful :  {'fear': 0.16666666666666666, 'anger': 0.16666666666666666, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.08333333333333333, 'negative': 0.16666666666666666, 'sadness': 0.16666666666666666, 'disgust': 0.16666666666666666, 'joy': 0.08333333333333333}
#
#
#  device,show,seem,huge,potential,really,want,like,soon,find,quite,limited,bit,disappointing,not,end,world,use,like,use,screenless,....,little,month,screen,start,flickering,mostly,bottom,screen,inequitable,quick,look,forum,make,understand,pointless,ask,replacement,people,device,replace,start,flicker,shortly,not,provide,serious,answer,quite,time,apparently.long,story,short,move,hallway,use,expensive,bulky,voice,activate,light,switch,hue,light,like,headline,suggest,meh :  {'fear': 0.0, 'anger': 0.05555555555555555, 'anticip': 0.0, 'trust': 0.16666666666666666, 'surprise': 0.0, 'positive': 0.05555555555555555, 'negative': 0.2777777777777778, 'sadness': 0.2222222222222222, 'disgust': 0.0, 'joy': 0.0, 'anticipation': 0.2222222222222222}
#
#
#  know,answer,many,question,ask,example,ask,many,cup,pound,say,pound,form,money :  {'fear': 0.0, 'anger': 0.2727272727272727, 'anticip': 0.0, 'trust': 0.09090909090909091, 'surprise': 0.09090909090909091, 'positive': 0.18181818181818182, 'negative': 0.18181818181818182, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.09090909090909091, 'anticipation': 0.09090909090909091}
#
#
#  decide,buy,smart,door,lock,decide,get,plus,control,choose,kwikset,say,compatible,buy,pose,question,somebody,community,say,work,ignore,z-wave,lock,zigbee,incompatible,body,know,lock,work,seamlessly,plus,not,guess,choice,exchange,plus,regular,buy,separate,like,wink.,return,whole,system,get,something,else.i,n't,want,buy,another,use,along,side,plus,'ll,back,ask,integrate,two,hubs.the,reason,keep,buy,smart,system,point,afraid,would,malfunction,seamlessly,unfortunately,enough,research,something,idle :  {'fear': 0.05555555555555555, 'anger': 0.05555555555555555, 'anticip': 0.0, 'trust': 0.16666666666666666, 'surprise': 0.05555555555555555, 'positive': 0.3333333333333333, 'negative': 0.2222222222222222, 'sadness': 0.05555555555555555, 'disgust': 0.05555555555555555, 'joy': 0.0}
#
#
#  habla,espanol :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  broke,leave,help,fixing,replace :  {'fear': 0.16666666666666666, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.16666666666666666, 'positive': 0.0, 'negative': 0.3333333333333333, 'sadness': 0.3333333333333333, 'disgust': 0.0, 'joy': 0.0}
#
#
#  still,unable,connect,device,although,say,build,buy,bridge,connect,device,think,everything,would,sync,device,still,not,discover,via,plus,look,forward,feature,able,play,music,check,weather,etc,fine :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.5, 'negative': 0.125, 'sadness': 0.25, 'disgust': 0.0, 'joy': 0.125}
#
#
#  terrible,stop,work,one,day :  {'fear': 0.2, 'anger': 0.2, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.2, 'sadness': 0.2, 'disgust': 0.2, 'joy': 0.0}
#
#
#  not,speak,spanish,buy,grandmother,someone,talk,not,around,spanish :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 1.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  get,excite,device,good,sound,control,hue,bulbs.what,n't,realize,also,meagerly,communicate,n't,use,hue,bulb,full,potential,device,turn,light,set,number,preset,color,also,not,update,bulb,new,firmare,security,concern,me.do,sell,want,full,featured,new,iot,device,end,need,update,standalone,make,inside,device,redundant,pointless.i,still,love,zero,complaint,functionality,sound,quality,device,disappointed,functionality :  {'fear': 0.041666666666666664, 'anger': 0.125, 'anticip': 0.0, 'trust': 0.08333333333333333, 'surprise': 0.08333333333333333, 'positive': 0.25, 'negative': 0.125, 'sadness': 0.041666666666666664, 'disgust': 0.041666666666666664, 'joy': 0.125, 'anticipation': 0.08333333333333333}
#
#
#  disappointed,product,try,install,two,different,unit,neither,one,successfully,complete,hour,technician,reset,app,unplug,plus,internet,connection,try,use,application,phone,tablet,chromebook,luck,unclean,direction,application,probably,send,back,mark,not,ready,time :  {'fear': 0.0, 'anger': 0.07692307692307693, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.07692307692307693, 'positive': 0.07692307692307693, 'negative': 0.15384615384615385, 'sadness': 0.07692307692307693, 'disgust': 0.15384615384615385, 'joy': 0.07692307692307693, 'anticipation': 0.3076923076923077}
#
#
#  awesome,rcieved,light,buld,ignore,need,another,adapter,light,buld,work,unmindful,disappoint :  {'fear': 0.0, 'anger': 0.2, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.4, 'sadness': 0.2, 'disgust': 0.2, 'joy': 0.0}
#
#
#  wish,battery,describe,well,plug,item :  {'fear': 0.0, 'anger': 0.5, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.5, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  hard,setup,think,reason,default,twice,thru,many,step,setup,find,device,would,nice,could,interact,xfinity,cable,cable,box,also,idle,xfinity,alarm,house,camera,nice,set,disarm,alarm,install,skill,app,setup,bulb,whats,ship,product,say,setup,bulb,find,new,bulb,setup,nest,fine,use,third,party,apps,work :  {'fear': 0.1875, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0625, 'surprise': 0.25, 'positive': 0.0625, 'negative': 0.1875, 'sadness': 0.0625, 'disgust': 0.0625, 'joy': 0.0, 'anticipation': 0.125}
#
#
#  part,work,fine,hue,disaster,work,month,nothing,spent,hour,phone,tech,support,one,send,repair,try,reconnect,light,pain,reset,light,bulb,take,time,get,reset,spend,hour,say,customer,service,friendly,try,helpful,smart,plug,lamp :  {'fear': 0.10526315789473684, 'anger': 0.05263157894736842, 'anticip': 0.0, 'trust': 0.10526315789473684, 'surprise': 0.05263157894736842, 'positive': 0.15789473684210525, 'negative': 0.15789473684210525, 'sadness': 0.10526315789473684, 'disgust': 0.05263157894736842, 'joy': 0.10526315789473684, 'anticipation': 0.10526315789473684}
#
#
#  suppose,come,free,hue,lightbulb,day,light,bulb,arrive,false,advertising :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0, 'anticipation': 1.0}
#
#
#  lack,week,already,unplug,network,try,reconnecting,manually,never,appear,list,device,connect,way,back :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.5, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0, 'anticipation': 0.5}
#
#
#  'll,return,nothing,annoy,differ,turn,obviate,interfere,hue,bridge,odd,install,light,unless,unplug,plenty,review,depth,issue,bottom,line,suck,negate,z-wave,zigbee,fairness,know,advance,one,protocol,support,unmake,many,function,dedicated,one,point,notice,right,away,hue,bridge,support,firmware,upgrade,light,bulb,n't,find,rather,interest :  {'fear': 0.06666666666666667, 'anger': 0.06666666666666667, 'anticip': 0.0, 'trust': 0.06666666666666667, 'surprise': 0.06666666666666667, 'positive': 0.2, 'negative': 0.2, 'sadness': 0.06666666666666667, 'disgust': 0.06666666666666667, 'joy': 0.06666666666666667, 'anticipation': 0.13333333333333333}
#
#
#  disconnect,direct,even,though,say,would,spend,multiple,hour,make,phone,call,text,also,miss,free,bulb :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.5, 'sadness': 0.5, 'disgust': 0.0, 'joy': 0.0}
#
#
#  n't,use,apple,music,worthless,without,sound,quality,also,poor :  {'fear': 0.0, 'anger': 0.14285714285714285, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.14285714285714285, 'negative': 0.14285714285714285, 'sadness': 0.2857142857142857, 'disgust': 0.14285714285714285, 'joy': 0.14285714285714285}
#
#
# ...
#
#
#  soon,still,learn :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 1.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  enjoy,still,learn,command,run,one,frustrating,issue,not,user,friendly,try,set,voice,recognition,household :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.2, 'surprise': 0.0, 'positive': 0.4, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.2, 'anticipation': 0.2}
#
#
#  love,option,play,music,everywhere,house,multiple,device :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.5, 'negative': 0.0, 'sadness': 0.16666666666666666, 'disgust': 0.0, 'joy': 0.3333333333333333}
#
#
#  like,almost,everything :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  amaze,help,become,well,organize,give,traffic,update,weather,update,help,maintain,good,fast,morning,routine :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.2222222222222222, 'surprise': 0.2222222222222222, 'positive': 0.3333333333333333, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.1111111111111111, 'anticipation': 0.1111111111111111}
#
#
#  kid,love,skill,amazing,would,like,see,get,little,smarter,answer,basic,question :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.6666666666666666, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.3333333333333333}
#
#
#  great,definitely,get,little,old,n't,really,regret,love,hook,speaker,via,bluetooth,wake,smith :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.2, 'surprise': 0.0, 'positive': 0.2, 'negative': 0.2, 'sadness': 0.2, 'disgust': 0.0, 'joy': 0.2}
#
#
#  love,add,upstairs,bedroom :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.5, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.5}
#
#
#  get,love,everything,around,house :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.5, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.5}
#
#
#  device,easy,set,work,perfectly :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  easy,set,start,use,work,advertised :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0, 'anticipation': 1.0}
#
#
#  love,little,know,original,large,unmake,pleased,capability :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.5, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.5}
#
#
#  work,expect,one,son,love,room,easy,set,alarm,play,music :  {'fear': 0.08333333333333333, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.08333333333333333, 'surprise': 0.16666666666666666, 'positive': 0.25, 'negative': 0.08333333333333333, 'sadness': 0.08333333333333333, 'disgust': 0.0, 'joy': 0.16666666666666666, 'anticipation': 0.08333333333333333}
#
#
#  dislike,volume,silence,loud,enough :  {'fear': 0.0, 'anger': 0.3333333333333333, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.3333333333333333, 'sadness': 0.0, 'disgust': 0.3333333333333333, 'joy': 0.0}
#
#
#  love,give,one,gift,huge,hit :  {'fear': 0.0, 'anger': 0.125, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.125, 'positive': 0.25, 'negative': 0.125, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.25, 'anticipation': 0.125}
#
#
#  expect :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.25, 'surprise': 0.25, 'positive': 0.25, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0, 'anticipation': 0.25}
#
#
#  love,technology,old,easy,set,use,bedroom,use,everything,use,living,room :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.6666666666666666, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.3333333333333333}
#
#
#  use,buy,husband,would,able,contact,someone,fall,lack,access,phone :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.25, 'negative': 0.5, 'sadness': 0.25, 'disgust': 0.0, 'joy': 0.0}
#
#
#  amazing,product,still,learnimg,thing :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  friend :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.3333333333333333, 'surprise': 0.0, 'positive': 0.3333333333333333, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.3333333333333333}
#
#
#  easy,thing :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  good,device :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.2, 'surprise': 0.2, 'positive': 0.2, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.2, 'anticipation': 0.2}
#
#
#  overall,love,command,ineffective,may,part,user,error,become,accustom,ask :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.2, 'negative': 0.4, 'sadness': 0.2, 'disgust': 0.0, 'joy': 0.2}
#
#
#  additional,base,device,make,access,well,part,home,rather,try,shout,question,instruction,house,lol,would,differ,without,variety,function,perform :  {'fear': 0.0, 'anger': 0.16666666666666666, 'anticip': 0.0, 'trust': 0.3333333333333333, 'surprise': 0.16666666666666666, 'positive': 0.3333333333333333, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  work,great,love,fact,play,music,group,device :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.16666666666666666, 'surprise': 0.0, 'positive': 0.3333333333333333, 'negative': 0.0, 'sadness': 0.16666666666666666, 'disgust': 0.0, 'joy': 0.3333333333333333}
#
#
#  love,think,would,addicted :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.5, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.5}
#
#
#  work,beautifully,excellent,sound :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.3333333333333333, 'surprise': 0.0, 'positive': 0.3333333333333333, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.3333333333333333}
#
#
#  still,learn,everything,good,room,volume,pretty,good,without,additional,speaker :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.2, 'surprise': 0.13333333333333333, 'positive': 0.26666666666666666, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.2, 'anticipation': 0.2}
#
#
#  neat,tool,enjoy,family :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.25, 'surprise': 0.0, 'positive': 0.25, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.25, 'anticipation': 0.25}
#
#
#  easy,connect,skill,create,gen,work,fine :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.5, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.5}
#
#
#  live,alone,best,companion :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.3333333333333333, 'surprise': 0.0, 'positive': 0.3333333333333333, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.3333333333333333}
#
#
#  easy,set,connect,smart,device,need :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  love,personally,prefer,spotify,music,great,able,set,default,not,day,without,music,home,also,reason,get,keep,pup,calm,leave,tell,play,classical,music,jazz,work,wonder,lot,calmer,bark,lock,door,start,walk,away,must :  {'fear': 0.038461538461538464, 'anger': 0.038461538461538464, 'anticip': 0.0, 'trust': 0.038461538461538464, 'surprise': 0.038461538461538464, 'positive': 0.3076923076923077, 'negative': 0.11538461538461539, 'sadness': 0.19230769230769232, 'disgust': 0.038461538461538464, 'joy': 0.15384615384615385, 'anticipation': 0.038461538461538464}
#
#
#  love,work,great,still,problem,get,well,every,day,not,expert,think,sound,quality,fine,not,perfect,good :  {'fear': 0.0625, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.1875, 'surprise': 0.0625, 'positive': 0.25, 'negative': 0.0625, 'sadness': 0.0625, 'disgust': 0.0, 'joy': 0.1875, 'anticipation': 0.125}
#
#
#  second,purchase,price,cheap,seriously,thinking,buy,use,everything,next,best,thing,internet :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 1.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  love,buy,one,daughter,one :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.5, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.5}
#
#
#  not,loud,think :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  enjoy,still,discover,new :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.25, 'surprise': 0.0, 'positive': 0.25, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.25, 'anticipation': 0.25}
#
#
#  able,add,speaker,plus,take,deck,outside,love,big,bedroom :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.5, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.5}
#
#
#  excellent,device,work,great,problem,concern :  {'fear': 0.16666666666666666, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.16666666666666666, 'surprise': 0.0, 'positive': 0.16666666666666666, 'negative': 0.16666666666666666, 'sadness': 0.16666666666666666, 'disgust': 0.0, 'joy': 0.16666666666666666}
#
#
#  pretty,fun,nice,speaker,respond,question,n't,understand,command,time :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.1111111111111111, 'surprise': 0.0, 'positive': 0.3333333333333333, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.2222222222222222, 'anticipation': 0.3333333333333333}
#
#
#  like,hand,free,operation,tap,use,control,smart,plug :  {'fear': 0.5, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.5, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  love,actually,throughout,house,favorite,function,list,great,time,management,course,music :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.18181818181818182, 'surprise': 0.0, 'positive': 0.36363636363636365, 'negative': 0.0, 'sadness': 0.09090909090909091, 'disgust': 0.0, 'joy': 0.2727272727272727, 'anticipation': 0.09090909090909091}
#
#
#  product,easy,use,entertaining,yet,hook,light,look,forward :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.5, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.25, 'anticipation': 0.25}
#
#
#  work,great,speaker,not,good,music,need,get,bluetooth,speaker :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.125, 'surprise': 0.125, 'positive': 0.25, 'negative': 0.0, 'sadness': 0.125, 'disgust': 0.0, 'joy': 0.25, 'anticipation': 0.125}
#
#
#  outstanding,product,easy,use,work,great :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.3333333333333333, 'negative': 0.3333333333333333, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.3333333333333333}
#
#
#  six,throughout,home,great,time,music,talk,happens,randomly,may,sensitive,listening,option,change,name,engagement,command,computer,little,annoying,color,black,white,would,also,good,thing :  {'fear': 0.047619047619047616, 'anger': 0.047619047619047616, 'anticip': 0.0, 'trust': 0.09523809523809523, 'surprise': 0.09523809523809523, 'positive': 0.23809523809523808, 'negative': 0.09523809523809523, 'sadness': 0.09523809523809523, 'disgust': 0.0, 'joy': 0.14285714285714285, 'anticipation': 0.14285714285714285}
#
#
#  use,product,music,great :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.3333333333333333, 'negative': 0.0, 'sadness': 0.3333333333333333, 'disgust': 0.0, 'joy': 0.3333333333333333}
#
#
#  easy,set-up,use :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  like,device,house,sale,price,day,tempting :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  love,exactly,say :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.5, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.5}
#
#
#  use,control,smart,home,device,work,great :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  convenient :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 1.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  este,producto,llegó,semana,quedó,sin,olor,perdió,toda,escencia,huele,solo,alcohol :  {'fear': 0.2, 'anger': 0.2, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.2, 'sadness': 0.2, 'disgust': 0.2, 'joy': 0.0}
#
#
#  easy,set,ready,use,minute :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0, 'anticipation': 1.0}
#
#
#  barry :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  three,year,old,love,good,basic,household,task,'re,add,smart,outlet,bulb :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.1111111111111111, 'surprise': 0.1111111111111111, 'positive': 0.4444444444444444, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.2222222222222222, 'anticipation': 0.1111111111111111}
#
#
#  awesome,device,wish,buy,one,age,ago :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  perfect,kid,adult,everyone :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.25, 'surprise': 0.0, 'positive': 0.25, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.25, 'anticipation': 0.25}
#
#
#  listen,music,search,location,check,time,look,weather,many,task,learn,simple,set :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.5, 'negative': 0.0, 'sadness': 0.16666666666666666, 'disgust': 0.0, 'joy': 0.16666666666666666, 'anticipation': 0.16666666666666666}
#
#
#  love,thing,run,entire,home,light,thermostat,front,door,dead,bolt,camera,love,listen,npr,thing,well,worth,value,really,shine,stat,add,smart,device,control,entire,home,like,right,trek,....,name,mine,computer,get,feel,amazing,device,smart,system :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.14285714285714285, 'surprise': 0.0, 'positive': 0.5714285714285714, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.2857142857142857}
#
#
#  complaint,sound,quality,n't,great,mostly,use,command,though,another,hook,stereo,system,play,music,couple,friends,forget,audio,quality,'re,bother,kind,thing,full,size,make,sure,hook,large,speaker :  {'fear': 0.0, 'anger': 0.08333333333333333, 'anticip': 0.0, 'trust': 0.16666666666666666, 'surprise': 0.0, 'positive': 0.25, 'negative': 0.25, 'sadness': 0.08333333333333333, 'disgust': 0.0, 'joy': 0.16666666666666666}
#
#
#  nice,little,unit,recall :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
#
#
#  easy,set,use,help,provide,music,etc,small,space,look :  {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.16666666666666666, 'surprise': 0.0, 'positive': 0.3333333333333333, 'negative': 0.16666666666666666, 'sadness': 0.16666666666666666, 'disgust': 0.0, 'joy': 0.16666666666666666}

# %%
 
# Create object
emotion = NRCLex(text)
 
# Using methods to classigy emotion
print('\n', emotion.words)
print('\n', emotion.sentences)
print('\n', emotion.affect_list)
print('\n', emotion.affect_dict)
print('\n', emotion.raw_emotion_scores)
print('\n', emotion.top_emotions)
print('\n', emotion.affect_frequencies)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1000\3708397797.py in <module>
#       1 # Create object
# ----> 2 emotion = NRCLex(text)
#       3
#       4 # Using methods to classigy emotion
#       5 print('\n', emotion.words)
#
# D:\Nuova cartella (2)\lib\site-packages\nrclex.py in __init__(self, text)
#    2870     def __init__(self, text):
#    2871         self.text = text
# -> 2872         blob = TextBlob(text)
#    2873         self.words = list(blob.words)
#    2874         self.sentences = list(blob.sentences)
#
# D:\Nuova cartella (2)\lib\site-packages\textblob\blob.py in __init__(self, text, tokenizer, pos_tagger, np_extractor, analyzer, parser, classifier, clean_html)
#     382                 parser=None, classifier=None, clean_html=False):
#     383         if not isinstance(text, basestring):
# --> 384             raise TypeError('The `text` argument passed to `__init__(text)` '
#     385                             'must be a string, not {0}'.format(type(text)))
#     386         if clean_html:
#
# TypeError: The `text` argument passed to `__init__(text)` must be a string, not <class 'pandas.core.series.Series'>

# %%
import pandas as pd
import nltk
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.svm import LinearSVC, SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import TfidfVectorizer
import string
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.corpus import wordnet
import re
import gensim
from gensim.models import KeyedVectors
import numpy as np
from numpy import dot
from numpy.linalg import norm
from gensim.models import Word2Vec
from gensim.models.phrases import Phrases
from nltk import sent_tokenize
from nltk.tokenize.treebank import TreebankWordDetokenizer
import gensim.downloader as api
from preprocessing import *

# %%
custom_stopwords = ['echo', 'alexa', "alexia", 'dot', "star", 'amazon', 'prime', '2nd', 'generation', "fire", "stick", "firestick", "skype", "facetime", '1st', '3rd', '4th', '5th', "hub", "hulu", 'google', 'netflix', "sony", 'youtube', 'philip', 'tp-link', 'fourth', 'roku', "siri", 'i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'nor', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "...", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', 'didn', 'doesn', 'hadn', 'hasn', 'haven', 'isn', 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', 'wasn', 'weren', 'won', 'wouldn']

def negation_handler(sentence):	

    """Handle negations using WordNet. See https://github.com/UtkarshRedd/Negation_handling for a clear explenation."""

    temp = int(0)
    for i in range(len(sentence)):
        if sentence[i-1] in ['not',"n't", "no", "without"]:
            antonyms = []
            for syn in wordnet.synsets(sentence[i]):
                syns = wordnet.synsets(sentence[i])
                w1 = syns[0].name()
                temp = 0
                for l in syn.lemmas():
                    if l.antonyms():
                        antonyms.append(l.antonyms()[0].name())
                max_dissimilarity = 0
                for ant in antonyms:
                    syns = wordnet.synsets(ant)
                    w2 = syns[0].name()
                    syns = wordnet.synsets(sentence[i])
                    w1 = syns[0].name()
                    word1 = wordnet.synset(w1)
                    word2 = wordnet.synset(w2)
                    if isinstance(word1.wup_similarity(word2), float) or isinstance(word1.wup_similarity(word2), int):
                        temp = 1 - word1.wup_similarity(word2)
                    if temp>max_dissimilarity:
                        max_dissimilarity = temp
                        antonym_max = ant
                        sentence[i] = antonym_max
                        sentence[i-1] = ''
    while '' in sentence:
        sentence.remove('')
    return sentence

# %%
dataset = pd.read_csv("amazon_alexa.tsv", sep = "\t")
dataset.drop(dataset[dataset.rating == 3].index, inplace=True) #droppa recensioni con 3 stelle
# dataset.drop(dataset[dataset.rating == 4].index, inplace=True) #droppa recensioni con 4 stelle
dataset.head()
# Out:
#    rating       date         variation  \
# 0       5  31-Jul-18  Charcoal Fabric
# 1       5  31-Jul-18  Charcoal Fabric
# 2       4  31-Jul-18    Walnut Finish
# 3       5  31-Jul-18  Charcoal Fabric
# 4       5  31-Jul-18  Charcoal Fabric
#
#                                     verified_reviews  feedback
# 0                                      Love my Echo!         1
# 1                                          Loved it!         1
# 2  Sometimes while playing a game, you can answer...         1
# 3  I have had a lot of fun with this thing. My 4 ...         1
# 4                                              Music         1

# %%
dataset = drop_positive_duplicates(dataset)
dataset.shape
# Out:
# (2453, 5)

# %%
new_text, new_sent_tok = tokenize_list_of_text(dataset["verified_reviews"], custom_stopwords, False, pos_list)
# contengono una lista di tutte le frasi pre processate, nella prima variabile in stringa, nella seconda in tokens
# Out:
# total number of types extracted is: 3174

# %%
negative_reviews = list(dataset[dataset["feedback"] == 0]["verified_reviews"].values)
negative_text, negative_tok = tokenize_list_of_text(negative_reviews, custom_stopwords, False, pos_list)
# Out:
# total number of types extracted is: 1240

# %%
dataset['cleared_text'] = np.array(new_sent_tok)
# Out:
# C:\Users\naomi\AppData\Local\Temp\ipykernel_1000\311145445.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   dataset['cleared_text'] = np.array(new_sent_tok)

# %%
dataset
# Out:
#       rating       date             variation  \
# 46         2  30-Jul-18      Charcoal Fabric
# 111        2  30-Jul-18      Charcoal Fabric
# 141        1  30-Jul-18      Charcoal Fabric
# 162        1  30-Jul-18     Sandstone Fabric
# 176        2  30-Jul-18  Heather Gray Fabric
# ...      ...        ...                   ...
# 2795       5  30-Jul-18            Black  Dot
# 2796       5  30-Jul-18            Black  Dot
# 2797       5  30-Jul-18            White  Dot
# 2799       5  29-Jul-18            Black  Dot
# 2800       5  31-Jul-18            Black  Dot
#
#                                        verified_reviews  feedback  \
# 46    It's like Siri, in fact, Siri answers more acc...         0
# 111   Sound is terrible if u want good music too get...         0
# 141                                  Not much features.         0
# 162   Stopped working after 2 weeks ,didn't follow c...         0
# 176                                Sad joke. Worthless.         0
# ...                                                 ...       ...
# 2795  Listening to music, searching locations, check...         1
# 2796  I do love these things, i have them running my...         1
# 2797  Only complaint I have is that the sound qualit...         1
# 2799                        Nice little unit  no issues         1
# 2800  The echo dot was easy to set up and use. It he...         1
#
#                                            cleared_text
# 46    [like, fact, answer, accurately, n't, see, rea...
# 111     [sound, terrible, want, good, music, get, bose]
# 141                                [not, much, feature]
# 162   [stop, work, week, precede, command, really, f...
# 176                              [sad, joke, worthless]
# ...                                                 ...
# 2795  [listen, music, search, location, check, time,...
# 2796  [love, thing, run, entire, home, light, thermo...
# 2797  [complaint, sound, quality, n't, great, mostly...
# 2799                       [nice, little, unit, recall]
# 2800  [easy, set, use, help, provide, music, etc, sm...
#
# [2453 rows x 6 columns]

# %%
dataset['clearedtext'] = dataset['cleared_text'].apply(lambda x: ','.join(map(str, x)))

# %%
dataset
# Out:
#       rating       date             variation  \
# 46         2  30-Jul-18      Charcoal Fabric
# 111        2  30-Jul-18      Charcoal Fabric
# 141        1  30-Jul-18      Charcoal Fabric
# 162        1  30-Jul-18     Sandstone Fabric
# 176        2  30-Jul-18  Heather Gray Fabric
# ...      ...        ...                   ...
# 2795       5  30-Jul-18            Black  Dot
# 2796       5  30-Jul-18            Black  Dot
# 2797       5  30-Jul-18            White  Dot
# 2799       5  29-Jul-18            Black  Dot
# 2800       5  31-Jul-18            Black  Dot
#
#                                        verified_reviews  feedback  \
# 46    It's like Siri, in fact, Siri answers more acc...         0
# 111   Sound is terrible if u want good music too get...         0
# 141                                  Not much features.         0
# 162   Stopped working after 2 weeks ,didn't follow c...         0
# 176                                Sad joke. Worthless.         0
# ...                                                 ...       ...
# 2795  Listening to music, searching locations, check...         1
# 2796  I do love these things, i have them running my...         1
# 2797  Only complaint I have is that the sound qualit...         1
# 2799                        Nice little unit  no issues         1
# 2800  The echo dot was easy to set up and use. It he...         1
#
#                                            cleared_text  \
# 46    [like, fact, answer, accurately, n't, see, rea...
# 111     [sound, terrible, want, good, music, get, bose]
# 141                                [not, much, feature]
# 162   [stop, work, week, precede, command, really, f...
# 176                              [sad, joke, worthless]
# ...                                                 ...
# 2795  [listen, music, search, location, check, time,...
# 2796  [love, thing, run, entire, home, light, thermo...
# 2797  [complaint, sound, quality, n't, great, mostly...
# 2799                       [nice, little, unit, recall]
# 2800  [easy, set, use, help, provide, music, etc, sm...
#
#                                             clearedtext
# 46    like,fact,answer,accurately,n't,see,real,need,...
# 111             sound,terrible,want,good,music,get,bose
# 141                                    not,much,feature
# 162      stop,work,week,precede,command,really,fun,work
# 176                                  sad,joke,worthless
# ...                                                 ...
# 2795  listen,music,search,location,check,time,look,w...
# 2796  love,thing,run,entire,home,light,thermostat,fr...
# 2797  complaint,sound,quality,n't,great,mostly,use,c...
# 2799                            nice,little,unit,recall
# 2800  easy,set,use,help,provide,music,etc,small,spac...
#
# [2453 rows x 7 columns]

# %%
len(dataset['clearedtext'].unique())
# Out:
# 2044

# %%
dataset['clearedtext'].unique()
# Out:
# array(["like,fact,answer,accurately,n't,see,real,need,household,though,good,bargain,day,deal",
#        'sound,terrible,want,good,music,get,bose', 'not,much,feature', ...,
#        "complaint,sound,quality,n't,great,mostly,use,command,though,another,hook,stereo,system,play,music,couple,friends,forget,audio,quality,'re,bother,kind,thing,full,size,make,sure,hook,large,speaker",
#        'nice,little,unit,recall',
#        'easy,set,use,help,provide,music,etc,small,space,look'],
#       dtype=object)
