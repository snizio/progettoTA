# %% [markdown]
# ### Il notebook implementa un approccio non supervisionato per la classificazione e genera tramite gli embeddings pretrainati un lessico dal quale estrarre i sentiment score. La metodologia è discussa nel report.

# %%
import pandas as pd
import nltk
import numpy as np
import string
import gensim
from sklearn.pipeline import Pipeline
from preprocessing import *
from numpy import array 
from numpy import dot
from numpy.linalg import norm

# %%
from gensim.models import Word2Vec
from gensim.models.phrases import Phrases

# %%
from nltk import sent_tokenize
from nltk import pos_tag
from nltk.tokenize.treebank import TreebankWordDetokenizer
from nltk.corpus import wordnet
import re

# %%
dataset = pd.read_csv("amazon_alexa.tsv", sep = "\t", encoding = "utf-8")
print(dataset.shape)
dataset.dropna(inplace = True)
print(dataset.shape)
dataset.drop(dataset[dataset.rating == 3].index, inplace=True)
print(dataset.shape)
dataset.drop_duplicates(subset = "verified_reviews", inplace = True)
print(dataset.shape)
# Out:
# (3150, 6)
# (3150, 6)
# (2998, 6)
# (2196, 6)

# %%
w2v_model = Word2Vec.load("w2vPreTrained")

# %%
w2v_model.wv.most_similar(['love'], topn = 10)
# Out:
# [('enjoy', 0.5578348636627197),
#  ('great', 0.5526167154312134),
#  ('amaze', 0.5221312046051025),
#  ('like', 0.4955675005912781),
#  ('awesome', 0.43842583894729614),
#  ('favorite', 0.42576074600219727),
#  ('fun', 0.4234786629676819),
#  ('amazing', 0.4115583598613739),
#  ('fantastic', 0.408966600894928),
#  ('nice', 0.3966287672519684)]

# %%
w2v_model.wv.most_similar(['love'], topn = len(w2v_model.wv.vectors))[-10:] # less similar words
# Out:
# [('may', -0.3007705509662628),
#  ('not_internet', -0.3016756474971771),
#  ('not_drop', -0.30507779121398926),
#  ('hype', -0.3121069371700287),
#  ('tight', -0.31214627623558044),
#  ('not_voice', -0.3136102557182312),
#  ('crash', -0.3138749599456787),
#  ('not_ready', -0.3269640803337097),
#  ('not_sync', -0.33947843313217163),
#  ('processor', -0.37799587845802307)]

# %%
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
import statistics 
#from plotnine import *
import plotly.express as px
import plotly.graph_objects as go

from sklearn.metrics import *
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.cluster import AgglomerativeClustering
from sklearn.neighbors import kneighbors_graph
from sklearn.metrics.pairwise import cosine_similarity

from kneed import KneeLocator

from yellowbrick.cluster import KElbowVisualizer
from yellowbrick.cluster import InterclusterDistance
from yellowbrick.cluster import SilhouetteVisualizer


#distance matrix (dbscan elbow, hierarchical)
from scipy.spatial.distance import pdist, squareform
# hierarchical (scipy)
from scipy.cluster.hierarchy import linkage, dendrogram

# %%
words_wv = w2v_model.wv.index_to_key
len(words_wv)
# Out:
# 3454

# %%
# calcola SSE e Silhuette per valutare il parametro k del k-means
sse_list = []
silhouette_list = []
for k in range(2, 51):
    kmeans = KMeans(n_clusters=k, n_init=10, max_iter=300)
    kmeans.fit(w2v_model.wv.vectors)
    sse_list.append(kmeans.inertia_)
    silhouette_list.append(silhouette_score(w2v_model.wv.vectors,kmeans.labels_))

# %%
plt.plot(range(2, len(silhouette_list)+2), silhouette_list, marker='o')
plt.ylabel('Silhoutte')
plt.show()
plt.plot(range(2, len(sse_list)+2), sse_list, marker='o')
plt.ylabel('SSE')
plt.show()

# %%
kmeans = KMeans(n_clusters=5, n_init=10, max_iter=300)
kmeans.fit(w2v_model.wv.vectors)
# Out:
# KMeans(n_clusters=5)

# %%
centers=kmeans.cluster_centers_ # centroidi
labels=kmeans.labels_ # clusters labels
np.unique(labels, return_counts=True)
# Out:
# (array([0, 1, 2, 3, 4]), array([ 562,  694, 1064,  402,  732], dtype=int64))

# %%
len(centers)
# Out:
# 5

# %%
for i in centers:
    print(w2v_model.wv.most_similar(i, topn=40))
    print("####################################################")
# Out:
# [('equivalent', 0.47151029109954834), ('already', 0.43056100606918335), ('standalone', 0.3873092830181122), ('infotainment', 0.3782343566417694), ('redundant', 0.3734094500541687), ('bell_whistle', 0.3667634427547455), ('consider', 0.36130979657173157), ('membership', 0.35279521346092224), ('invest', 0.3479014039039612), ('build', 0.34558743238449097), ('comparable', 0.34545502066612244), ('tether', 0.3423275947570801), ('limited', 0.3412395715713501), ('lack', 0.3326011300086975), ('smarter', 0.3325844407081604), ('market', 0.33152034878730774), ('compete', 0.33079448342323303), ('cheap', 0.33035364747047424), ('brainer', 0.3300340473651886), ('exist', 0.32598960399627686), ('cost', 0.3253600299358368), ('affordable', 0.3249719440937042), ('ultimate', 0.3224535882472992), ('skeptical', 0.32004350423812866), ('available', 0.3198855519294739), ('transmitter', 0.3196362555027008), ('segregate', 0.3190455734729767), ('versatile', 0.31873229146003723), ('offer', 0.3185325562953949), ('volvo', 0.31679001450538635), ('provide', 0.31625494360923767), ('amplifier', 0.3142263889312744), ('carplay', 0.312502920627594), ('functionality', 0.3123215436935425), ('pay', 0.3079099655151367), ('capability', 0.30625519156455994), ('bmw', 0.3053022027015686), ('jeep_wrangler', 0.30420753359794617), ('seamless', 0.30401015281677246), ('compatibility', 0.3029758930206299)]
# ####################################################
# [('not_require', 0.5730985403060913), ('integración', 0.563129186630249), ('puedes', 0.5519153475761414), ('respuesta', 0.5462127923965454), ('not_sync', 0.5359464287757874), ('without_need', 0.5343666672706604), ('not_worry', 0.5326075553894043), ('not_user', 0.5283364057540894), ('problemas', 0.5255404710769653), ('otros', 0.5237486958503723), ('asistente', 0.5224152207374573), ('reconoce', 0.5220259428024292), ('momento', 0.5205038189888), ('not_experience', 0.5193957090377808), ('not_true', 0.5170237421989441), ('otro', 0.505799412727356), ('agrado', 0.5028115510940552), ('not_display', 0.49818769097328186), ('cuenta', 0.49410712718963623), ('hasta', 0.48881080746650696), ('celular', 0.48677361011505127), ('not_disappointed', 0.48256900906562805), ('compra', 0.48098134994506836), ('inteligente', 0.47688430547714233), ('cumple', 0.47456613183021545), ('not_let', 0.47314274311065674), ('imagen', 0.47301608324050903), ('not_return', 0.472970575094223), ('vida', 0.47295334935188293), ('not_fix', 0.471595823764801), ('regalo', 0.4705396890640259), ('not_drop', 0.46996787190437317), ('maravilla', 0.4687167704105377), ('comando', 0.4672839939594269), ('eso', 0.467180073261261), ('not_hand', 0.4653300344944), ('not_talk', 0.46414563059806824), ('puedo', 0.46259379386901855), ('not_waste', 0.4614754021167755), ('fácil', 0.46142512559890747)]
# ####################################################
# [('kid', 0.518379807472229), ('comfort', 0.4782872200012207), ('joke', 0.4573113024234772), ('mom', 0.44584497809410095), ('reminder', 0.428076833486557), ('tell', 0.4272676408290863), ('grandkids', 0.4236069619655609), ('daughter', 0.42325666546821594), ('dog', 0.4154222011566162), ('shopping_list', 0.41258522868156433), ('med', 0.4079503118991852), ('husband', 0.40746238827705383), ('buddy', 0.4070107638835907), ('dinner', 0.40638643503189087), ('medication', 0.4049158990383148), ('laugh', 0.40373528003692627), ('grandchild', 0.3979237675666809), ('bible', 0.396475225687027), ('weather', 0.39480364322662354), ('football', 0.3946520984172821), ('organize', 0.38968077301979065), ('animal', 0.3884038031101227), ('son', 0.38256171345710754), ('bed', 0.37689754366874695), ('dance', 0.3767208158969879), ('appointment', 0.37319886684417725), ('lol', 0.3696606457233429), ('friend', 0.3670501112937927), ('child', 0.3640167713165283), ('favorite', 0.3633522689342499), ('texts', 0.36317798495292664), ('headline', 0.357119619846344), ('storm', 0.35690760612487793), ('fav', 0.3536783754825592), ('ask', 0.35307860374450684), ('verbally', 0.35288429260253906), ('schedule', 0.35195058584213257), ('remind', 0.3503487706184387), ('game', 0.34977492690086365), ('covid', 0.34919124841690063)]
# ####################################################
# [('reboot', 0.5794491171836853), ('restart', 0.5687442421913147), ('reconnect', 0.5235116481781006), ('stop', 0.5224387049674988), ('reset', 0.514655590057373), ('sometimes', 0.4982225000858307), ('happen', 0.4752350449562073), ('randomly', 0.4697325527667999), ('prompt', 0.4603540301322937), ('unpaired', 0.45935502648353577), ('reconnected', 0.45327794551849365), ('freeze', 0.4515511691570282), ('offline', 0.45090386271476746), ('unplug', 0.4491095542907715), ('try', 0.44735532999038696), ('disconnect', 0.4421566128730774), ('unpair', 0.43830639123916626), ('troubleshoot', 0.43777135014533997), ('start', 0.4374411106109619), ('correct', 0.43549588322639465), ('annoy', 0.4330264627933502), ('reinstall', 0.41701802611351013), ('refuse', 0.41492021083831787), ('time', 0.41341808438301086), ('crash', 0.4132939279079437), ('ignore', 0.4106902480125427), ('delete', 0.41013777256011963), ('app', 0.4069308638572693), ('unresponsive', 0.3968167006969452), ('correctly', 0.3934767544269562), ('frustrating', 0.39311760663986206), ('issue', 0.39083555340766907), ('properly', 0.38933077454566956), ('modem', 0.3871305286884308), ('occasionally', 0.3869006335735321), ('unable', 0.3867463171482086), ('usually', 0.3866504728794098), ('trouble', 0.38490980863571167), ('redo', 0.384575217962265), ('internet', 0.3835626542568207)]
# ####################################################
# [('placement', 0.5176272392272949), ('hole', 0.4899522364139557), ('corner', 0.4801223874092102), ('cloth', 0.4719349145889282), ('cabinet', 0.46947547793388367), ('wall', 0.4468459188938141), ('tweeter', 0.44382429122924805), ('side', 0.44032588601112366), ('table', 0.4257342219352722), ('center', 0.42339983582496643), ('directional', 0.4228452444076538), ('cubby', 0.42057564854621887), ('visible', 0.41800591349601746), ('rattle', 0.41697996854782104), ('small', 0.41624191403388977), ('flat', 0.41584035754203796), ('prop', 0.41377201676368713), ('height', 0.4108949899673462), ('footprint', 0.4051891267299652), ('dashboard', 0.3996870815753937), ('rear', 0.39915066957473755), ('vibrate', 0.3985252380371094), ('place', 0.3914390206336975), ('top', 0.3907296061515808), ('shelf', 0.3878277540206909), ('punchy', 0.38534897565841675), ('bass', 0.38493725657463074), ('angle', 0.38418930768966675), ('countertop', 0.3841685950756073), ('sun', 0.3816814124584198), ('lens', 0.37873581051826477), ('large', 0.3786800801753998), ('boomy', 0.3776238262653351), ('maximum', 0.3753710091114044), ('dresser', 0.37536463141441345), ('project', 0.37364280223846436), ('furniture', 0.37133362889289856), ('surface', 0.3694210946559906), ('velcro', 0.36792778968811035), ('move', 0.3678728938102722)]
# ####################################################

# %%
df = pd.DataFrame()

# %%
print(len(w2v_model.wv["love"]))
print(len(centers[0])) # to check if the vectors have the same length
# Out:
# 100
# 100

# %%
words = []
labels = []
cos = []
for w, label in zip(words_wv, kmeans.labels_):
    # this calculates the similarity bewtween centroids and all the words in their clusters
    try:
        cos_sim = dot(w2v_model.wv[w], centers[label])/(norm(w2v_model.wv[w])*norm(centers[label])) # cosine similarity formula (dot(a, b)/norm(a)*norm(b))
    except:
        continue
    words.append(w)
    labels.append(label)
    cos.append(cos_sim)
    
df["word"] = words
df["labels"] = labels
df["cos"] = cos

print(df[df["labels"] == 1].sort_values(by = "cos", ascending = False).to_markdown()) # shows the most similar words to that cluster
# Out:
# |      | word           |   labels |        cos |
# |-----:|:---------------|---------:|-----------:|
# |  209 | kid            |        1 | 0.507033   |
# |  489 | joke           |        1 | 0.455718   |
# |   65 | tell           |        1 | 0.452636   |
# |  483 | mom            |        1 | 0.445218   |
# | 2755 | comfort        |        1 | 0.44162    |
# |  286 | reminder       |        1 | 0.437656   |
# | 1246 | grandkids      |        1 | 0.427547   |
# | 2945 | bible          |        1 | 0.41344    |
# |  510 | shopping_list  |        1 | 0.41193    |
# |  756 | dog            |        1 | 0.404975   |
# |  119 | weather        |        1 | 0.403101   |
# |  428 | daughter       |        1 | 0.402966   |
# | 2490 | animal         |        1 | 0.398813   |
# | 2785 | football       |        1 | 0.398211   |
# | 2927 | buddy          |        1 | 0.395103   |
# | 3244 | med            |        1 | 0.39211    |
# |  253 | favorite       |        1 | 0.387793   |
# | 2513 | medication     |        1 | 0.387262   |
# |  409 | husband        |        1 | 0.386061   |
# | 1770 | grandchild     |        1 | 0.385596   |
# | 1053 | dinner         |        1 | 0.385477   |
# | 3376 | fav            |        1 | 0.384141   |
# | 1712 | headline       |        1 | 0.383496   |
# | 1530 | laugh          |        1 | 0.382651   |
# |  388 | son            |        1 | 0.380261   |
# |   31 | ask            |        1 | 0.378932   |
# | 2420 | storm          |        1 | 0.373761   |
# | 1865 | organize       |        1 | 0.373511   |
# |  468 | lol            |        1 | 0.370708   |
# | 2455 | texts          |        1 | 0.368426   |
# | 1328 | dance          |        1 | 0.366262   |
# |  402 | morning        |        1 | 0.359259   |
# | 1168 | appointment    |        1 | 0.358597   |
# |  347 | game           |        1 | 0.358541   |
# | 1677 | rain           |        1 | 0.357902   |
# | 1993 | verbally       |        1 | 0.352637   |
# |  652 | remind         |        1 | 0.352213   |
# |  353 | friend         |        1 | 0.350468   |
# | 1856 | bedtime        |        1 | 0.349574   |
# |  408 | whatever       |        1 | 0.349236   |
# |  629 | bed            |        1 | 0.348068   |
# |  743 | child          |        1 | 0.345578   |
# | 1357 | granddaughter  |        1 | 0.345164   |
# | 1080 | sing           |        1 | 0.342647   |
# | 1183 | trivia         |        1 | 0.341426   |
# | 1851 | teach          |        1 | 0.340954   |
# | 1947 | grandma        |        1 | 0.338164   |
# |  700 | grocery        |        1 | 0.33639    |
# |  183 | news           |        1 | 0.336337   |
# | 1191 | baby           |        1 | 0.335886   |
# | 3265 | lunch          |        1 | 0.335017   |
# | 2657 | blah_blah      |        1 | 0.333381   |
# |  334 | playlist       |        1 | 0.333194   |
# |   25 | also           |        1 | 0.331976   |
# |  251 | timer          |        1 | 0.331445   |
# |  197 | recipe         |        1 | 0.331405   |
# | 1070 | schedule       |        1 | 0.330591   |
# |   10 | love           |        1 | 0.329647   |
# |   70 | able           |        1 | 0.328066   |
# | 2366 | flash_briefing |        1 | 0.326629   |
# | 3046 | surf           |        1 | 0.326385   |
# | 1779 | mood           |        1 | 0.324917   |
# | 2330 | peace          |        1 | 0.323644   |
# | 2931 | singer         |        1 | 0.321624   |
# | 1249 | recipes        |        1 | 0.321432   |
# | 3099 | wikipedia      |        1 | 0.320524   |
# | 2856 | dementia       |        1 | 0.320249   |
# | 2509 | boyfriend      |        1 | 0.319738   |
# | 2844 | xyz            |        1 | 0.318287   |
# | 1255 | covid          |        1 | 0.317894   |
# | 3404 | bam            |        1 | 0.316706   |
# |    2 | music          |        1 | 0.316644   |
# |  724 | shop           |        1 | 0.316281   |
# |   84 | song           |        1 | 0.316125   |
# |  326 | night          |        1 | 0.31185    |
# |   12 | play           |        1 | 0.310271   |
# | 1792 | spell          |        1 | 0.309433   |
# |  755 | info           |        1 | 0.309283   |
# |  124 | help           |        1 | 0.308857   |
# |  285 | someone        |        1 | 0.308628   |
# |  325 | cook           |        1 | 0.307516   |
# |  739 | whenever       |        1 | 0.307395   |
# |  726 | story          |        1 | 0.307037   |
# | 2739 | toddler        |        1 | 0.306898   |
# | 1568 | coffee         |        1 | 0.302155   |
# |  638 | random         |        1 | 0.30209    |
# | 2512 | homework       |        1 | 0.300994   |
# |  221 | fun            |        1 | 0.300934   |
# |  455 | sleep          |        1 | 0.300402   |
# |  129 | talk           |        1 | 0.300041   |
# | 1957 | quiz           |        1 | 0.299972   |
# |  747 | calendar       |        1 | 0.299506   |
# |  846 | traffic        |        1 | 0.298964   |
# | 3425 | samuel_jackson |        1 | 0.298741   |
# |   30 | want           |        1 | 0.29494    |
# | 2284 | accident       |        1 | 0.294594   |
# | 1263 | father         |        1 | 0.293989   |
# |  904 | announcement   |        1 | 0.292328   |
# |  696 | everyday       |        1 | 0.292096   |
# | 1805 | heart          |        1 | 0.29194    |
# | 2145 | facility       |        1 | 0.29193    |
# | 2441 | loved          |        1 | 0.29171    |
# | 1111 | brother        |        1 | 0.290166   |
# | 1566 | girl           |        1 | 0.287385   |
# |  373 | information    |        1 | 0.285543   |
# |  602 | podcasts       |        1 | 0.285307   |
# | 1133 | entertain      |        1 | 0.284234   |
# | 1275 | busy           |        1 | 0.283976   |
# |   23 | thing          |        1 | 0.283437   |
# |  719 | podcast        |        1 | 0.282685   |
# | 2833 | oldie          |        1 | 0.282327   |
# | 3424 | wash_dish      |        1 | 0.281866   |
# |  960 | dad            |        1 | 0.28156    |
# |   40 | listen         |        1 | 0.280364   |
# |  881 | conversation   |        1 | 0.280183   |
# | 1632 | nearby         |        1 | 0.279973   |
# | 2063 | jeopardy       |        1 | 0.279384   |
# | 2318 | covert         |        1 | 0.278455   |
# | 1502 | town           |        1 | 0.27656    |
# |   38 | call           |        1 | 0.276343   |
# |  661 | mother         |        1 | 0.276081   |
# | 1863 | fumble         |        1 | 0.275997   |
# | 2884 | purse          |        1 | 0.275754   |
# |  171 | list           |        1 | 0.275257   |
# | 3344 | soothe         |        1 | 0.273391   |
# |  579 | store          |        1 | 0.272768   |
# | 2365 | fart           |        1 | 0.272608   |
# | 1602 | grandson       |        1 | 0.271874   |
# | 2832 | ect            |        1 | 0.271798   |
# | 2228 | xbox           |        1 | 0.271624   |
# | 1840 | shopping       |        1 | 0.271433   |
# |  419 | message        |        1 | 0.271296   |
# | 2367 | cleaning       |        1 | 0.270485   |
# | 1817 | restaurant     |        1 | 0.269469   |
# | 2089 | whoever        |        1 | 0.269388   |
# |  458 | text           |        1 | 0.268213   |
# | 1001 | funny          |        1 | 0.267585   |
# | 1526 | relax          |        1 | 0.266712   |
# | 3354 | piano          |        1 | 0.266451   |
# | 1658 | young          |        1 | 0.265331   |
# | 3451 | jackson        |        1 | 0.265203   |
# |  318 | book           |        1 | 0.265097   |
# |  354 | christmas      |        1 | 0.264292   |
# | 2801 | maker          |        1 | 0.264258   |
# | 2035 | wan            |        1 | 0.264074   |
# |  279 | station        |        1 | 0.263652   |
# |  290 | check          |        1 | 0.262063   |
# | 2398 | popular        |        1 | 0.261991   |
# | 1670 | history        |        1 | 0.261963   |
# | 1652 | permission     |        1 | 0.260169   |
# |  175 | alarm          |        1 | 0.260123   |
# | 3267 | aunt           |        1 | 0.259638   |
# | 3036 | rider          |        1 | 0.259634   |
# | 2147 | alexis         |        1 | 0.258125   |
# | 1891 | inform         |        1 | 0.258017   |
# | 3020 | spouse         |        1 | 0.257785   |
# | 1006 | record         |        1 | 0.257645   |
# | 2277 | weekend        |        1 | 0.257638   |
# |  241 | name           |        1 | 0.256812   |
# | 3054 | brown          |        1 | 0.255762   |
# |  446 | forget         |        1 | 0.255529   |
# | 1160 | school         |        1 | 0.254665   |
# | 1204 | neighbor       |        1 | 0.254382   |
# | 3291 | anniversary    |        1 | 0.254317   |
# | 1179 | audiobooks     |        1 | 0.254169   |
# |  128 | etc            |        1 | 0.252128   |
# | 1673 | pet            |        1 | 0.251839   |
# |  198 | hand_free      |        1 | 0.251782   |
# | 2586 | niece          |        1 | 0.250077   |
# | 3067 | ignition       |        1 | 0.249797   |
# |  605 | channel        |        1 | 0.249675   |
# | 2829 | karaoke        |        1 | 0.249415   |
# |  439 | hand           |        1 | 0.249052   |
# | 1542 | senior         |        1 | 0.248586   |
# | 1600 | hundred        |        1 | 0.248442   |
# | 1784 | awake          |        1 | 0.248011   |
# | 3026 | cart           |        1 | 0.247962   |
# | 2656 | john           |        1 | 0.247905   |
# | 2249 | vacation       |        1 | 0.247678   |
# |  505 | course         |        1 | 0.247631   |
# |  479 | notification   |        1 | 0.247403   |
# | 1892 | chore          |        1 | 0.246902   |
# | 2192 | photos         |        1 | 0.246598   |
# |  803 | email          |        1 | 0.24636    |
# |  923 | library        |        1 | 0.246198   |
# |  188 | direction      |        1 | 0.246115   |
# | 1621 | pandemic       |        1 | 0.245466   |
# |  741 | communicate    |        1 | 0.245392   |
# | 2402 | advance        |        1 | 0.245114   |
# | 3125 | allows         |        1 | 0.245064   |
# | 3160 | dress          |        1 | 0.24424    |
# |  282 | wife           |        1 | 0.243978   |
# | 1489 | score          |        1 | 0.243948   |
# |  835 | lyric          |        1 | 0.243637   |
# | 2514 | tonight        |        1 | 0.243528   |
# | 2486 | ingredient     |        1 | 0.241611   |
# | 3107 | opera          |        1 | 0.241532   |
# | 2784 | milk           |        1 | 0.241056   |
# |   97 | something      |        1 | 0.240931   |
# |  157 | anything       |        1 | 0.240091   |
# | 1713 | saver          |        1 | 0.239773   |
# | 2726 | polite         |        1 | 0.239654   |
# | 2683 | iheartradio    |        1 | 0.239511   |
# | 1640 | bore           |        1 | 0.239267   |
# | 2976 | meanwhile      |        1 | 0.238438   |
# | 1417 | brief          |        1 | 0.238391   |
# | 1046 | alex           |        1 | 0.238363   |
# | 2493 | ocean          |        1 | 0.238177   |
# | 2110 | importantly    |        1 | 0.238124   |
# |  999 | visit          |        1 | 0.237957   |
# | 1815 | emergency      |        1 | 0.237901   |
# | 1992 | study          |        1 | 0.237837   |
# | 2920 | private        |        1 | 0.237436   |
# | 1061 | cooking        |        1 | 0.236922   |
# | 1423 | cat            |        1 | 0.236869   |
# | 1281 | classical      |        1 | 0.236688   |
# |  110 | question       |        1 | 0.236547   |
# | 3243 | approve        |        1 | 0.235876   |
# | 1117 | event          |        1 | 0.235852   |
# |  429 | routine        |        1 | 0.235147   |
# | 1535 | audiobook      |        1 | 0.234811   |
# | 2182 | incoming       |        1 | 0.2343     |
# |  117 | drive          |        1 | 0.234163   |
# |  984 | sister         |        1 | 0.234157   |
# | 1462 | memory         |        1 | 0.233995   |
# | 2304 | briefing       |        1 | 0.233966   |
# | 1304 | wherever       |        1 | 0.233719   |
# | 3121 | skills         |        1 | 0.23337    |
# | 2158 | smile          |        1 | 0.232974   |
# | 3319 | resource       |        1 | 0.23244    |
# |  532 | program        |        1 | 0.23233    |
# | 2962 | puppy          |        1 | 0.231998   |
# |   69 | know           |        1 | 0.231748   |
# | 2090 | calm           |        1 | 0.231666   |
# |  375 | person         |        1 | 0.231511   |
# | 1196 | forecast       |        1 | 0.230029   |
# |  520 | number         |        1 | 0.230001   |
# | 3162 | supervisor     |        1 | 0.229635   |
# | 1622 | npr            |        1 | 0.229555   |
# | 3176 | songs          |        1 | 0.229124   |
# | 2635 | ella           |        1 | 0.228152   |
# | 1931 | evening        |        1 | 0.228126   |
# |  521 | everyone       |        1 | 0.228116   |
# | 3135 | scene          |        1 | 0.227538   |
# | 2895 | grandmother    |        1 | 0.227241   |
# |   81 | video          |        1 | 0.227024   |
# |  146 | drop           |        1 | 0.227005   |
# |  233 | let            |        1 | 0.226492   |
# | 3391 | fox            |        1 | 0.226445   |
# | 1087 | business       |        1 | 0.226171   |
# |  320 | skill          |        1 | 0.22607    |
# | 3226 | hospital       |        1 | 0.226011   |
# |  145 | answer         |        1 | 0.225104   |
# |  495 | computer       |        1 | 0.224489   |
# | 3011 | lesson         |        1 | 0.22305    |
# | 1591 | fabulous       |        1 | 0.222641   |
# | 3302 | sick           |        1 | 0.222382   |
# |  571 | temperature    |        1 | 0.221984   |
# |  287 | fact           |        1 | 0.221913   |
# | 2830 | discuss        |        1 | 0.221908   |
# | 1481 | destination    |        1 | 0.221616   |
# |  390 | stuff          |        1 | 0.220858   |
# | 1042 | safe           |        1 | 0.219814   |
# |  142 | family         |        1 | 0.218763   |
# | 2571 | dismiss        |        1 | 0.217782   |
# |  830 | alert          |        1 | 0.217403   |
# |  987 | birthday       |        1 | 0.217117   |
# |  985 | commute        |        1 | 0.217037   |
# |  699 | tune           |        1 | 0.216073   |
# |   61 | day            |        1 | 0.215609   |
# | 1071 | upstairs       |        1 | 0.215459   |
# | 3190 | xxx            |        1 | 0.215425   |
# | 2349 | season         |        1 | 0.213639   |
# |  471 | daily          |        1 | 0.213377   |
# | 1103 | somewhere      |        1 | 0.211907   |
# |  125 | enjoy          |        1 | 0.211846   |
# |  626 | pop            |        1 | 0.211019   |
# | 1656 | asleep         |        1 | 0.210684   |
# | 1169 | driveway       |        1 | 0.210665   |
# | 2660 | habit          |        1 | 0.210475   |
# | 1541 | guest          |        1 | 0.210035   |
# |  676 | bathroom       |        1 | 0.209823   |
# | 1604 | count          |        1 | 0.209278   |
# | 2810 | alive          |        1 | 0.208743   |
# | 2598 | measurement    |        1 | 0.20842    |
# |  299 | hour           |        1 | 0.206992   |
# | 3418 | texas          |        1 | 0.206434   |
# | 2883 | telephone      |        1 | 0.205756   |
# |   55 | light          |        1 | 0.204885   |
# | 1035 | lamp           |        1 | 0.204804   |
# | 3044 | visitor        |        1 | 0.204668   |
# | 1055 | catch          |        1 | 0.204634   |
# |  494 | outside        |        1 | 0.204498   |
# | 2991 | asset          |        1 | 0.204293   |
# | 3277 | needle         |        1 | 0.204232   |
# | 3239 | medical        |        1 | 0.204142   |
# | 1381 | pocket         |        1 | 0.20355    |
# |  372 | road           |        1 | 0.203474   |
# | 2627 | tan            |        1 | 0.203434   |
# |  507 | ready          |        1 | 0.203011   |
# | 3139 | whats          |        1 | 0.201859   |
# | 3193 | dryer          |        1 | 0.201542   |
# |  523 | mind           |        1 | 0.201408   |
# |  926 | tip            |        1 | 0.201245   |
# |  109 | radio          |        1 | 0.201132   |
# | 2702 | spam           |        1 | 0.201069   |
# | 1692 | endless        |        1 | 0.200829   |
# | 2978 | santa          |        1 | 0.200081   |
# | 1317 | yesterday      |        1 | 0.200053   |
# | 2123 | laundry        |        1 | 0.200026   |
# | 2112 | math           |        1 | 0.199073   |
# | 1105 | country        |        1 | 0.198915   |
# | 2409 | relationship   |        1 | 0.198776   |
# |  977 | law            |        1 | 0.198595   |
# | 2546 | everybody      |        1 | 0.19819    |
# | 1645 | ups            |        1 | 0.197882   |
# | 1969 | haha           |        1 | 0.197759   |
# | 2802 | hmm            |        1 | 0.197677   |
# | 1833 | nature         |        1 | 0.196591   |
# | 1518 | heck           |        1 | 0.196489   |
# | 2382 | meal           |        1 | 0.196001   |
# | 1222 | guard          |        1 | 0.195969   |
# | 2936 | trek           |        1 | 0.195897   |
# | 1601 | episode        |        1 | 0.195786   |
# | 3081 | inquiry        |        1 | 0.194419   |
# | 2159 | meditation     |        1 | 0.194348   |
# | 1424 | companion      |        1 | 0.193853   |
# |  213 | learn          |        1 | 0.193532   |
# | 2412 | approach       |        1 | 0.193442   |
# | 2614 | tired          |        1 | 0.193157   |
# | 1758 | broadcast      |        1 | 0.19257    |
# | 2232 | dirty          |        1 | 0.192398   |
# |  797 | parent         |        1 | 0.192116   |
# | 2543 | risk           |        1 | 0.19182    |
# | 2938 | rap            |        1 | 0.191714   |
# |  492 | convenient     |        1 | 0.191676   |
# | 2254 | reassure       |        1 | 0.191511   |
# | 3396 | drown          |        1 | 0.191441   |
# | 1990 | street         |        1 | 0.191095   |
# | 1326 | english        |        1 | 0.18998    |
# | 1924 | virtually      |        1 | 0.18982    |
# |  250 | photo          |        1 | 0.189703   |
# |  714 | report         |        1 | 0.189414   |
# | 3105 | yay            |        1 | 0.188935   |
# | 2733 | perk           |        1 | 0.188715   |
# | 2325 | upcoming       |        1 | 0.188468   |
# | 3408 | ins            |        1 | 0.188012   |
# | 2265 | treat          |        1 | 0.187706   |
# | 1398 | notify         |        1 | 0.18721    |
# | 1335 | ride           |        1 | 0.187115   |
# | 1880 | reading        |        1 | 0.185951   |
# | 1098 | food           |        1 | 0.185757   |
# | 2413 | unbelievable   |        1 | 0.185435   |
# | 1286 | customize      |        1 | 0.184933   |
# |  805 | navigate       |        1 | 0.184878   |
# | 2096 | woman          |        1 | 0.184532   |
# | 3381 | bbc            |        1 | 0.184453   |
# |   95 | keep           |        1 | 0.183702   |
# | 1634 | blind          |        1 | 0.183541   |
# | 3158 | puzzle         |        1 | 0.183537   |
# | 1777 | dream          |        1 | 0.182397   |
# | 1724 | damn           |        1 | 0.181461   |
# | 1077 | genre          |        1 | 0.180598   |
# | 2141 | joy            |        1 | 0.179923   |
# | 1512 | meeting        |        1 | 0.179811   |
# | 2768 | march          |        1 | 0.178846   |
# | 1170 | shuffle        |        1 | 0.17883    |
# | 3060 | dear           |        1 | 0.178521   |
# | 3334 | chill          |        1 | 0.178196   |
# | 3332 | ditch          |        1 | 0.177646   |
# | 2458 | hip            |        1 | 0.177529   |
# | 2332 | hubby          |        1 | 0.177377   |
# | 3290 | praise         |        1 | 0.176842   |
# | 2306 | tomorrow       |        1 | 0.176762   |
# | 3247 | hmmm           |        1 | 0.176324   |
# |  234 | live           |        1 | 0.176073   |
# |  933 | special        |        1 | 0.176041   |
# | 1356 | driving        |        1 | 0.175858   |
# |  896 | travel         |        1 | 0.175288   |
# |  319 | movie          |        1 | 0.17489    |
# | 2887 | cassette       |        1 | 0.174761   |
# |  784 | artist         |        1 | 0.174157   |
# |  959 | local          |        1 | 0.173811   |
# |  980 | machine        |        1 | 0.173385   |
# |  568 | trip           |        1 | 0.173305   |
# |  516 | audible        |        1 | 0.173094   |
# | 2078 | girlfriend     |        1 | 0.172718   |
# | 2383 | convert        |        1 | 0.172156   |
# | 3412 | let_go_of      |        1 | 0.171892   |
# | 2221 | partner        |        1 | 0.171692   |
# | 1861 | shot           |        1 | 0.171491   |
# | 1151 | temp           |        1 | 0.171108   |
# | 2049 | somebody       |        1 | 0.170817   |
# |  493 | garage         |        1 | 0.170429   |
# | 2217 | brain          |        1 | 0.169467   |
# | 2464 | nursing        |        1 | 0.168685   |
# | 1691 | instant        |        1 | 0.168649   |
# | 2335 | hello          |        1 | 0.168566   |
# | 3024 | backseat       |        1 | 0.168485   |
# |   63 | feature        |        1 | 0.168441   |
# |  501 | chat           |        1 | 0.16837    |
# |  560 | everywhere     |        1 | 0.168089   |
# | 2902 | blah           |        1 | 0.168057   |
# |  734 | date           |        1 | 0.167847   |
# | 1264 | dumb           |        1 | 0.167773   |
# | 2403 | sample         |        1 | 0.166879   |
# |  968 | tool           |        1 | 0.166429   |
# | 1730 | train          |        1 | 0.16636    |
# | 3385 | aka            |        1 | 0.166294   |
# |  718 | album          |        1 | 0.16615    |
# | 3228 | mercedes       |        1 | 0.166035   |
# | 1174 | downstairs     |        1 | 0.165532   |
# |  312 | ability        |        1 | 0.164871   |
# | 2616 | ipod           |        1 | 0.16483    |
# | 2039 | interactive    |        1 | 0.164569   |
# | 2818 | escape         |        1 | 0.163664   |
# | 2196 | exercise       |        1 | 0.163504   |
# | 1504 | assistance     |        1 | 0.163501   |
# | 2375 | glance         |        1 | 0.162542   |
# | 1890 | art            |        1 | 0.162008   |
# |  564 | pandora        |        1 | 0.161327   |
# | 2320 | female         |        1 | 0.16095    |
# | 1431 | anytime        |        1 | 0.160484   |
# |  147 | long           |        1 | 0.16041    |
# | 3434 | beware         |        1 | 0.159875   |
# | 1359 | usual          |        1 | 0.159691   |
# | 1734 | ziggy          |        1 | 0.159171   |
# | 2973 | translate      |        1 | 0.159021   |
# | 2368 | safer          |        1 | 0.159018   |
# | 1528 | wheel          |        1 | 0.158846   |
# | 2621 | browse         |        1 | 0.158826   |
# | 2899 | monday         |        1 | 0.158641   |
# |   87 | kitchen        |        1 | 0.157533   |
# | 1373 | demand         |        1 | 0.157468   |
# | 1456 | route          |        1 | 0.157439   |
# |  753 | convenience    |        1 | 0.15708    |
# | 1031 | mile           |        1 | 0.156434   |
# | 1946 | visually       |        1 | 0.156151   |
# | 2688 | instrumental   |        1 | 0.155453   |
# | 1820 | comfortable    |        1 | 0.15543    |
# | 1589 | print          |        1 | 0.15492    |
# | 1795 | flip           |        1 | 0.154862   |
# | 1310 | water          |        1 | 0.154337   |
# | 1478 | file           |        1 | 0.15428    |
# | 3329 | locally        |        1 | 0.154036   |
# | 1981 | recording      |        1 | 0.153926   |
# | 3214 | vibe           |        1 | 0.153432   |
# | 1909 | relative       |        1 | 0.153161   |
# |  641 | member         |        1 | 0.153154   |
# | 3218 | refresh        |        1 | 0.15308    |
# | 2198 | lover          |        1 | 0.152946   |
# | 2791 | roommate       |        1 | 0.152822   |
# | 3101 | nervous        |        1 | 0.152747   |
# | 1829 | safety         |        1 | 0.152575   |
# |  362 | cell           |        1 | 0.152138   |
# | 1783 | custom         |        1 | 0.151922   |
# |  166 | without        |        1 | 0.151705   |
# | 3003 | amuse          |        1 | 0.151499   |
# | 2252 | soooo          |        1 | 0.151372   |
# | 3216 | mail           |        1 | 0.151063   |
# |  511 | handy          |        1 | 0.150943   |
# | 2113 | dish           |        1 | 0.150752   |
# | 1394 | title          |        1 | 0.150521   |
# | 3031 | bath           |        1 | 0.150343   |
# |  649 | literally      |        1 | 0.150217   |
# | 3072 | wash           |        1 | 0.149488   |
# | 1188 | language       |        1 | 0.149174   |
# | 1782 | videos         |        1 | 0.148929   |
# |  122 | around         |        1 | 0.148716   |
# | 2060 | rush           |        1 | 0.148025   |
# | 1412 | interesting    |        1 | 0.147724   |
# | 2773 | host           |        1 | 0.146928   |
# | 2917 | intelligence   |        1 | 0.146563   |
# | 1427 | loop           |        1 | 0.146497   |
# | 1725 | possibility    |        1 | 0.145434   |
# | 1570 | city           |        1 | 0.145179   |
# | 1737 | easier         |        1 | 0.144885   |
# |  986 | intercom       |        1 | 0.144838   |
# | 2680 | soundtrack     |        1 | 0.144621   |
# | 3448 | sided_tape     |        1 | 0.144378   |
# |   24 | make           |        1 | 0.143907   |
# | 1130 | delivery       |        1 | 0.143824   |
# | 3400 | rental         |        1 | 0.143608   |
# | 1810 | clue           |        1 | 0.143425   |
# | 1764 | jam            |        1 | 0.143339   |
# | 2138 | manner         |        1 | 0.143252   |
# | 1256 | accent         |        1 | 0.143129   |
# | 2916 | hair           |        1 | 0.142846   |
# | 2855 | conference     |        1 | 0.142512   |
# | 2926 | generic        |        1 | 0.142404   |
# |  358 | helpful        |        1 | 0.142394   |
# | 2700 | cnn            |        1 | 0.142157   |
# | 3086 | doctor         |        1 | 0.14191    |
# | 2691 | net            |        1 | 0.141505   |
# | 1962 | texting        |        1 | 0.140987   |
# |  589 | totally        |        1 | 0.140929   |
# |  971 | thru           |        1 | 0.140552   |
# | 2099 | better         |        1 | 0.140483   |
# | 2629 | bank           |        1 | 0.139748   |
# |  761 | skip           |        1 | 0.139331   |
# | 2570 | nobody         |        1 | 0.139043   |
# | 2168 | bake           |        1 | 0.138663   |
# | 1612 | adult          |        1 | 0.138532   |
# |  623 | package        |        1 | 0.138007   |
# | 3252 | aloud          |        1 | 0.137965   |
# | 1942 | vacuum         |        1 | 0.137593   |
# | 2968 | caller         |        1 | 0.137486   |
# | 1605 | eat            |        1 | 0.137191   |
# | 2626 | addict         |        1 | 0.136964   |
# |  983 | scroll         |        1 | 0.136777   |
# | 2016 | xmas           |        1 | 0.135829   |
# | 2439 | stair          |        1 | 0.135646   |
# |  945 | gps            |        1 | 0.135602   |
# | 2362 | grant          |        1 | 0.135463   |
# | 3278 | messenger      |        1 | 0.134889   |
# | 2091 | breakfast      |        1 | 0.134262   |
# | 1219 | elderly        |        1 | 0.133914   |
# | 2241 | concert        |        1 | 0.133306   |
# | 2468 | cue            |        1 | 0.132895   |
# | 2351 | protect        |        1 | 0.131651   |
# |   46 | could          |        1 | 0.131522   |
# | 3084 | bing           |        1 | 0.13128    |
# | 2896 | cousin         |        1 | 0.131106   |
# |  671 | gadget         |        1 | 0.131071   |
# | 2427 | behold         |        1 | 0.130828   |
# | 2496 | nissan         |        1 | 0.130372   |
# | 2214 | feeling        |        1 | 0.130367   |
# | 2434 | pitch          |        1 | 0.129909   |
# | 2347 | nut            |        1 | 0.129857   |
# |  459 | idea           |        1 | 0.129788   |
# | 3093 | social         |        1 | 0.128487   |
# | 2540 | query          |        1 | 0.12838    |
# | 1773 | till           |        1 | 0.128362   |
# |  100 | lot            |        1 | 0.128225   |
# |   58 | way            |        1 | 0.128108   |
# | 1295 | bell           |        1 | 0.127812   |
# | 1213 | slide          |        1 | 0.126859   |
# | 1802 | aid            |        1 | 0.126726   |
# |  131 | away           |        1 | 0.126002   |
# | 2079 | grandparent    |        1 | 0.125976   |
# |  111 | year           |        1 | 0.125772   |
# |  216 | gift           |        1 | 0.125455   |
# | 3356 | algorithm      |        1 | 0.125348   |
# | 1710 | didnt          |        1 | 0.1253     |
# |  206 | item           |        1 | 0.124493   |
# | 2781 | dodge          |        1 | 0.124481   |
# |  855 | announce       |        1 | 0.124447   |
# | 1197 | instantly      |        1 | 0.124295   |
# |  512 | immediately    |        1 | 0.124118   |
# |  818 | moment         |        1 | 0.123548   |
# | 2701 | november       |        1 | 0.123078   |
# |  543 | background     |        1 | 0.123062   |
# | 3130 | lifesaver      |        1 | 0.122085   |
# |  133 | watch          |        1 | 0.122059   |
# | 1192 | bunch          |        1 | 0.12136    |
# | 1635 | initiate       |        1 | 0.121286   |
# |  760 | zoom           |        1 | 0.120143   |
# |    7 | like           |        1 | 0.120087   |
# | 1372 | shower         |        1 | 0.118494   |
# |   88 | everything     |        1 | 0.118197   |
# | 2618 | broken         |        1 | 0.118129   |
# | 3167 | watching       |        1 | 0.117131   |
# | 1327 | interest       |        1 | 0.117105   |
# |   54 | see            |        1 | 0.116891   |
# |  908 | ton            |        1 | 0.116418   |
# | 1016 | cant           |        1 | 0.1162     |
# | 2591 | practical      |        1 | 0.116026   |
# |   18 | show           |        1 | 0.115786   |
# | 1245 | basement       |        1 | 0.115785   |
# | 1397 | gas            |        1 | 0.11572    |
# | 2840 | errand         |        1 | 0.115486   |
# |  386 | anyone         |        1 | 0.115207   |
# | 2507 | omg            |        1 | 0.115038   |
# | 2076 | slideshow      |        1 | 0.115037   |
# | 3188 | gym            |        1 | 0.114653   |
# | 2338 | plex           |        1 | 0.114414   |
# | 1870 | learning       |        1 | 0.114153   |
# |  793 | digital        |        1 | 0.114102   |
# |  593 | state          |        1 | 0.113972   |
# |  267 | ever           |        1 | 0.113435   |
# | 1639 | changer        |        1 | 0.113375   |
# |  153 | order          |        1 | 0.113072   |
# | 2354 | understands    |        1 | 0.112293   |
# | 2711 | devoice        |        1 | 0.112064   |
# | 3057 | cry            |        1 | 0.111161   |
# | 3254 | yelling        |        1 | 0.110841   |
# |   34 | need           |        1 | 0.110624   |
# | 1148 | commercial     |        1 | 0.109958   |
# |  769 | imagine        |        1 | 0.109816   |
# | 1365 | boy            |        1 | 0.109456   |
# |  112 | many           |        1 | 0.109357   |
# | 2323 | lil            |        1 | 0.109142   |
# | 3022 | scale          |        1 | 0.109087   |
# | 3047 | sooo           |        1 | 0.108338   |
# | 2423 | put_option     |        1 | 0.108045   |
# | 2069 | wear           |        1 | 0.107951   |
# | 1949 | classic        |        1 | 0.107906   |
# | 1079 | laptop         |        1 | 0.10668    |
# |  893 | hey            |        1 | 0.106475   |
# |  944 | alot           |        1 | 0.10549    |
# |  780 | listening      |        1 | 0.105459   |
# | 1271 | folk           |        1 | 0.104452   |
# | 1881 | iheart         |        1 | 0.103596   |
# |  938 | act            |        1 | 0.103084   |
# |  842 | anymore        |        1 | 0.102716   |
# | 2720 | revise         |        1 | 0.102696   |
# |  302 | door           |        1 | 0.102428   |
# | 3208 | screensaver    |        1 | 0.102092   |
# |  378 | touch          |        1 | 0.101617   |
# | 3016 | roomba         |        1 | 0.100969   |
# |  616 | task           |        1 | 0.100406   |
# |   62 | house          |        1 | 0.100393   |
# | 1438 | thrill         |        1 | 0.100208   |
# |  445 | throughout     |        1 | 0.100203   |
# | 1920 | ten            |        1 | 0.100018   |
# |  565 | clearly        |        1 | 0.0992675  |
# | 2408 | headset        |        1 | 0.098798   |
# | 2698 | disarm         |        1 | 0.0982791  |
# |  572 | playing        |        1 | 0.0975833  |
# | 1176 | enjoyable      |        1 | 0.0967839  |
# | 3273 | kudos          |        1 | 0.0958453  |
# | 1393 | holiday        |        1 | 0.0956553  |
# |  196 | word           |        1 | 0.0951775  |
# | 3027 | bound          |        1 | 0.0950107  |
# | 2188 | heater         |        1 | 0.0949075  |
# |  862 | present        |        1 | 0.0948272  |
# |  838 | waze           |        1 | 0.0945834  |
# | 1910 | definition     |        1 | 0.0944886  |
# | 1350 | activity       |        1 | 0.0944434  |
# | 2862 | ons            |        1 | 0.0942108  |
# |  549 | alone          |        1 | 0.0938981  |
# | 2210 | anybody        |        1 | 0.0934101  |
# |   41 | even           |        1 | 0.0922066  |
# | 1290 | toy            |        1 | 0.0903734  |
# |    8 | one            |        1 | 0.0897438  |
# | 1822 | magic          |        1 | 0.088911   |
# | 1834 | lazy           |        1 | 0.0879036  |
# | 1217 | crap           |        1 | 0.085974   |
# |  432 | map            |        1 | 0.0854129  |
# | 2809 | craft          |        1 | 0.0853868  |
# | 1875 | lightbulb      |        1 | 0.0840127  |
# |  774 | tap            |        1 | 0.0837073  |
# | 2451 | tough          |        1 | 0.0835259  |
# | 1073 | man            |        1 | 0.083119   |
# | 3071 | scary          |        1 | 0.0830084  |
# | 1401 | penny          |        1 | 0.0827708  |
# |  368 | yes            |        1 | 0.0825433  |
# |  342 | mine           |        1 | 0.0825255  |
# | 3108 | fixed          |        1 | 0.0823877  |
# | 1506 | pic            |        1 | 0.0816307  |
# | 1418 | feed           |        1 | 0.0815548  |
# | 3025 | overnight      |        1 | 0.0812129  |
# |  867 | interact       |        1 | 0.080947   |
# | 2384 | era            |        1 | 0.0799388  |
# | 2238 | assisted       |        1 | 0.0796178  |
# |  460 | bring          |        1 | 0.0793412  |
# | 3197 | capacity       |        1 | 0.07925    |
# |  374 | kind           |        1 | 0.0780819  |
# | 2762 | detailed       |        1 | 0.0770307  |
# | 1225 | cam            |        1 | 0.0767526  |
# | 2715 | thermometer    |        1 | 0.0761497  |
# |  170 | read           |        1 | 0.075499   |
# | 1273 | trick          |        1 | 0.0753382  |
# |  998 | alexas         |        1 | 0.0748515  |
# | 2288 | florida        |        1 | 0.0742464  |
# | 1854 | status         |        1 | 0.0724035  |
# |  947 | handle         |        1 | 0.0714788  |
# | 1523 | crystal        |        1 | 0.0713901  |
# |   47 | voice          |        1 | 0.0706686  |
# |  453 | office         |        1 | 0.0701253  |
# |  934 | chance         |        1 | 0.0682585  |
# | 2559 | helper         |        1 | 0.0681434  |
# | 2811 | fingertip      |        1 | 0.0663217  |
# |  174 | picture        |        1 | 0.0662423  |
# | 1435 | pod            |        1 | 0.0658801  |
# | 1329 | yeah           |        1 | 0.0640683  |
# | 3241 | promptly       |        1 | 0.0619348  |
# |  307 | absolutely     |        1 | 0.0613835  |
# | 2495 | yellow         |        1 | 0.060186   |
# | 1360 | dial           |        1 | 0.0570979  |
# |  421 | load           |        1 | 0.0570112  |
# | 2912 | tempt          |        1 | 0.0569015  |
# | 1107 | explore        |        1 | 0.0551507  |
# | 2024 | shipping       |        1 | 0.0533046  |
# |  463 | doorbell       |        1 | 0.0529351  |
# |  574 | near           |        1 | 0.0524319  |
# |  224 | almost         |        1 | 0.0503881  |
# |  730 | thermostat     |        1 | 0.0467298  |
# | 3298 | dang           |        1 | 0.0453661  |
# |  796 | dont           |        1 | 0.0448229  |
# | 1884 | charm          |        1 | 0.0379261  |
# | 2999 | champ          |        1 | 0.01986    |
# | 3106 | exceptionally  |        1 | 0.0142286  |
# |  278 | super          |        1 | 0.00751855 |

# %%
from sklearn.manifold import TSNE

# %%
# dimensionality reduction a 3 dimensioni per plottare
tsne = TSNE(3, learning_rate="auto", metric="cosine")
tokens_list = []
for vec in w2v_model.wv.vectors:
    tokens_list.append(vec)

# %%
new_val = tsne.fit_transform(np.array(tokens_list))
# Out:
# c:\Users\crist\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(

# %%
df["x"] = [x[0] for x in new_val]
df["y"] = [x[1] for x in new_val]
df["z"] = [x[2] for x in new_val]

# %%
import seaborn as sns

# %%
sns.scatterplot(data = df, x = "x", y = "y", hue = "labels")
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
import plotly_express as px

# %%
px.scatter_3d(data_frame = df, x = "x", y = "y", z = "z", hover_name = "word")

# %%
# distance_matrix = pairwise_distances(vectors, vectors, metric = "cosine")
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster

l = linkage(w2v_model.wv.vectors, method='ward', metric='euclidean')

# calculate full dendrogram
plt.figure(figsize=(25, 15))
plt.title('Hierarchical Clustering Dendrogram')
plt.ylabel('word')
plt.xlabel('distance')

dendrogram(
    l,
    leaf_rotation=75.,  # rotates the x axis labels
    leaf_font_size=3.,  # font size for the x axis labels
    leaf_label_func=lambda v: str(w2v_model.wv.index_to_key[v])
)
plt.show()

# %%
hier_df = pd.DataFrame()

hier_labels = fcluster(l, 6, "maxclust")
hier_df["labels"] = hier_labels

hier_df["x"] = df["x"]
hier_df["y"] = df["y"]
hier_df["z"] = df["z"]
hier_df["word"] = df["word"]
print(hier_df[hier_df["labels"] == 1].to_markdown())
# Out:
# |      |   labels |          x |          y |           z | word              |
# |-----:|---------:|-----------:|-----------:|------------:|:------------------|
# |  344 |        1 | -40.7885   |  11.419    |   5.89392   | not_sure          |
# |  490 |        1 | -43.2869   |   8.11955  | -13.1583    | not_work          |
# |  551 |        1 | -46.5358   |  18.4788   |   6.92923   | not_use           |
# |  624 |        1 | -45.2141   |  10.5674   |   5.453     | not_good          |
# |  787 |        1 | -50.4672   |  16.3511   |   3.30789   | not_able          |
# |  791 |        1 | -35.7665   |  17.5024   |  -4.34035   | not_get           |
# |  814 |        1 | -41.3177   |  14.2585   |   0.936869  | not_connect       |
# |  817 |        1 | -32.1884   |   8.66648  | -13.3293    | not_much          |
# |  832 |        1 | -47.7177   |  16.3504   |   8.09089   | not_like          |
# |  850 |        1 | -37.7263   |  27.5341   |   3.55174   | not_great         |
# |  912 |        1 | -50.0888   |  19.7914   |   5.19265   | not_really        |
# |  941 |        1 | -37.7209   |  13.5036   |   5.68317   | not_worth         |
# |  948 |        1 | -31.1814   |  12.1142   | -13.5115    | not_big           |
# |  979 |        1 | -34.6643   |  11.1121   |  -0.488242  | not_even          |
# |  989 |        1 | -37.5296   |  17.5134   |  10.0398    | not_hear          |
# | 1018 |        1 | -33.7756   |   0.977829 |  -4.8128    | not_bad           |
# | 1056 |        1 | -36.9428   |   5.9082   |   1.47825   | not_need          |
# | 1067 |        1 | -50.4826   |   6.57396  |   1.34543   | not_play          |
# | 1082 |        1 | -32.946    |  21.6414   | -17.6532    | not_want          |
# | 1095 |        1 | -30.9949   |   6.41683  |  -3.9772    | not_always        |
# | 1113 |        1 | -47.2603   |  23.1235   |  -0.538526  | not_bluetooth     |
# | 1156 |        1 | -36.0734   |  18.9155   |   8.18075   | not_respond       |
# | 1226 |        1 | -45.3947   |  19.3876   |   4.01251   | not_understand    |
# | 1244 |        1 | -33.4226   |   6.75938  |  -6.4906    | not_buy           |
# | 1253 |        1 | -42.9987   |  19.8416   | -11.0187    | not_one           |
# | 1262 |        1 | -33.1603   |  19.7016   |   4.07695   | not_know          |
# | 1268 |        1 | -53.2705   |  14.38     |  -3.04921   | not_quite         |
# | 1289 |        1 | -25.1212   |  23.471    |  -5.33257   | not_mention       |
# | 1349 |        1 | -43.0775   |  24.8111   |   6.79342   | not_perfect       |
# | 1355 |        1 | -29.6399   |  20.0645   |   0.65429   | not_find          |
# | 1395 |        1 | -42.5281   |  16.6049   |   6.58094   | not_listen        |
# | 1408 |        1 | -41.9844   |  14.6497   |  -3.77107   | not_problem       |
# | 1446 |        1 | -37.2832   |  14.5589   | -12.3607    | not_recognize     |
# | 1465 |        1 | -42.1963   |  20.4861   |   5.99965   | not_recommend     |
# | 1479 |        1 | -50.0211   |  13.0537   |   2.59007   | not_issue         |
# | 1496 |        1 | -28.3637   |  11.7924   | -10.4608    | not_enough        |
# | 1503 |        1 | -41.4898   |   3.49466  |  -3.53846   | not_sound         |
# | 1511 |        1 | -27.9303   |  12.8673   |   0.0822617 | not_give          |
# | 1517 |        1 | -45.5968   |  21.4827   |   9.39862   | not_disappoint    |
# | 1572 |        1 | -52.5087   |  14.1054   |   3.13778   | without_issue     |
# | 1594 |        1 | -29.7794   |  17.7218   |  -6.86894   | not_happy         |
# | 1597 |        1 | -31.4978   |   6.18535  | -14.7478    | form              |
# | 1615 |        1 | -47.6555   |  15.4249   |  -9.30351   | not_make          |
# | 1616 |        1 | -37.6015   |   9.02045  |  -0.123031  | not_device        |
# | 1637 |        1 | -37.8661   |  15.7804   |  -1.54402   | not_compatible    |
# | 1676 |        1 | -37.1059   |  25.809    |   1.75279   | not_see           |
# | 1700 |        1 | -41.8654   |   8.66935  |  -3.38642   | not_turn          |
# | 1711 |        1 | -35.1622   |  17.1169   |  -9.82352   | not_show          |
# | 1716 |        1 | -45.1172   |  21.0254   | -10.292     | not_try           |
# | 1720 |        1 | -24.3145   |  27.8843   |  -4.38471   | anyways           |
# | 1722 |        1 | -36.2772   |  10.8216   | -18.5818    | not_support       |
# | 1729 |        1 | -43.7989   |  11.5324   |   1.05975   | not_not           |
# | 1732 |        1 | -43.4374   |  15.289    |  16.0871    | not_best          |
# | 1763 |        1 | -46.7725   |   5.27836  |   4.0998    | not_audiophile    |
# | 1771 |        1 | -35.478    |  23.3766   |  -0.805345  | not_well          |
# | 1791 |        1 | -28.4077   |  10.5025   |  -6.78058   | not_say           |
# | 1816 |        1 | -37.4425   |  20.5467   | -14.8998    | not_expect        |
# | 1828 |        1 | -36.5116   |   8.50853  | -20.2425    | not_loud          |
# | 1862 |        1 | -45.3089   |   7.56468  |   4.91332   | not_think         |
# | 1879 |        1 | -49.8235   |  12.7906   | -11.4725    | not_case          |
# | 1897 |        1 | -33.6144   |  12.1129   | -12.231     | not_take          |
# | 1916 |        1 | -49.0503   |  17.8196   |  -9.05921   | not_allow         |
# | 1937 |        1 | -43.0157   |  -0.623098 |  -0.561542  | not_huge          |
# | 1940 |        1 | -39.0501   |  14.3039   |  11.341     | not_set           |
# | 1951 |        1 | -35.7392   |  18.4032   |   5.30586   | without_problem   |
# | 1970 |        1 | -42.5089   |   8.88192  | -16.5867    | not_seem          |
# | 2007 |        1 | -45.3615   |   9.01554  |  -8.48772   | not_ready         |
# | 2068 |        1 | -28.3492   |  18.0966   |   6.26033   | not_yet           |
# | 2071 |        1 | -34.476    |   3.0227   |  -0.269098  | not_ask           |
# | 2098 |        1 | -40.7138   |  13.1486   | -15.1604    | not_figure        |
# | 2108 |        1 | -35.3589   |  23.8591   | -11.8192    | not_change        |
# | 2139 |        1 | -31.3675   |  18.8285   | -12.642     | not_include       |
# | 2178 |        1 | -43.577    |  22.1345   |  -1.95168   | without_bluetooth |
# | 2190 |        1 | -32.6155   |  16.9761   | -12.2684    | not_deal          |
# | 2223 |        1 | -35.3099   |  12.7955   |  -5.89977   | not_follow        |
# | 2259 |        1 | -50.2589   |  12.1142   | -15.8897    | not_pick          |
# | 2260 |        1 | -40.3182   |  19.0222   |  -9.66968   | not_tell          |
# | 2334 |        1 | -37.2922   |   7.1609   |  -2.5484    | not_pay           |
# | 2357 |        1 | -36.9305   |  26.721    |  -8.28736   | not_fault         |
# | 2364 |        1 | -49.6311   |  12.0653   | -18.1595    | not_impressed     |
# | 2369 |        1 | -40.8004   |   6.06585  |   1.1845    | not_look          |
# | 2385 |        1 | -32.7813   |  16.1531   |   0.537216  | not_something     |
# | 2392 |        1 | -46.0063   |  19.0626   |  -5.01769   | not_car           |
# | 2401 |        1 | -54.7238   |   9.29501  |  -1.55284   | not_answer        |
# | 2415 |        1 | -38.6086   |   2.51701  |  -4.81641   | not_smart         |
# | 2416 |        1 | -48.0126   |  11.7335   |  -5.31989   | not_music         |
# | 2436 |        1 | -44.3253   |  22.2108   |  -6.5883    | not_let           |
# | 2456 |        1 | -39.5476   |  11.4648   |  -4.66678   | not_return        |
# | 2475 |        1 | -34.2061   |  15.1583   | -17.9243    | not_full          |
# | 2489 |        1 | -39.6796   |  19.8331   |  -5.07408   | not_way           |
# | 2500 |        1 | -38.677    |  17.6691   | -15.0865    | programming       |
# | 2511 |        1 | -43.43     |  22.6739   |   7.58513   | not_time          |
# | 2557 |        1 | -39.5809   |  11.2691   |   0.491715  | not_come          |
# | 2562 |        1 | -43.9732   |  15.437    |  -0.211527  | without_need      |
# | 2572 |        1 | -36.4018   |  16.2341   |   3.53372   | not_experience    |
# | 2574 |        1 | -35.8614   |  28.6749   | -15.0079    | not_add           |
# | 2597 |        1 | -42.4651   |  10.7121   | -13.1007    | not_stay          |
# | 2605 |        1 | -38.873    |  13.9727   |  -7.41893   | not_fix           |
# | 2630 |        1 | -45.3023   |   8.89466  |  -0.519294  | not_call          |
# | 2637 |        1 | -43.2428   |  13.1338   |   5.7434    | not_interested    |
# | 2639 |        1 | -34.7175   |  20.8968   | -12.8567    | not_disturb       |
# | 2646 |        1 | -33.1458   |  12.2018   |   2.81317   | not_auto          |
# | 2651 |        1 | -41.663    |  11.8929   | -10.9977    | not_drive         |
# | 2663 |        1 | -44.7183   |  12.397    |  -4.43179   | not_useful        |
# | 2669 |        1 | -32.7741   |  19.5467   |  -3.03565   | not_move          |
# | 2675 |        1 | -30.9248   |   7.90774  |   4.20949   | not_speaker       |
# | 2677 |        1 | -30.1074   |  13.6163   |  -2.25212   | not_help          |
# | 2682 |        1 | -37.685    |  23.3399   |  -6.44955   | not_small         |
# | 2717 |        1 | -37.0069   |  21.2814   |  -5.41043   | not_require       |
# | 2719 |        1 | -35.2927   |  19.8564   |  -9.92339   | not_receive       |
# | 2731 |        1 | -49.5294   |   7.05904  |  -3.31173   | not_control       |
# | 2779 |        1 | -32.2095   |  11.0906   |  -1.91599   | not_live          |
# | 2790 |        1 | -39.7562   |  22.1817   | -15.9918    | not_impress       |
# | 2822 |        1 | -32.055    |   9.88629  |   8.04767   | not_reconnect     |
# | 2824 |        1 | -37.7323   |   9.55358  |   6.49417   | not_long          |
# | 2849 |        1 | -49.6145   |  10.3368   |   3.21239   | not_purchase      |
# | 2865 |        1 | -40.9864   |   3.30348  |   3.03218   | without_look      |
# | 2867 |        1 | -33.26     |   6.46455  |   4.63844   | without_even      |
# | 2886 |        1 | -46.9867   |  15.6343   | -13.0218    | without_take      |
# | 2888 |        1 | -45.1006   |  12.0089   | -14.3457    | not_annoy         |
# | 2904 |        1 | -42.7533   |   1.46496  | -12.5279    | not_audio         |
# | 2906 |        1 | -46.7037   |   6.90187  |  -8.09883   | not_believe       |
# | 2935 |        1 | -47.9029   |  15.3074   |  -0.885419  | not_mean          |
# | 2937 |        1 | -47.6111   |  17.3582   |  -3.87649   | not_possible      |
# | 2940 |        1 | -36.5422   |   3.12383  |  -9.7936    | not_intuitive     |
# | 2946 |        1 | -41.798    |  24.1947   |  -5.5233    | not_high          |
# | 2963 |        1 | -38.7473   |  17.6062   |   0.137125  | not_studio        |
# | 2989 |        1 | -42.6864   |  26.2662   |  -2.69082   | not_hand          |
# | 2994 |        1 | -45.8792   |  16.1042   |  16.7782    | without_phone     |
# | 3019 |        1 | -42.7924   |  -1.73041  |   1.91601   | not_ideal         |
# | 3028 |        1 | -42.0945   |  -5.63344  |  -5.32973   | protocol          |
# | 3036 |        1 | -27.9968   |  23.4033   |  12.0593    | rider             |
# | 3059 |        1 | -31.3421   |  18.0398   |   0.0933539 | not_exactly       |
# | 3073 |        1 | -35.3283   |  12.4005   | -17.136     | not_talk          |
# | 3074 |        1 | -34.1094   |   7.47713  |  11.5306    | without_get       |
# | 3088 |        1 | -43.2768   |  28.9025   | -10.0934    | not_realize       |
# | 3096 |        1 | -53.1895   |  11.4706   |  -0.922582  | not_replace       |
# | 3100 |        1 | -31.6951   |  23.6342   |  -8.10478   | not_anything      |
# | 3103 |        1 | -29.8963   |  23.613    | -14.084     | not_sync          |
# | 3117 |        1 | -29.9665   |   7.87909  |   0.505654  | not_option        |
# | 3140 |        1 | -41.6001   |  -0.573148 | -12.8122    | inessential       |
# | 3145 |        1 | -38.2134   |   9.81429  |  -5.7949    | not_would         |
# | 3154 |        1 | -43.3058   |  17.0076   |  -5.16775   | not_new           |
# | 3163 |        1 | -34.5963   |  22.1707   |  -4.22261   | not_wait          |
# | 3169 |        1 | -34.9898   |   2.02872  |  -2.30227   | not_phone         |
# | 3177 |        1 | -39.1097   |   8.25896  | -11.2476    | not_first         |
# | 3198 |        1 | -32.1925   |  13.5898   |  -8.94236   | not_user          |
# | 3202 |        1 | -39.8807   |  21.1986   |   4.07624   | not_adjust        |
# | 3204 |        1 | -47.847    |   4.94012  |   1.38401   | not_provide       |
# | 3210 |        1 | -38.2817   |   5.026    |  -8.49902   | not_access        |
# | 3217 |        1 | -30.254    |  18.5785   |  -4.11055   | not_bother        |
# | 3223 |        1 | -42.0774   |  26.3867   | -10.6273    | not_feel          |
# | 3242 |        1 | -50.9825   |   9.25693  |  -7.25952   | not_screen        |
# | 3262 |        1 | -37.8374   |   7.72331  | -13.796     | not_meet          |
# | 3272 |        1 | -47.9637   |   7.36672  |  -5.64042   | not_waste         |
# | 3288 |        1 | -36.6909   |  11.7955   |  -7.98477   | not_display       |
# | 3292 |        1 | -34.8602   |  21.8409   |   9.20187   | without_open      |
# | 3301 |        1 |   0.401451 |  37.5333   |  10.4537    | purchasing        |
# | 3307 |        1 | -37.8519   |  11.214    |   8.62258   | not_app           |
# | 3310 |        1 | -46.306    |   5.32897  | -14.631     | not_run           |
# | 3315 |        1 | -34.2613   |   7.9112   | -12.2826    | not_hard          |
# | 3335 |        1 | -26.0078   |   8.39234  | -18.9097    | buyer_beware      |
# | 3342 |        1 | -42.0682   |   3.85432  |  -8.21688   | without_sound     |
# | 3343 |        1 | -34.5421   |   4.03202  |   6.17084   | not_speak         |
# | 3346 |        1 | -28.4087   |  15.3611   |   4.25176   | not_read          |
# | 3367 |        1 |  -3.07363  |  -4.40548  | -25.5045    | battle            |
# | 3370 |        1 | -31.9307   |  22.6347   | -15.6308    | not_true          |
# | 3373 |        1 | -46.6604   |   8.14615  |  -2.99111   | not_drop          |
# | 3374 |        1 | -44.9937   |  24.3378   |   2.5553    | not_open          |
# | 3383 |        1 | -42.8771   |  19.6501   |  -0.517389  | not_integrate     |
# | 3384 |        1 | -46.4618   |  13.7998   |  -2.55565   | not_worry         |
# | 3399 |        1 | -37.6917   |  20.0739   |  -0.393448  | not_stereo        |
# | 3429 |        1 | -36.7339   |  -9.93967  |  22.7265    | soul              |
# | 3436 |        1 | -22.59     | -20.7699   | -27.7277    | www_com           |

# %%
px.scatter_3d(data_frame = hier_df, x = "x", y = "y", z = "z", color = [str(x) for x in hier_df["labels"]], hover_name = "word")

# %%
target_pos = ["love", "awesome", "nice",
"amazing", "best", "fantastic", "correct", "happy"
]

target_neg = ["hate", "terrible", "nasty", "awful",
"worst", "horrible"]

# %%
pos_average_vector = np.zeros(w2v_model.vector_size).reshape((w2v_model.vector_size, ))
neg_average_vector = np.zeros(w2v_model.vector_size).reshape((w2v_model.vector_size, ))
for word in target_pos:
    try:
        pos_average_vector += w2v_model.wv[word]
    except KeyError:
        continue
for word in target_neg:
    try:
        neg_average_vector += w2v_model.wv[word]
    except KeyError:
        continue

pos_average_vector = pos_average_vector / norm(pos_average_vector)
neg_average_vector = neg_average_vector / norm(neg_average_vector)

semantic_axe = pos_average_vector - neg_average_vector

# %%
df_polarity = pd.DataFrame()

words = []
scores = []

for w in words_wv:
    words.append(w)
    score = dot(w2v_model.wv[w], semantic_axe)/(norm(w2v_model.wv[w])*norm(semantic_axe))
    scores.append(score)

df_polarity["word"] = words
df_polarity["score"] = scores

df_polarity.sort_values(by = "score", ascending = True).head(10)
# Out:
#               word     score
# 993       horrible -0.447070
# 1344         awful -0.437519
# 3375    afterwards -0.391189
# 1585  unresponsive -0.388564
# 704           hate -0.342750
# 1023     seriously -0.330945
# 283     microphone -0.328395
# 1661      headache -0.324527
# 180            bad -0.322235
# 3317  questionable -0.320123

# %%
print(df_polarity.sort_values(by = "score", ascending = False).head(10).to_latex(index = False))
# Out:
# \begin{tabular}{lr}
# \toprule
#       word &    score \\
# \midrule
#      happy & 0.520724 \\
#  fantastic & 0.500865 \\
#      great & 0.455940 \\
#    pleased & 0.439680 \\
#    awesome & 0.436962 \\
#      enjoy & 0.406554 \\
#       nice & 0.402090 \\
#       love & 0.384281 \\
#      lyric & 0.354649 \\
# worthwhile & 0.337414 \\
# \bottomrule
# \end{tabular}
# C:\Users\crist\AppData\Local\Temp\ipykernel_1840\1835509105.py:1: FutureWarning:
#
# In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.

# %%
def scoring_function(x, pos_w, neg_w, w2v):
    bigrams_clean = Phrases(x)
    # print(clean)
    predicted = []
    i = 0
    for review in bigrams_clean[x]:
        score = 0
        for w in review:
            try:
                vec = w2v[w]
                pos = dot(vec, w2v[pos_w])/(norm(vec)*norm(w2v[pos_w]))
                neg = dot(vec, w2v[neg_w])/(norm(vec)*norm(w2v[neg_w]))
                score += pos
                score -= neg
            except KeyError:
                continue
        if score > 0:
            predicted.append(1)
        elif score < 0:
            predicted.append(0)
        else:
            predicted.append(0)
        i+=1

    return predicted

# %%
def scoring_functionV4(x, pos_list, neg_list, w2v, threshold = 0.10, stampa = True):
    import statistics
    bigrams_clean = Phrases(x, scoring="npmi", threshold=0.60)
    pos_average_vector = np.zeros(w2v.vector_size).reshape((w2v.vector_size, ))
    neg_average_vector = np.zeros(w2v.vector_size).reshape((w2v.vector_size, ))
    for word in pos_list:
        try:
            pos_average_vector += w2v[word]
        except KeyError:
            continue
    for word in neg_list:
        try:
            neg_average_vector += w2v[word]
        except KeyError:
            continue

    pos_average_vector = pos_average_vector / norm(pos_average_vector)
    neg_average_vector = neg_average_vector / norm(neg_average_vector)

    semantic_axe = pos_average_vector - neg_average_vector


    # print(clean)
    predicted = []
    for review in bigrams_clean[x]:
        rev_score = 0
        for w in review:
            try:
                vec = w2v[w]
            except KeyError:
                continue
            score = dot(vec, semantic_axe)/(norm(vec)*norm(semantic_axe))
            if stampa:
                print(w, ":", score)
            if score > 0 and score >= threshold:
                rev_score += score
            if score < 0 and score <= -threshold:
                rev_score += score

        if rev_score>0:
            predicted.append(1)
        elif rev_score<0:
            predicted.append(0)
        else:
            predicted.append(0)
    
    return predicted

# %%
y = []
x = []

for feedback, review in zip(dataset["feedback"], dataset["verified_reviews"]):
    y.append(feedback)
    x.append(review)
    
x_test = tokenize_list_of_text(x, custom_stopwords, False, 2)[1]
# Out:
# total number of types extracted is: 3038

# %%
# target_pos = ["love", "awesome", "nice",
# "amazing", "best", "fantastic", "correct", "happy"
# ]

# target_neg = ["hate", "terrible", "nasty", "awful",
# "worst", "horrible"]

predicted = scoring_function(x_test, "great", "bad", w2v_model.wv)
print(classification_report(y, predicted))

predicted = scoring_functionV4(x_test, target_pos, target_neg, w2v_model.wv, stampa = False, threshold=0.03)
print(classification_report(y, predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.30      0.69      0.42       206
#            1       0.96      0.84      0.90      1990
#
#     accuracy                           0.82      2196
#    macro avg       0.63      0.76      0.66      2196
# weighted avg       0.90      0.82      0.85      2196
#
#               precision    recall  f1-score   support
#
#            0       0.41      0.72      0.52       206
#            1       0.97      0.89      0.93      1990
#
#     accuracy                           0.88      2196
#    macro avg       0.69      0.80      0.72      2196
# weighted avg       0.92      0.88      0.89      2196

# %%
for pred, review, correct in zip(predicted, x_test, y):
    print("prediction:", pred, "true label:", correct)
    print(review)
    print("################")
# Out:
# prediction: 1 true label: 1
# ['love']
# ################
# prediction: 1 true label: 1
# ['love']
# ################
# prediction: 1 true label: 1
# ['sometimes', 'play', 'game', 'answer', 'question', 'correctly', 'say', 'get', 'wrong', 'answer', 'like', 'able', 'turn', 'light', 'away', 'home']
# ################
# prediction: 1 true label: 1
# ['lot', 'fun', 'thing', 'old', 'learn', 'dinosaur', 'control', 'light', 'play', 'game', 'like', 'category', 'nice', 'sound', 'play', 'music', 'well']
# ################
# prediction: 1 true label: 1
# ['music']
# ################
# prediction: 1 true label: 1
# ['receive', 'gift', 'need', 'another', 'bluetooth', 'something', 'play', 'music', 'easily', 'accessible', 'find', 'smart', 'speaker', 'not_wait', 'see', 'else']
# ################
# prediction: 1 true label: 1
# ['think', 'one', "'ve", 'purchase', 'work', 'get', 'one', 'every', 'room', 'house', 'really', 'like', 'feature', 'offer', 'specifily', 'play', 'music', 'control', 'light', 'throughout', 'house']
# ################
# prediction: 1 true label: 1
# ['look', 'great']
# ################
# prediction: 1 true label: 1
# ['love', 'listen', 'song', 'not_heard', 'since', 'childhood', 'get', 'news', 'weather', 'information', 'great']
# ################
# prediction: 0 true label: 1
# ['send', 'year', 'old', 'dad', 'talk', 'constantly']
# ################
# prediction: 1 true label: 1
# ['love', 'learn', 'know', 'thing', 'eveyday', 'still', 'figure', 'everything', 'work', 'far', 'easy', 'use', 'understand', 'make', 'laugh', 'time']
# ################
# prediction: 1 true label: 1
# ['purchase', 'mother', 'knee', 'problem', 'give', 'something', 'try', 'come', 'end', 'around', 'fast', 'like', 'enjoy', 'little', 'big', 'thing', 'play', 'song', 'time', 'cook']
# ################
# prediction: 1 true label: 1
# ['love', 'love', 'love']
# ################
# prediction: 1 true label: 1
# ['expect']
# ################
# prediction: 1 true label: 1
# ['love', 'wife', 'hat']
# ################
# prediction: 1 true label: 1
# ['really', 'happy', 'purchase', 'great', 'speaker', 'easy', 'set']
# ################
# prediction: 1 true label: 1
# ['use', 'couple', 'day', 'lot', 'fun', 'new', 'toy', 'like', 'new', 'household', 'member', 'try', 'learn', 'different', 'featues', 'benefit', 'come']
# ################
# prediction: 1 true label: 1
# ['love', 'size', 'still', 'need', 'little', 'improvement', 'sound']
# ################
# prediction: 1 true label: 1
# ['like', 'original', 'short', 'great', 'fabric', 'color', 'choice', 'miss', 'volume', 'ring', 'top', 'plus', 'minus', 'button', 'not_a', 'big', 'deal', 'ring', 'comfort', 'well', 'like', 'use', 'standard', 'usb', 'charger', 'port', 'instead', 'previous', 'round', 'pin', 'guess', 'sound', 'seem', 'work', 'still', 'answer', 'computer', 'not_to', 'like']
# ################
# prediction: 1 true label: 1
# ['love', 'good', 'music', 'sound', 'play', 'understand', 'command', 'difficult', 'time', 'find', 'specific', 'playlist', 'song', 'spotify', 'good', 'music', 'lack', 'major', 'program']
# ################
# prediction: 1 true label: 1
# ['love', 'use', 'play', 'music', 'play', 'radio', 'itunes', 'play', 'podcasts', 'anypod', 'set', 'reminder', 'listen', 'flash', 'briefing', 'news', 'weather', 'every', 'morning', 'rely', 'custom', 'list', 'like', 'able', 'voice', 'control', 'volume', "'re", 'sure', "'ll", 'continue', 'find', 'new', 'sometimes', 'bit', 'frustrate', 'not_understand', "'re", 'say']
# ################
# prediction: 1 true label: 1
# ['set', 'day', 'still', 'add', 'smart', 'home', 'device', 'speaker', 'great', 'play', 'music', 'like', 'size', 'station', 'kitchen', 'counter', 'unintrusive', 'look']
# ################
# prediction: 1 true label: 1
# ['love', 'play', 'sleep', 'sound', 'immediately', 'ask']
# ################
# prediction: 1 true label: 1
# ['amazing', 'product']
# ################
# prediction: 1 true label: 1
# ['love', 'easy', 'operate', 'load', 'fun', 'everything', 'advertised', 'use', 'mainly', 'play', 'favorite', 'tune', 'test', 'knowledge']
# ################
# prediction: 1 true label: 1
# ['sound', 'great', 'love']
# ################
# prediction: 1 true label: 1
# ['fun', 'item', 'play', 'get', 'use', 'use', 'sometimes', 'hard', 'time', 'answer', 'question', 'ask', 'think', 'good']
# ################
# prediction: 1 true label: 1
# ['like', 'one']
# ################
# prediction: 1 true label: 1
# ['still', 'learn', 'capability', 'far', 'pretty', 'pretty', 'pretty', 'good']
# ################
# prediction: 1 true label: 1
# ['like']
# ################
# prediction: 1 true label: 1
# ['work', 'well', 'need', 'learning', 'command', 'unique', 'owner', 'user', 'like', 'learn', 'tasha', 'birthday', 'learn', 'definition', 'fine', 'etc', 'great']
# ################
# prediction: 1 true label: 1
# ['device', 'awesome']
# ################
# prediction: 1 true label: 1
# ['buy', 'compare', 'speaker', 'quality', 'first', 'speaker', 'like', 'sound', 'good', 'ship', 'daughter', 'though', 'like', 'fact', 'first', 'chargeable', 'base', 'buy', 'keep', 'mobile', 'need', 'good', 'sound']
# ################
# prediction: 1 true label: 1
# ['love', 'still', 'learn', 'thing', 'unable', 'follow', 'instruction', 'include', 'package', 'find', 'great', 'one', 'tube']
# ################
# prediction: 1 true label: 1
# ['speaker', 'good']
# ################
# prediction: 1 true label: 1
# ['thing', 'way', 'cool', 'get', 'one', 'want', 'cool']
# ################
# prediction: 1 true label: 1
# ['first', 'digital', 'assistant', 'give', 'good', 'review', 'speaker', 'really', 'good', 'cheap', 'price', 'day', 'fun', 'play', 'use', 'alarm', 'clock', 'get', 'first', 'place', 'end', 'lack', 'one', 'definitely', 'try', 'like', 'best', 'number', 'device', 'connect', 'purchase', 'come', 'smart', 'plug', 'connect', 'lamp', 'turn', 'light']
# ################
# prediction: 1 true label: 1
# ['husband', 'like', 'able', 'use', 'listen', 'music', 'wish', 'know', 'capability']
# ################
# prediction: 0 true label: 1
# ['android', 'would', 'forbid', 'connect', 'fortunately', 'sister', 'apple', 'cell', 'hour', 'tech', 'support', 'fix', 'glitch', 'run']
# ################
# prediction: 1 true label: 1
# ['far', 'good']
# ################
# prediction: 1 true label: 1
# ['try', 'play', 'certain', 'broadway', 'show', 'like', 'camelot', 'give', 'group', 'camelot']
# ################
# prediction: 1 true label: 1
# ['great']
# ################
# prediction: 1 true label: 1
# ['satisfied', 'control', 'light', 'family', 'room', 'wife', 'listen', 'jimmy', 'buffet', 'ask']
# ################
# prediction: 1 true label: 0
# ['like', 'fact', 'answer', 'accurately', 'not_see', 'real', 'need', 'household', 'though', 'good', 'bargain', 'day', 'deal']
# ################
# prediction: 1 true label: 1
# ['love', 'still', 'learn', 'every', 'thing', 'work', 'ton', 'fun']
# ################
# prediction: 1 true label: 1
# ['love', 'much']
# ################
# prediction: 0 true label: 1
# ['excellent', 'thing', 'not_in', 'spanish']
# ################
# prediction: 1 true label: 1
# ['still', 'learn', 'use', 'far', 'great', 'sound', 'actually', 'much', 'good', 'expect']
# ################
# prediction: 1 true label: 1
# ['work', 'expect', 'also', 'good', 'sound', 'quality', 'consider', 'price', 'sale', 'feature']
# ################
# prediction: 1 true label: 1
# ['sound', 'phenomenal', 'not_to', 'mention', 'love', 'helpful']
# ################
# prediction: 1 true label: 1
# ['let', 'play', 'learn', 'get']
# ################
# prediction: 1 true label: 1
# ['work', 'advertised', 'easy', 'setup', 'still', 'learn']
# ################
# prediction: 1 true label: 1
# ['great', 'sound', 'easy', 'set']
# ################
# prediction: 1 true label: 1
# ['love', 'buy', 'others', 'friend']
# ################
# prediction: 1 true label: 1
# ['love', 'purchase', 'company', 'husband', 'great', 'say', 'name', 'tell', 'joke', 'play', 'favorite', 'song']
# ################
# prediction: 0 true label: 1
# []
# ################
# prediction: 1 true label: 1
# ['love', 'able', 'listen', 'music', 'easily', 'still', 'learn', 'feature', 'available']
# ################
# prediction: 0 true label: 1
# ['not_really', 'know', 'could', 'use', 'device', 'use', 'thing', 'need', 'overview']
# ################
# prediction: 1 true label: 1
# ['love', 'wish', 'build']
# ################
# prediction: 1 true label: 1
# ['use', 'primarily', 'play', 'music', 'work', 'wonderfully', 'still', 'get', 'use', 'many', 'thing', 'send', 'several', 'tip', 'since', 'get', 'thank', 'help']
# ################
# prediction: 0 true label: 1
# ['easy', 'set']
# ################
# prediction: 1 true label: 1
# ['fast', 'response', 'amaze', 'clear', 'concise', 'answer', 'sound', 'quality', 'fantastic', 'still', 'get', 'use', 'not_usde', 'full', 'extent']
# ################
# prediction: 1 true label: 1
# ["'re", 'need', 'look']
# ################
# prediction: 1 true label: 1
# ['everything', 'expect']
# ################
# prediction: 1 true label: 1
# ['love', 'work', 'like', 'say', 'would', 'lack', 'smart', 'home', 'not_speak', 'function', 'everything', 'else', 'good']
# ################
# prediction: 1 true label: 1
# ['great', 'sound', 'small', 'package', 'easy', 'set', 'use', 'fun']
# ################
# prediction: 1 true label: 1
# ['work', 'sound', 'great']
# ################
# prediction: 1 true label: 1
# ['sound', 'amazing', 'many', 'collection', 'music']
# ################
# prediction: 1 true label: 1
# ['set']
# ################
# prediction: 0 true label: 1
# ['never', 'listen']
# ################
# prediction: 1 true label: 1
# ['awesome']
# ################
# prediction: 1 true label: 1
# ['buy', 'control', 'fios', 'television', 'work', 'well', 'hop', 'time', 'control', 'fios', 'discover', 'thing', 'play', 'music', 'ask', 'great', 'sound', 'play', 'game', 'play', 'radio', 'station', 'play', 'old', 'time', 'radio', 'program', 'like', 'long', 'ranger', 'many', 'apps', 'add', 'ability', 'day', 'play', 'madlibs', 'great', 'fun', 'also', 'control', 'household', 'appliance', 'purchase', 'compatible', 'power', 'strip', 'control', 'light', 'fan', 'component', 'look', 'forward', 'implement', 'controll', 'also', 'add', 'component', 'choose', 'music', 'play', 'room', 'component', 'locate']
# ################
# prediction: 1 true label: 1
# ['speaker', 'excellent', 'sound', 'work', 'perfectly']
# ################
# prediction: 1 true label: 1
# ['like']
# ################
# prediction: 1 true label: 1
# ['love', 'everything']
# ################
# prediction: 1 true label: 1
# ['little', 'nervous', 'receive', 'new', 'not_really', 'tech', 'savvy', 'find', 'bit', 'intimidate', 'first', 'disclaim', 'long', 'figure', 'happy', 'purchase', 'think', 'add', 'spot']
# ################
# prediction: 1 true label: 1
# ['like', 'still', 'learn', 'use']
# ################
# prediction: 1 true label: 1
# ['great', 'technology', 'disbelieve', 'speaker', 'volume', 'quality', 'wonderful', 'wish', 'buy', 'another', 'one']
# ################
# prediction: 1 true label: 1
# ['purchase', 'husband', 'father', 'day', 'use', 'constantly', 'hear', 'quality', 'sound', 'not_brainer', 'best', 'gift', 'ever']
# ################
# prediction: 1 true label: 1
# ['work', 'fine']
# ################
# prediction: 0 true label: 1
# []
# ################
# prediction: 1 true label: 1
# ['clear', 'music']
# ################
# prediction: 1 true label: 1
# ['fun', 'use', 'good', 'sound', 'quality']
# ################
# prediction: 1 true label: 1
# ['work', 'well', 'able', 'sync', 'music', 'device']
# ################
# prediction: 1 true label: 1
# ['work', 'great', 'forget', 'charge', 'another', 'cent', 'unlimited', 'music', 'buy']
# ################
# prediction: 1 true label: 1
# ['already', 'even', 'well', 'fuller', 'sound', 'also', 'setup', 'let', 'phone', 'call', 'make', 'contact', 'list', 'great']
# ################
# prediction: 1 true label: 1
# ['speaker', 'sound', 'really', 'good']
# ################
# prediction: 1 true label: 1
# ['good', 'sound', 'work', 'well']
# ################
# prediction: 1 true label: 1
# ['love', 'not_very', 'savvy', 'support', 'helpful', 'patient']
# ################
# prediction: 1 true label: 1
# ['love', 'think', 'get', 'one', 'day', 'discount', 'offer', 'could', 'not_pas', 'fun', 'ask', 'play', 'song', 'group', 'come', 'playlist', 'music', 'also', 'connect', 'iphone', 'bluetooth', 'play', 'music', 'pandora', 'video', 'use', 'speaker', "'ve", 'fun', 'ask', 'different', 'type', 'question', 'information', 'like', 'weather', 'news', 'even', 'time', 'country', 'downside', 'limit', 'data', 'wifi', 'plan', 'burn', 'play', 'music']
# ################
# prediction: 1 true label: 1
# ['like', 'far', 'lot', 'try', 'yet']
# ################
# prediction: 1 true label: 1
# ['love', 'use', 'strictly', 'music', 'great']
# ################
# prediction: 1 true label: 1
# ['love', 'love', 'size', 'material', 'speaker', 'quality', 'hook', 'one', 'light', 'easily', 'work', 'additional', 'light', 'thermostat', 'next', 'bedroom', 'lot', 'think', 'traffic', 'weather', 'trivia', 'etc']
# ################
# prediction: 1 true label: 1
# ['love']
# ################
# prediction: 1 true label: 1
# ['entire', 'family', 'love', 'part', 'family']
# ################
# prediction: 1 true label: 1
# ['great', 'fun', 'get', 'know', 'function', 'product', 'wow', 'family', 'fun', 'homework', 'help', 'talk', 'grandchild', 'also', 'huge', 'bonus', 'not_wait', 'learn']
# ################
# prediction: 1 true label: 1
# ['awesome', 'thing', 'love']
# ################
# prediction: 1 true label: 1
# ['work', 'exactly', 'expect', 'speaker', 'great', 'sound', 'perfect', 'classroom']
# ################
# prediction: 1 true label: 1
# ['love', 'love', 'new', 'little', 'gadget', 'make', 'life', 'much', 'easy', 'like', 'personal', 'secretary', 'living', 'home', 'hardly', 'need', 'anymore', 'since', 'play', 'everything', 'need', 'get', 'soon', 'room', 'thanks']
# ################
# prediction: 1 true label: 1
# ['speaker', 'surprising', 'quality', 'happy', 'purchase']
# ################
# prediction: 1 true label: 1
# ['easy', 'set', 'work', 'wonderful', 'love']
# ################
# prediction: 1 true label: 1
# ['really', 'impress', 'sound', 'quality', 'play', 'music', 'device', 'bass', 'sound', 'almost', 'like', 'come', 'big', 'speaker', 'props']
# ################
# prediction: 1 true label: 1
# ['still', 'great', 'product', 'sound', 'quality', 'seem', 'bad', 'end', 'wrong', 'definitely', 'get', 'use', 'within', 'hour', 'definitely', 'feel', 'like', 'gen', 'sound', 'quality', 'good', 'besides', 'great', 'addition', 'able', 'play', 'bluetooth', 'not_wifi', 'even', 'well']
# ################
# prediction: 1 true label: 1
# ['outlet', 'idle', 'disappoint']
# ################
# prediction: 1 true label: 1
# ['great', 'device', 'responsive', 'helpful']
# ################
# prediction: 1 true label: 0
# ['sound', 'terrible', 'want', 'good', 'music', 'get', 'bose']
# ################
# prediction: 1 true label: 1
# ['like', 'sound', 'trouble', 'pay', 'extra', 'money', 'access', 'million', 'song', 'sometimes', 'idle', 'play', 'italian', 'song', 'lack', 'not_understand', 'play', 'opera', 'tosca', 'response', 'sorry', 'lack']
# ################
# prediction: 1 true label: 1
# ['easy', 'set', 'use', 'bad', 'plug', 'would', 'nice', 'take', 'outside', 'operate', 'battery', 'recharge']
# ################
# prediction: 1 true label: 1
# ['still', 'learn', 'way', 'use', 'real', 'hit', 'grandkids', 'ask', 'play', 'music', 'dance', 'yrs', 'cute']
# ################
# prediction: 1 true label: 1
# ['generally', 'like', 'product', 'great', 'ask', 'like', 'play', 'music', 'set', 'timer', 'make', 'call', 'reason', 'not_rate', 'sometimes', 'connection', 'stop', 'play', 'music', 'show', 'red', 'ring', 'seem', 'connection', 'issue', 'overall', 'great', 'product']
# ################
# prediction: 1 true label: 1
# ['work', 'great', 'upgraded', 'full', 'size', 'differ', 'happier']
# ################
# prediction: 0 true label: 1
# ['else', 'say']
# ################
# prediction: 1 true label: 1
# ['upgrade', 'lilttle', 'happy', 'sound']
# ################
# prediction: 1 true label: 1
# ['excellent', 'product', 'set', 'ease', 'well']
# ################
# prediction: 1 true label: 1
# ["'ve", 'first', 'gen', 'since', 'first', 'come', 'work', 'well', 'purchase', 'gen', 'day', 'far', 'happy', 'seem', 'improve', 'speaker', 'provide', 'enhanced', 'sound', 'music']
# ################
# prediction: 1 true label: 1
# ['love', 'smart', 'speaker', 'love', 'volume', 'clarity', 'easy', 'set', 'wonderful', 'gift', 'age']
# ################
# prediction: 1 true label: 1
# ['wonderful', 'product', 'fast', 'delivery']
# ################
# prediction: 1 true label: 1
# ['initially', 'hard', 'set', 'call', 'tech', 'not_that', 'knowledgeable', 'work', 'great']
# ################
# prediction: 1 true label: 1
# ['easy', 'set', 'family', 'love']
# ################
# prediction: 1 true label: 1
# ['great', 'sound', 'responsive', 'voice', 'command']
# ################
# prediction: 1 true label: 1
# ['live', 'long', 'not_the', 'get', 'enjoy', 'music', 'style', 'ask', 'greade', 'wireless', 'love', 'love']
# ################
# prediction: 1 true label: 1
# ['cool', 'product', 'speaker', 'sound', 'good', 'spotify', 'blast']
# ################
# prediction: 1 true label: 1
# ['much', 'fun', 'love', 'able', 'listen', 'music', 'across', 'room', 'busy', 'something', 'else']
# ################
# prediction: 1 true label: 1
# ['far', 'seem', 'nice', 'item', 'pick', 'voice', 'understand', 'not_any', 'problem', 'day', 'ask', 'turn', 'music', 'next', 'room', 'hear', 'fine', "'ve", 'use', 'listen', 'music', 'check', 'weather', 'thing', 'well']
# ################
# prediction: 1 true label: 1
# ['love']
# ################
# prediction: 1 true label: 1
# ['love', 'helpful', 'use', 'remember', 'thing', 'sleep', 'ask', 'anything', 'week', 'still', 'learn']
# ################
# prediction: 1 true label: 1
# ['good', 'gen', 'every', 'way', 'except', 'one', 'really', 'miss', 'ring', 'top', 'volume', 'control', 'quicker', 'easy', 'grab', 'top', 'twist', 'lack', 'look', 'button', 'find', 'one', 'press', 'time', 'also', 'wish', 'bass', 'bit', 'well', 'great', 'device', 'happy']
# ################
# prediction: 1 true label: 1
# ['love']
# ################
# prediction: 1 true label: 1
# ['far', 'like']
# ################
# prediction: 1 true label: 1
# ['thoroughly', 'enjoy', 'ecoo', 'love', 'read', 'audiobook', 'office', 'simply', 'open', 'audiobook', 'kindle', 'continue', 'elsewhere', 'wonderful', 'listen', 'music', 'not_in', 'mood', 'book', 'great', 'set', 'reminder', 'much']
# ################
# prediction: 1 true label: 1
# ['still', 'love']
# ################
# prediction: 1 true label: 1
# ['love']
# ################
# prediction: 1 true label: 1
# ['love', 'sound', 'quality', 'unit', 'clear', 'sound']
# ################
# prediction: 1 true label: 1
# ['listen', 'talk', 'radio', 'morning', 'turn', 'light', 'etc', 'system', 'excellent', 'job', 'full', 'house', 'sound', 'system', 'stream', 'sirius']
# ################
# prediction: 1 true label: 1
# ['week', 'still', 'learn', 'learning', 'process', 'love', 'music', 'call', 'time', 'listen', 'podcasts', 'radio', 'station', 'start', 'keep', 'shopping', 'list', 'grocery', 'list', 'love', 'lack', 'search', 'paper', 'pencil', 'get', 'time', 'temperature', 'great', 'lack', 'wait', 'weather', 'report', 'sound', 'good', 'not_fussy', 'woofer', 'tweeter', 'base', 'etc', 'fine', 'afternoon', 'try', 'drop', 'son', 'get', 'home', 'surprise']
# ################
# prediction: 1 true label: 0
# ['little', 'feature']
# ################
# prediction: 1 true label: 1
# ['great', 'sound', 'quality', 'great', 'feature', 'great', 'product', 'multi', 'room', 'music', 'cool']
# ################
# prediction: 1 true label: 1
# ['cool']
# ################
# prediction: 0 true label: 1
# ['everyone', 'two', 'three', 'buy', 'qvc']
# ################
# prediction: 0 true label: 1
# ['since', 'beginning', 'accidentally', 'spill', 'water', 'replace', 'decide', 'could', 'differ', 'not_an', 'setup', 'easy', 'work', 'within', 'minute']
# ################
# prediction: 1 true label: 1
# ['like', 'able', 'tell', 'music', 'want', 'hear', 'sometimes', 'trouble', 'find', 'song', 'not_very', 'specific', 'title']
# ################
# prediction: 1 true label: 1
# ['like', 'look', 'good', 'original', 'move', 'old', 'basement', 'family', 'room', 'nice', 'sound']
# ################
# prediction: 1 true label: 1
# ['wonderful', 'still', 'learn', 'use', 'music', 'request', 'somewhat', 'limited']
# ################
# prediction: 1 true label: 1
# ['awesome', 'understands', 'kid']
# ################
# prediction: 1 true label: 1
# ['pleasantly', 'surprise', 'sound', 'quality', 'many', 'feature', 'nice', 'easily', 'hear', 'particular', 'artist', 'hear', 'book', 'simple', 'command', 'look', 'forward', 'explore', 'option', 'device']
# ################
# prediction: 0 true label: 1
# ['met', 'exceed', 'expectation', 'easy', 'set', 'really', 'quick', 'response']
# ################
# prediction: 1 true label: 1
# ['like', 'fact', 'get', 'kind', 'music', 'want', 'request', 'like', 'informative', 'photo', 'little', 'pamphlet', 'wish', 'include', 'connect', 'etc', 'command', 'really', 'love', 'music']
# ################
# prediction: 1 true label: 1
# ['abolish', 'way', 'access', 'thorough', 'account', 'think', 'part', 'top', 'line', 'video', 'music', 'etc', 'also', 'think', 'setup', 'app', 'define', 'example', 'music', 'like', 'ill', 'integrate', 'try', 'ask', 'playlist', 'uncertain', 'even', 'though', 'set', 'play', 'list', 'setting', 'also', 'unlike', 'fact', 'word', 'exact', 'match', 'playlist', 'name', 'never', 'remember', 'like', 'ready', 'nature', 'respond', 'query']
# ################
# prediction: 1 true label: 1
# ['great', 'item', 'add', 'audible', 'book', 'make', 'even', 'well', 'thank']
# ################
# prediction: 1 true label: 1
# ['day', 'gen', 'sale', 'could', 'surrender', 'beginning', 'smart', 'home', 'set', 'could', 'differ', 'happy', 'say', 'amazing', 'job', 'connect', 'smart', 'device', 'thanks', 'control', 'light', 'smart', 'plugs', 'etc', 'not_trouble', 'connect', 'wifi', 'phone', 'app', 'work', 'perfectly', 'fine', 'let', 'add', 'skill', 'routine', 'smart', 'device', 'timer', 'much', 'sound', 'quality', 'good', 'enough', 'since', 'not_an', 'audiophile', 'hear', 'voice', 'even', 'watch', 'movie', 'high', 'volume', 'design', 'great', 'modern', 'definitely', 'add', 'nice', 'touch', 'home', 'change', 'cover', 'like', 'sale', 'overall', 'great', 'addition', 'home', 'enables', 'many', 'possibility', 'not_yet', 'sure', 'add', 'home']
# ################
# prediction: 1 true label: 1
# ['versatile', 'fun']
# ################
# prediction: 1 true label: 1
# ['work', 'great', 'killer', 'speaker', 'wife', 'son', 'love']
# ################
# prediction: 1 true label: 1
# ['regret', 'wait', 'long', 'purchase', 'item', 'surprised', 'pleased', 'sound', 'quality']
# ################
# prediction: 0 true label: 0
# ['stop', 'work', 'week', 'precede', 'command', 'really', 'fun', 'work']
# ################
# prediction: 1 true label: 1
# ['far', 'love', 'work', 'get', 'thing', 'set', 'love', 'grocery', 'list', 'app']
# ################
# prediction: 1 true label: 1
# ['perform', 'pretty', 'much', 'expect', 'disappointed', 'not_provide', 'terminology', 'need', 'play', 'various', 'kind', 'music', 'not_subscribe', 'music', 'service', 'understand', 'music', 'choice', 'may', 'limit', 'ignore', 'ask', 'not_access', 'music', 'provide', 'free', 'along', 'purchase', 'chart', 'show', 'language', 'need', 'use']
# ################
# prediction: 0 true label: 1
# ['easy', 'set']
# ################
# prediction: 1 true label: 1
# ['great', 'investment', 'help', 'make', 'laugh']
# ################
# prediction: 1 true label: 1
# ['yet', 'another', 'exho', 'home', 'love']
# ################
# prediction: 1 true label: 1
# ['love', 'plan', 'gender', 'music', 'big', 'band', 'jazz', 'difficult', 'find', 'local', 'radio', 'sound', 'good', 'stop', 'voice', 'command', 'get', 'phone', 'call']
# ################
# prediction: 1 true label: 1
# ['good', 'value']
# ################
# prediction: 1 true label: 1
# ['super', 'easy', 'set', 'love', 'new']
# ################
# prediction: 1 true label: 1
# ['whats', 'not_to', 'like', 'speaker', 'ask']
# ################
# prediction: 1 true label: 1
# ['best', 'father', 'day', 'gift', 'dad', 'joke', 'mom', 'one', 'listening', 'repeated', 'story', 'forward']
# ################
# prediction: 1 true label: 1
# ['great', 'addition', 'breakfast', 'room', 'kitchen', 'tune', 'information', 'instantly', 'available', 'slowly', 'learn', 'feature']
# ################
# prediction: 0 true label: 1
# ['sound', 'quality']
# ################
# prediction: 0 true label: 0
# ['sad', 'joke', 'worthless']
# ################
# prediction: 0 true label: 1
# ['entertainment']
# ################
# prediction: 1 true label: 1
# ['good', 'quality']
# ################
# prediction: 1 true label: 1
# ['work', 'great', 'sound', 'great', 'hit', 'beat', 'wish', 'battery', 'good', 'portability']
# ################
# prediction: 1 true label: 1
# ['love', 'till', 'someone', 'stoled', 'not_afford', 'replace', 'yet']
# ################
# prediction: 0 true label: 1
# ['rock']
# ################
# prediction: 1 true label: 1
# ['get', 'gift', 'love', 'never', 'would', 'buy', 'one', 'allow', 'play', 'music', 'amozon', 'music', 'worth', 'also', 'give', 'new', 'brief', 'tell', 'joke']
# ################
# prediction: 1 true label: 1
# ['not_my', 'mom', 'buy', 'repeat', 'ask', 'take', 'one', 'great', 'tell', 'not_for', 'two', 'day', 'make', 'take', 'hour', 'later', 'could', 'dead', 'life', 'not_it', 'amaze', 'four', 'large', 'speaker', 'small', 'return', 'say', 'order', 'speaker', 'big', 'get', 'otherwise', 'tou', 'return', 'two', 'dead']
# ################
# prediction: 1 true label: 1
# ['love', 'great', 'product']
# ################
# prediction: 0 true label: 1
# ['easy', 'set', 'user', 'friendly']
# ################
# prediction: 0 true label: 0
# ['really', 'disappointed', 'plug', 'wall', 'socket', 'time', 'fault', 'disagree', 'make', 'assumption', 'company', 'technologically', 'advance', 'would', 'sell', 'product', 'rechargeable', 'battery', 'could', 'return', 'would', 'apple', 'music', 'boom', 'speaker', 'give', 'flexibility']
# ################
# prediction: 0 true label: 1
# ['everything']
# ################
# prediction: 1 true label: 1
# ['supberb', 'sound', 'definitely', 'worth', 'extra', 'money', 'listen', 'lot', 'music']
# ################
# prediction: 1 true label: 1
# ['really', 'love', 'think', 'sound', 'quality', 'great', 'lot', 'fun', 'really', 'handy', 'music', 'get', 'update', 'weather', 'sport']
# ################
# prediction: 1 true label: 1
# ['love', 'grandkids']
# ################
# prediction: 0 true label: 1
# ['far', 'work', 'well', 'never', 'intuitive', 'link', 'different', 'device', 'skill', 'get', 'hang']
# ################
# prediction: 1 true label: 1
# ['work', 'advertised']
# ################
# prediction: 1 true label: 1
# ['love']
# ################
# prediction: 1 true label: 1
# ['love', 'new', 'addition', 'house', 'speaker', 'quality', 'great', 'love', 'two', 'not_complaint', 'suggestion', 'future', 'series', 'would', 'good', 'communication', 'ability', 'example', 'smart', 'light', 'house', 'unless', 'specify', 'kitchen', 'light', 'kitchen', 'light', 'prior', 'command', 'either', 'win', 'not_respond', 'say', 'not_recognize', 'may', 'want', 'respond', 'say', 'thank', 'afterwards', 'repeat', 'thank', 'time', 'win', 'not_respond', 'husband', 'know', 'sound', 'odd', 'laugh', 'maybe', 'southern', 'thing', 'want', 'manner']
# ################
# prediction: 1 true label: 1
# ['like', 'everything', 'music', 'trivia', 'game', 'weather']
# ################
# prediction: 1 true label: 1
# ['describe', 'receive', 'time', 'unlike', 'automatic', 'enrolment', 'music']
# ################
# prediction: 1 true label: 1
# ['great', 'device']
# ################
# prediction: 1 true label: 1
# ['love', 'kitchen', 'work', 'well']
# ################
# prediction: 1 true label: 1
# ['nice', 'impressed', 'wish', 'say', 'though']
# ################
# prediction: 1 true label: 1
# ['love', 'product', 'nice', 'easy', 'access', 'much', 'info']
# ################
# prediction: 1 true label: 0
# ['get', 'great', 'sound', 'bass', 'idle', 'time', 'still', 'hot', 'miss', 'recognize', 'thing']
# ################
# prediction: 1 true label: 1
# ['still', 'discover']
# ################
# prediction: 1 true label: 1
# ['amaze', 'paroduct']
# ################
# prediction: 1 true label: 1
# ['good', 'hearing', 'range', 'sound', 'quality', 'bit', 'complicated', 'set', 'not_quite', 'understand', 'lot', 'even', 'speak', 'slowly', 'clearly', 'love', 'flash', 'briefing', 'feature', 'interfacing', 'abode', 'home', 'security', 'system']
# ################
# prediction: 1 true label: 1
# ['speaker', 'sound', 'good']
# ################
# prediction: 1 true label: 1
# ['absolutely', 'love']
# ################
# prediction: 1 true label: 1
# ['best', 'part', 'product', 'control', 'thermostat', 'light', 'house', 'not_anything', 'dislike']
# ################
# prediction: 1 true label: 1
# ["'re", 'thoroughly', 'enjoy', 'installation', 'easy', 'use', 'app', 'purchase', 'kasa', 'smart', 'plug', 'control', 'living', 'room', 'light', 'installation', 'easy', 'use', 'kasa', 'app', 'sinqued', 'right', "'re", 'enjoy', 'play', 'music', 'sound', 'quality', 'awesome', "'ve", 'add', 'kasa', 'smart', 'bulb', 'kitchen', 'setup', 'seamless', "'re", 'look', 'forward', 'add', 'automation', 'home']
# ################
# prediction: 1 true label: 1
# ['home', 'entertainment']
# ################
# prediction: 1 true label: 1
# ['cool', 'product', 'easy', 'setup', 'fun', 'use', 'sound', 'quality', 'much', 'good', 'anticipate']
# ################
# prediction: 1 true label: 1
# ['love', 'great', 'sound', 'easy', 'connect', 'use']
# ################
# prediction: 1 true label: 1
# ['idle', 'fairly', 'new', 'smart', 'mainly', 'manufacturer', 'fault', 'due', 'negate', 'anything', 'old', 'year', 'smart', 'lock', 'also', 'need', 'additional', 'piece', 'equipment', 'order', 'connect', 'well', 'speaker', 'sound', 'great', 'work', 'well']
# ################
# prediction: 1 true label: 1
# ['great', 'sound', 'little', 'speaker']
# ################
# prediction: 1 true label: 1
# ['enjoy']
# ################
# prediction: 1 true label: 1
# ['good', 'quality', 'great', 'sound', 'quality']
# ################
# prediction: 0 true label: 1
# ['work', 'perfectly']
# ################
# prediction: 1 true label: 1
# ['great', 'product', 'sometimes', 'not_understand', 'command', 'fabulous', 'speaker']
# ################
# prediction: 1 true label: 1
# ['love', 'great', 'sound', 'smart']
# ################
# prediction: 1 true label: 1
# ['sure', 'love']
# ################
# prediction: 1 true label: 1
# ['play', 'great']
# ################
# prediction: 1 true label: 1
# ['work', 'absolutely', 'great']
# ################
# prediction: 1 true label: 1
# ['amazing', 'product', 'great', 'sound', 'quality']
# ################
# prediction: 1 true label: 1
# ['best', 'thing', "'ve", 'invest', 'thank', 'much']
# ################
# prediction: 1 true label: 1
# ['extremely', 'impressed', 'item', 'buy', 'warehouse', 'outlet', 'minor', 'imperfection', 'not_tell', 'even', 'one', 'work', 'great', 'packaging', 'seal', 'not_damage', 'hit', 'anything', 'like', 'sound', 'quality', 'see', 'knock', 'not_a', 'bose', 'great', 'family', 'easy', 'use', 'minor', 'learn', 'curve', 'learn', 'voice', 'integrate', 'seamlessly', 'service', 'not_wait', 'get', 'classroom', 'lot', 'fun', 'even', 'speaker', 'let', 'alone', 'plan']
# ################
# prediction: 1 true label: 1
# ['love', 'show', 'bedroom', 'wonderful', 'music', 'info', 'sleep', 'sound']
# ################
# prediction: 1 true label: 1
# ['awesome', 'life', 'changer', 'seriously', 'able', 'start', 'morning', 'wake', 'alarm', 'play', 'music', 'get', 'use', 'voice', 'another', 'room', 'listen', 'say', 'love', 'not_hesitate', 'get', 'one', 'price', 'speaker', 'unbelievable', 'buy', 'cordless', 'holder', 'take', 'anywhere', 'love', 'purchase', 'love']
# ################
# prediction: 0 true label: 0
# ['not_super', 'impressed', 'lapse', 'would', 'tightness', 'anything', 'stupid', 'enough', 'differentiate', 'among', 'spotify', 'account', 'not_use', 'either', 'randomly', 'speak', 'nobody', 'talk', 'today', 'unplug', 'uncertain', "'ll", 'ever', 'use']
# ################
# prediction: 1 true label: 1
# ['like', 'everything']
# ################
# prediction: 1 true label: 1
# ['like']
# ################
# prediction: 1 true label: 1
# ['never', 'issue', 'buy', 'use', 'electronics', 'long', 'get', 'good', 'like', 'new', 'read', 'comment', 'see', 'use']
# ################
# prediction: 1 true label: 1
# ['family', 'really', 'love', 'new']
# ################
# prediction: 1 true label: 1
# ['bought', 'wife', 'love']
# ################
# prediction: 1 true label: 1
# ['fun', 'get', 'today', 'pod', 'car', 'use', 'house']
# ################
# prediction: 1 true label: 1
# ['like']
# ################
# prediction: 1 true label: 1
# ['third', 'worth', 'every', 'penny', 'like', 'household', 'employee', 'small', 'flat', 'rate', 'keep', 'bedroom', 'living', 'room', 'drop', 'use', 'intercom', 'listen', 'music', 'answer', 'quick', 'question', 'alarm', 'wake', 'school', 'etc']
# ################
# prediction: 1 true label: 1
# ['listen', 'music', 'set', 'timer']
# ################
# prediction: 1 true label: 1
# ['receive', 'perfect', 'condition', 'device', 'easy', 'set', 'responds', 'quickly', 'not_any', 'issue', 'great', 'addition', 'family']
# ################
# prediction: 1 true label: 1
# ['good', 'sound', 'like', 'music', 'schedule', 'like', 'get', 'random', 'thought', 'record', 'think', 'joke', 'cute']
# ################
# prediction: 1 true label: 1
# ['purchase', 'begin', 'learn', 'far', 'pleased', 'amaze', 'different', 'action', 'perform', 'enjoy', 'look', 'forward', 'learn', 'option', 'provide']
# ################
# prediction: 1 true label: 1
# ['great', 'others', 'even', 'though', 'small']
# ################
# prediction: 1 true label: 1
# ['funny', 'buy', 'something', 'look', 'fun', 'wind', 'totally', 'useful', 'part', 'home', 'loving']
# ################
# prediction: 1 true label: 1
# ['good', 'experience', 'far', 'second', 'many', 'thing', 'learn', 'lack', 'time', 'yet', 'right', 'mostly', 'enjoy', 'music', 'weather', 'update', 'use', 'alarm', 'feature', 'personality', 'also', 'purchase', 'mini', 'smart', 'socket', 'yes', 'excited', 'begin', 'use']
# ################
# prediction: 1 true label: 1
# ['trouble', 'connect', 'imprecisely', 'tech', 'smart', 'sure', 'one', 'grandson', 'figure', 'far', 'use', 'mostly', 'music']
# ################
# prediction: 1 true label: 1
# ['simply', 'love', 'hardly', 'watch', 'anymore', 'busy', 'listen', 'music', 'speaker', 'pretty', 'goo', 'size', 'fun', 'skills', 'really', 'make', 'fun', 'whole', 'family']
# ################
# prediction: 1 true label: 1
# ['enjoy', 'entire', 'experience']
# ################
# prediction: 0 true label: 1
# ['amazing', 'device', 'many', 'time', 'seem', 'intuitive', 'time', 'ask', 'something', 'seem', 'clear', 'simple', 'get', 'not_result', 'installation', 'fairly', 'straightforward', 'mess', 'several', 'time', 'simply', 'think', 'step', 'complete', 'not_this', 'actually', 'make', 'lose', 'ground', 'figure', 'advice', 'patient', 'app', 'let', 'know', 'move', 'next', 'step', 'big', 'issue', 'moment', 'several', 'device', 'home', 'would', 'like', 'use', 'intercom', 'tell', 'however', 'unmake', 'aware', 'others', 'existence', 'ask', 'answer', 'instruction', 'change', 'name', 'know', 'likely', 'fault', 'would', 'think', 'designer', 'would', 'anticipate', 'make', 'easy', 'find', 'needed', 'instruction', 'small', 'deal', 'many', 'device', 'savvy', 'people', 'challenge']
# ################
# prediction: 1 true label: 1
# ['love', 'much']
# ################
# prediction: 1 true label: 1
# ['original', 'tap', 'far', 'best', 'happy', 'see', 'make', 'improvement', 'new', 'one', 'would', 'great', 'update', 'little', 'think', 'would', 'help', 'lot', 'bug', 'happy', 'play', 'music', 'throughout', 'whole', 'house', 'adjust', 'bass', 'treble', 'thank']
# ################
# prediction: 1 true label: 1
# ['pleased', 'nice', 'available', 'music', 'weather', 'news', 'probably', 'lot', 'not_discover']
# ################
# prediction: 1 true label: 1
# ['pleasantly', 'surprise', 'sound', 'quality', 'big', 'fan', 'deep', 'bass', 'might', 'differ', 'sufficient', 'though', 'potential', 'control', 'home', 'option', 'explore', 'evolve', 'home', 'smart', 'home', 'voice', 'recognition', 'impressive', 'stylish', 'fun', 'not_regret', 'purchase', 'great', 'technically', 'change', 'people', 'ask', 'play', 'song', 'movie', 'respond', 'instantly', 'elderly', 'love', 'one', 'would', 'great', 'gift', 'connect', 'wifi', 'simple', 'use', 'want', 'unlimited', 'music', 'control', 'sure', 'premium', 'spotify', 'blow', 'away', 'personal', 'even', 'conversation', 'not_embarrass', 'say', 'make', 'laugh', 'couple', 'time', 'ask', 'tell', 'joke', 'tell', 'package', 'since', 'addict', 'come', 'extremely', 'handy']
# ################
# prediction: 1 true label: 1
# ['easy', 'setup', 'love', 'thing']
# ################
# prediction: 1 true label: 1
# ['throughout', 'house', 'future', 'arrive']
# ################
# prediction: 1 true label: 1
# ['already', 'find', 'today', 'could', 'surrender', 'get', 'also', 'best', 'thing', 'ever', 'use', 'side', 'house', 'could', 'differ', 'happy']
# ################
# prediction: 0 true label: 1
# ['arrive', 'expect']
# ################
# prediction: 0 true label: 1
# ['buy', 'week', 'ago', 'everything', 'product', 'excellent', 'mind', 'buy', 'charger', 'order', 'must', 'take', 'outside', 'pool', 'lack', 'worry', 'hire', 'electrician', 'put', 'outlet', 'yard']
# ################
# prediction: 1 true label: 1
# ['terrific']
# ################
# prediction: 1 true label: 1
# ['love']
# ################
# prediction: 0 true label: 1
# ['small', 'original', 'look', 'nicer']
# ################
# prediction: 1 true label: 1
# ['work', 'great']
# ################
# prediction: 1 true label: 1
# ['husband', 'would', 'call', 'late', 'adopter', 'come', 'technology', 'decide', 'would', 'try', 'serve', 'primarily', 'music', 'source', 'wow', 'amaze', 'great', 'sound', "'ve", 'also', 'great', 'time', 'listen', 'favorite', 'song', 'buy', 'ask', 'may', 'even', 'buy', 'one', 'elderly', 'dad', 'think', 'enjoy', 'one', 'listen', 'music', 'even', 'place', 'call']
# ################
# prediction: 1 true label: 1
# ['really', 'enjoy', 'change', 'directv', 'channel', 'play', 'iheartradio', 'pandora', 'adjust', 'thermostat', 'turn', 'living', 'room', 'light', 'outside', 'light']
# ################
# prediction: 1 true label: 1
# ['want', 'one', 'buy', 'day', 'absolutely', 'love']
# ################
# prediction: 1 true label: 1
# ['glad', 'get', 'bluetooth', 'speaker', 'much', 'stuff', 'non', 'smart', 'speaker', 'personally', 'love', 'timer', 'feature', 'help', 'cook', 'multiple', 'thing', 'simultaneously', 'pandora', 'integration', 'another', 'feature', 'use', 'daily', 'happy', 'day', 'purchase', 'get', 'future']
# ################
# prediction: 1 true label: 1
# ['see', 'subject', 'line', 'love']
# ################
# prediction: 1 true label: 1
# ['easy', 'setup']
# ################
# prediction: 1 true label: 1
# ['hesitant', 'buy', 'seem', 'good', 'enough', 'except', 'sound', 'quality', 'really', 'not_feel', 'need', 'however', 'glad', 'get', 'difference', 'sound', 'really', 'far', 'superior', 'listen', 'great', 'showman', 'little', 'power']
# ################
# prediction: 1 true label: 1
# ['sound', 'quality', 'great', 'still', 'learn', 'different', 'thing', 'fun']
# ################
# prediction: 1 true label: 1
# ['get', 'good', 'deal', 'work', 'great', 'setup', 'bit', 'pain', 'fault', 'crappy', 'internet', 'service', 'work', 'great', 'nice', 'sound', 'small', 'speaker']
# ################
# prediction: 1 true label: 1
# ['love']
# ################
# prediction: 1 true label: 1
# ['work', 'great', 'perfect', 'office']
# ################
# prediction: 1 true label: 1
# ['love', 'one', 'inside', 'house', 'one', 'pool', 'good', 'bose', 'speaker', 'around', 'house']
# ################
# prediction: 1 true label: 1
# ['easy', 'use', 'amazing']
# ################
# prediction: 1 true label: 1
# ['nice', 'product']
# ################
# prediction: 1 true label: 1
# ['love', 'totally', 'amaze', 'speaker', 'quality', 'bum', 'sell', 'two', 'since', 'get', 'day']
# ################
# prediction: 1 true label: 1
# ['responsive', 'great', 'sound', 'quality', 'size']
# ################
# prediction: 1 true label: 1
# ['efficient', 'amazing', 'cool', 'use', 'often', 'every', 'day']
# ################
# prediction: 1 true label: 1
# ['impress', 'quality', 'sound', 'definitely', 'comparable', 'bose', 'mini', 'give', 'not_use', 'apple', 'music', 'account']
# ################
# prediction: 1 true label: 1
# ['technology', 'small', 'device', 'price', 'good', 'sound', 'amaze', 'must', 'feature', 'home']
# ################
# prediction: 0 true label: 1
# ['mainly', 'use', 'music', 'learn', 'time', 'really', 'nothing', 'bad', 'say']
# ################
# prediction: 0 true label: 1
# ['replace', 'gen', 'concern', 'small', 'unit', 'lack', 'sound', 'wrong', 'anything', 'volume', 'clear', 'good', 'product']
# ################
# prediction: 1 true label: 1
# ['great', 'addition', 'plus']
# ################
# prediction: 1 true label: 1
# ['best']
# ################
# prediction: 1 true label: 1
# ['love', 'feature', 'play', 'music', 'every', 'room', 'multiple']
# ################
# prediction: 1 true label: 1
# ['love', 'surprise', 'much', 'use']
# ################
# prediction: 1 true label: 1
# ['use', 'product', 'enjoyment', 'love']
# ################
# prediction: 1 true label: 1
# ['easy', 'use', 'great', 'sound', 'great', 'purchase', 'great', 'price']
# ################
# prediction: 0 true label: 1
# ['easy', 'set', 'recall']
# ################
# prediction: 1 true label: 1
# ['unit', 'add', 'much', 'pleasure', 'plus', 'music', 'information', 'home', 'one', 'room']
# ################
# prediction: 1 true label: 1
# ['extremely', 'useful', 'simple', 'thing', 'like', 'spotify', 'audible', 'thing', 'like', 'sometimes', 'question', 'everything', 'ask', 'still', 'nice', 'use']
# ################
# prediction: 1 true label: 0
# ['difficult', 'set', 'keep', 'time', 'enter', 'password']
# ################
# prediction: 1 true label: 1
# ['get', 'use', 'use', 'use', 'shop', 'list', 'listen', 'music', 'timer', 'work', 'great', 'far']
# ################
# prediction: 1 true label: 1
# ['cool', 'lot', 'fun', 'use', 'week', 'still', 'learn', 'capability']
# ################
# prediction: 1 true label: 1
# ['love', 'love']
# ################
# prediction: 1 true label: 1
# ['love', 'hard', 'time', 'set', 'apps']
# ################
# prediction: 1 true label: 1
# ['use', 'office', 'another', 'apartment', 'music', 'information']
# ################
# prediction: 1 true label: 1
# ['great', 'music', 'little', 'hard', 'figure', 'work']
# ################
# prediction: 1 true label: 1
# ['give', 'year', 'time', 'birthday', 'gift', 'dad', 'love', 'ask', 'anything', 'answer', 'plus', 'good', 'homework', 'purchase', 'one', 'day', 'bathroom', 'get', 'ready', 'work', 'listen', 'music', 'base', 'metro', 'booming', 'replacement', 'clock', 'radio', 'plus', 'night', 'stand', 'alarm', 'clock']
# ################
# prediction: 1 true label: 1
# ['impressed', 'look', 'clarity', 'sound', 'color']
# ################
# prediction: 1 true label: 1
# ['amazing', 'great', 'speaker']
# ################
# prediction: 1 true label: 1
# ['still', 'get', 'use', 'lack', 'connect', 'yet', 'thing', 'right', 'use', 'music', 'information', 'great']
# ################
# prediction: 1 true label: 1
# ['work', 'sound', 'great', 'house', 'barely', 'sit', 'kitchen', 'counter', 'hear', 'speak', 'room', 'lot', 'functionality', 'still', 'discover']
# ################
# prediction: 1 true label: 1
# ['pure', 'fun', 'weather', 'joke', 'news', 'briefing', 'music', 'still', 'much', 'use', 'lot', 'fun', 'money']
# ################
# prediction: 1 true label: 1
# ['use', 'time', 'especially', 'communicate', 'kid', 'throughout', 'home']
# ################
# prediction: 1 true label: 1
# ['love', 'still', 'learn', 'make', 'lot', 'thing', 'easier', 'like', 'forget', 'turn', 'light', 'another', 'room', 'ask', 'turn', 'light']
# ################
# prediction: 1 true label: 1
# ['buy', 'daughter', 'turn', 'love', 'especially', 'like', 'call', 'feature', 'since', 'lack', 'cell', 'phone', 'love', 'play', 'music', 'dancing', 'music', 'play', 'favorite', 'song', 'sometimes', 'lol']
# ################
# prediction: 1 true label: 1
# ['get', 'wedding', 'gift', 'not_discover', 'feature', 'yet', 'update', 'playing', 'music', 'great', 'though']
# ################
# prediction: 1 true label: 1
# ['impress', 'sound', 'quality']
# ################
# prediction: 1 true label: 1
# ['pleased', 'purchase', 'smart', 'speaker', 'love', 'fact', 'play', 'music', 'different', 'genre', 'whenever', 'want', 'trouble', 'first', 'work']
# ################
# prediction: 1 true label: 1
# ['wife', 'enjoy', 'ease', 'play', 'music', 'game', 'fun', 'entertain', 'look', 'forward', 'add', 'smart', 'product', 'home']
# ################
# prediction: 1 true label: 1
# ['second', 'love', 'help', 'kitchen', 'set', 'timer', 'listen', 'news', 'prepare', 'grocery', 'list', 'get', 'great', 'music']
# ################
# prediction: 1 true label: 1
# ['sound', 'quality', 'good', 'wish', 'could', 'answer', 'question']
# ################
# prediction: 1 true label: 1
# ['second', 'speaker', 'weak', 'purchase', 'listen', 'music', 'speaker', 'great']
# ################
# prediction: 1 true label: 1
# ['great', 'sound']
# ################
# prediction: 0 true label: 1
# ['really', 'use', 'speaker', 'stream', 'music', 'month', 'kinda', 'useless']
# ################
# prediction: 1 true label: 1
# ['set', 'user', 'friendly', 'set', 'not_a', 'user', 'friendly', 'hop', 'app', 'able', 'download', 'not_instal', 'invasive', 'driver', 'wife', 'retired', 'would', 'lack', 'able', 'install', 'son', 'recall', 'smart', 'phone', 'would', 'differ', 'use', 'yet']
# ################
# prediction: 1 true label: 1
# ['easy', 'set', 'really', 'enjoy']
# ################
# prediction: 1 true label: 1
# ['compact', 'bit', 'well', 'original']
# ################
# prediction: 1 true label: 1
# ['love', 'pretty', 'cool']
# ################
# prediction: 1 true label: 1
# ['living', 'room', 'music', 'sound', 'really', 'good', 'living', 'room', 'hear', 'upstairs']
# ################
# prediction: 1 true label: 1
# ['great', 'product', 'set', 'easy', 'sound', 'wonderful']
# ################
# prediction: 1 true label: 1
# ['far', 'like', 'buy', 'music', 'though', 'sound', 'pretty', 'good']
# ################
# prediction: 1 true label: 1
# ['love']
# ################
# prediction: 1 true label: 1
# ['glad', 'buy']
# ################
# prediction: 1 true label: 1
# ['like', 'type', 'fun', 'music']
# ################
# prediction: 1 true label: 1
# ['like', 'volume', 'top', 'turn', 'quickly']
# ################
# prediction: 1 true label: 1
# ['love', 'new', 'give', 'hour', 'music', 'help', 'thing', 'difficult', 'set', 'help', 'tekkie']
# ################
# prediction: 1 true label: 1
# ['almost', 'good', 'bose', 'love', 'whole', 'house', 'music']
# ################
# prediction: 0 true label: 0
# ['hardly', 'come']
# ################
# prediction: 1 true label: 1
# ['easy', 'setup', 'use', 'app', 'also', 'easy', 'install', 'phone', 'sound', 'quality', 'listen', 'music', 'pandora', 'wonderful']
# ################
# prediction: 1 true label: 1
# ['still', 'learn', 'use', 'far', 'love']
# ################
# prediction: 1 true label: 1
# ['work', 'awesome']
# ################
# prediction: 1 true label: 1
# ['work', 'great']
# ################
# prediction: 1 true label: 1
# ['small', 'speaker', 'sound', 'great']
# ################
# prediction: 1 true label: 1
# ['great', 'sound', 'size', 'prize', 'course']
# ################
# prediction: 1 true label: 1
# ['lack', 'definitely', 'need', 'one']
# ################
# prediction: 1 true label: 1
# ['great', 'device', 'seem', 'work', 'good']
# ################
# prediction: 0 true label: 0
# ['item', 'unretentive', 'work', 'month', 'use', 'disconnect', 'wifi', 'unresponsive', 'reset', 'request']
# ################
# prediction: 1 true label: 1
# ['love', 'easy', 'fun', 'get', 'drop', 'grandaughter', 'live', 'mile', 'away', 'sound', 'like', 'right', 'next']
# ################
# prediction: 1 true label: 1
# ['work', 'great', 'like', 'new', 'one']
# ################
# prediction: 1 true label: 1
# ['one', 'kitchen', 'timer', 'music', 'duty']
# ################
# prediction: 1 true label: 1
# ['love', 'volume', 'could', 'definitely', 'use', 'boost', 'well', 'build', 'speaker', 'would', 'definitively', 'think', 'ahead', 'put', 'audio', 'auxiliary', 'input', 'buy', 'dedicated', 'speaker', 'prove', 'best', 'way']
# ################
# prediction: 1 true label: 1
# ['work', 'fine']
# ################
# prediction: 1 true label: 1
# ['work', 'great', 'look', 'brand', 'new', 'love', 'new', 'get', 'main', 'room', 'house']
# ################
# prediction: 1 true label: 1
# ...
# ################
# prediction: 1 true label: 1
# ['work', 'great', 'fun', 'play', 'music', 'check', 'weather', 'king', 'question']
# ################
# prediction: 1 true label: 1
# ['small', 'convenient', 'dependable', 'cutie', 'job', 'ask', 'issue', 'fidelity', 'expect', 'small', 'speaker']
# ################
# prediction: 1 true label: 1
# ['perfect', 'people', 'like', 'live', 'alone', 'least', 'someone', 'talk', 'keep', 'sanity', 'though', 'wish', 'powerful', 'speaker', 'obviate', 'connect', 'bluetooth', 'speaker']
# ################
# prediction: 1 true label: 1
# ['small', 'footprint', 'nice', 'clarity']
# ################
# prediction: 1 true label: 1
# ['great', 'addition', 'base', 'use', 'guest', 'bedroom', 'music', 'clock', 'info', 'speaker', 'not_a', 'strong', 'base', 'great', 'value']
# ################
# prediction: 1 true label: 1
# ['build', 'thermostat', 'idle', 'well', 'stand', 'right', 'next', 'hear', 'music', 'play', 'choppy', 'decide', 'try', 'since', 'day', 'differ', 'disappointed', 'hear', 'fine', 'music', 'play', 'problem', 'really', 'like', 'bluetooth', 'connect', 'bose', 'speaker', 'quality', 'sound']
# ################
# prediction: 1 true label: 1
# ['connect', 'whole', 'home', 'sound', 'system', 'play', 'music', 'home', 'mini', 'unmake', 'work', 'well']
# ################
# prediction: 1 true label: 1
# ['much', 'fun', 'play', 'ask', 'set', 'alarm', 'wake', 'morning', 'tell', 'turn', 'learns', 'question', 'ask', 'play', 'music', 'ask', 'play', 'music', 'domain', 'wake', 'middle', 'night', 'lack', 'turn', 'light', 'ask', 'time', 'want', 'current', 'weather', 'tell', 'ask', 'city', 'know', 'call', 'friend', 'dial', 'not_use', 'one', 'yet', 'say', 'could', 'contact']
# ################
# prediction: 1 true label: 1
# ['easy', 'set', 'everything', 'poster', 'despite', 'small', 'size', 'speaker', 'adequate', 'understands', 'instruction', 'across', 'room', 'happy', 'purchase']
# ################
# prediction: 1 true label: 1
# ['great', 'product', 'price', 'work', 'well']
# ################
# prediction: 1 true label: 1
# ['perfect', 'home', 'office']
# ################
# prediction: 1 true label: 0
# ['weak', 'sound', 'compare', 'home', 'mini', 'sound', 'bad', 'also', 'need', 'small', 'selection', 'music', 'need', 'music', 'play', 'everything', 'also', 'get', 'two', 'need', 'family', 'music', 'play', 'music', 'think', 'lame', 'need', 'family', 'plan', 'use', 'multiple', 'device']
# ################
# prediction: 1 true label: 1
# ['suppose', 'great', 'product']
# ################
# prediction: 1 true label: 1
# ['love', 'item', 'able', 'hear', 'kind', 'music', 'enjoy', 'much', 'order', 'another']
# ################
# prediction: 1 true label: 1
# ['love']
# ################
# prediction: 1 true label: 1
# ['great', 'item', 'glad', 'make', 'purchase', 'day']
# ################
# prediction: 1 true label: 1
# ['still', 'learn', 'use', 'figure', 'read', 'kindle', 'book', 'real', 'bonus']
# ################
# prediction: 1 true label: 1
# ['love', 'one', 'bedroom', 'kitchen', 'great', 'drop', 'family', 'around', 'house']
# ################
# prediction: 1 true label: 1
# ['far', 'good', 'not_to', 'tech', 'savvy', 'still', 'try', 'figure', 'easy', 'set', 'far', 'easy', 'use', 'lot', 'apps', 'use', 'play', 'fun']
# ################
# prediction: 0 true label: 0
# ['responds', 'odd', 'talk', "'ve", 'unplug', 'feel', 'like', 'spy']
# ################
# prediction: 0 true label: 0
# ['disconnect', 'phone', 'playlist']
# ################
# prediction: 1 true label: 1
# ['put', 'awhile', 'finally', 'get', 'around', 'buying', 'home', 'wife', 'legally', 'blind', 'not_use', 'computer', 'godsend', 'music', 'listen', 'music', 'check', 'weather', 'get', 'phone', 'number', 'make', 'call', 'etc', 'etc', 'still', 'learn', 'tell', 'absolutely', 'amazing', 'purchase', 'extended', 'family', 'grandchild', 'absolutely', 'love', 'play', 'music', 'wifi', 'direct', 'cable', 'capability', 'speaker', 'stereo', 'option', 'choosing', 'well', 'worth', 'money', 'not_regret']
# ################
# prediction: 1 true label: 1
# ['perfect', 'fast', 'shipment', 'packaging', 'work', 'intend']
# ################
# prediction: 0 true label: 1
# ['addict', 'thing']
# ################
# prediction: 1 true label: 1
# ['love', 'hop', 'add', 'couple', 'around', 'apartment', 'reason', 'starve', 'wish', 'speaker', 'would', 'little', 'good', 'know', 'probably', 'want', 'keep', 'cost', 'item', 'really', 'like', 'play', 'music', 'around', 'apartment', 'busy', 'thing', 'would', 'add', 'speaker', 'little', 'wattage', 'bass', 'response', 'would', 'something', 'great', 'put', 'bathroom', 'kitchen', 'might', 'differ', 'lot', 'space', 'full', 'sized', 'would', 'willing', 'pay', 'dollar', 'good', 'speaker', 'well', 'still', 'love', 'find', 'bluetooth', 'speaker', 'sound', 'good', 'disclaim', 'whole', 'lot', 'space']
# ################
# prediction: 1 true label: 1
# ['far', 'say', 'love']
# ################
# prediction: 1 true label: 1
# ['love', 'easy', 'use', 'two', 'plus', 'spot', 'one', 'favorite', 'feature', 'ability', 'listen', 'music', 'iheart', 'radio', 'pandora']
# ################
# prediction: 1 true label: 1
# ['great', 'play', 'music', 'throughout', 'house', 'great', 'easily', 'fit', 'decor', 'home']
# ################
# prediction: 1 true label: 1
# ['obsess', 'tell', 'weather', 'every', 'morning', 'play', 'game', 'love', 'guess', 'song', 'one', 'one', 'upstairs', 'turn', 'downstairs', 'cool', 'walk', 'stair']
# ################
# prediction: 0 true label: 1
# ['easy', 'setup', 'easy', 'use', 'work', 'smart', 'product', 'always', 'learn']
# ################
# prediction: 1 true label: 1
# ['much', 'fun', 'easy', 'use', 'even', 'four', 'year', 'old', 'love', 'talk']
# ################
# prediction: 1 true label: 1
# ['love', 'new', 'right', 'mainly', 'use', 'play', 'music', 'night', 'get', 'job']
# ################
# prediction: 1 true label: 1
# ['love', 'thing', 'wish', 'would', 'get', 'sooner', 'certainly', 'want', 'setting', 'lock', 'kid', 'great', 'additional', 'even', 'unexpected', 'thing', 'like', 'help', 'kid', 'homework', 'load', 'skill', 'happy', 'purchase', 'especially', 'since', 'get', 'day', 'almost', 'half', 'price']
# ################
# prediction: 1 true label: 1
# ['super', 'easy', 'hook', 'program', 'use', 'music', 'feature', 'love', 'set', 'reminder', 'phone', 'remind', 'set', 'time', 'great', 'news', 'update']
# ################
# prediction: 1 true label: 1
# ['work', 'like']
# ################
# prediction: 1 true label: 1
# ['set', 'simple', 'recognize', 'voice', 'well', 'seam', 'intuitive', 'enjoy', 'ease', 'use']
# ################
# prediction: 0 true label: 0
# ['negative', 'product', 'terrible', 'sound', 'quality', 'massive', 'difference', 'big', 'reason', 'want', 'purchase', 'differ', 'buy', 'another', 'speaker', 'sound', 'quality', 'improve']
# ################
# prediction: 1 true label: 1
# ['like', 'ability', 'multiple', 'different', 'thing', 'like', 'create', 'list', 'set', 'alarm', 'play', 'song', 'think', 'much', 'wish', 'sound', 'could', 'tad', 'louder']
# ################
# prediction: 1 true label: 1
# ['soon', 'still', 'learn']
# ################
# prediction: 1 true label: 1
# ['enjoy', 'still', 'learn', 'command', 'run', 'one', 'frustrate', 'issue', 'not_user', 'friendly', 'try', 'set', 'voice', 'recognition', 'household']
# ################
# prediction: 1 true label: 1
# ['love', 'option', 'play', 'music', 'everywhere', 'house', 'multiple', 'device']
# ################
# prediction: 0 true label: 1
# ['like', 'almost', 'everything']
# ################
# prediction: 1 true label: 1
# ['amaze', 'help', 'become', 'well', 'organized', 'give', 'traffic', 'update', 'weather', 'update', 'help', 'maintain', 'good', 'fast', 'morning', 'routine']
# ################
# prediction: 1 true label: 1
# ['kid', 'love', 'skill', 'amaze', 'would', 'like', 'see', 'get', 'little', 'smarter', 'answer', 'basic', 'question']
# ################
# prediction: 1 true label: 1
# ['great', 'definitely', 'get', 'little', 'old', 'not_really', 'regret', 'love', 'hook', 'speaker', 'via', 'bluetooth', 'wake', 'smith']
# ################
# prediction: 1 true label: 1
# ['love', 'add', 'upstairs', 'bedroom']
# ################
# prediction: 1 true label: 1
# ['get', 'love', 'everything', 'around', 'house']
# ################
# prediction: 1 true label: 1
# ['work', 'great', 'easy', 'set']
# ################
# prediction: 0 true label: 1
# ['device', 'easy', 'set', 'work', 'perfectly']
# ################
# prediction: 1 true label: 1
# ['easy', 'set', 'start', 'use', 'work', 'advertised']
# ################
# prediction: 1 true label: 1
# ['love', 'little', 'ignore', 'original', 'large', 'unmake', 'pleased', 'capability']
# ################
# prediction: 1 true label: 1
# ['work', 'expect', 'one', 'son', 'love', 'room', 'easy', 'set', 'alarm', 'play', 'music']
# ################
# prediction: 0 true label: 1
# ['dislike', 'volume', 'devoice', 'loud', 'enough']
# ################
# prediction: 1 true label: 1
# ['love', 'give', 'one', 'gift', 'huge', 'hit']
# ################
# prediction: 1 true label: 1
# ['expect']
# ################
# prediction: 0 true label: 0
# ['deregulate']
# ################
# prediction: 1 true label: 1
# ['love', 'technology', 'old', 'easy', 'set', 'use', 'bedroom', 'use', 'everything', 'use', 'living', 'room']
# ################
# prediction: 1 true label: 1
# ['use', 'buy', 'husband', 'would', 'able', 'contact', 'someone', 'fall', 'lack', 'access', 'phone']
# ################
# prediction: 1 true label: 1
# ['amaze', 'product', 'still', 'learnimg', 'thing']
# ################
# prediction: 1 true label: 1
# ['expect']
# ################
# prediction: 1 true label: 0
# ['product', 'sound', 'emoji', 'speaker', 'five', 'sister', 'even', 'one', 'bluetooth', 'obviate', 'plug', 'good', 'thing', 'speak']
# ################
# prediction: 1 true label: 1
# ['friend']
# ################
# prediction: 0 true label: 1
# ['easy', 'thing']
# ################
# prediction: 1 true label: 1
# ['good', 'device']
# ################
# prediction: 0 true label: 1
# ['overall', 'love', 'command', 'ineffective', 'may', 'part', 'user', 'error', 'become', 'accustom', 'ask']
# ################
# prediction: 1 true label: 1
# ['additional', 'base', 'device', 'make', 'access', 'well', 'part', 'home', 'rather', 'try', 'shout', 'question', 'instruction', 'house', 'lol', 'would', 'differ', 'not_alexa', 'variety', 'function', 'performs']
# ################
# prediction: 1 true label: 1
# ['work', 'great', 'love', 'fact', 'play', 'music', 'group', 'device']
# ################
# prediction: 1 true label: 1
# ['love', 'think', 'would', 'addicted']
# ################
# prediction: 1 true label: 1
# ['work', 'beautifully', 'excellent', 'sound']
# ################
# prediction: 1 true label: 1
# ['still', 'learn', 'everything', 'good', 'room', 'volume', 'pretty', 'good', 'not_an', 'additional', 'speaker']
# ################
# prediction: 1 true label: 1
# ['neat', 'tool', 'enjoy', 'family']
# ################
# prediction: 1 true label: 1
# ['easy', 'connect', 'skill', 'create', 'gen', 'work', 'fine']
# ################
# prediction: 1 true label: 1
# ['live', 'alone', 'best', 'companion']
# ################
# prediction: 1 true label: 1
# ['easy', 'set', 'connect', 'smart', 'device', 'need']
# ################
# prediction: 1 true label: 1
# ['love', 'personally', 'prefer', 'spotify', 'music', 'great', 'able', 'set', 'default', 'not_a', 'day', 'not_music', 'home', 'also', 'reason', 'get', 'keep', 'pup', 'calm', 'leave', 'tell', 'play', 'classical', 'music', 'jazz', 'work', 'wonder', 'lot', 'calmer', 'not_bark', 'lock', 'door', 'start', 'walk', 'away', 'must']
# ################
# prediction: 1 true label: 1
# ['love', 'work', 'great', 'still', 'problem', 'get', 'well', 'every', 'day', 'not_an', 'expert', 'think', 'sound', 'quality', 'fine', 'imperfect', 'good']
# ################
# prediction: 1 true label: 1
# ['second', 'purchase', 'price', 'cheap', 'seriously', 'thinking', 'buy', 'use', 'everything', 'next', 'best', 'thing', 'internet']
# ################
# prediction: 1 true label: 1
# ['love', 'buy', 'one', 'daughter', 'one']
# ################
# prediction: 1 true label: 1
# ['not_a', 'loud', 'think']
# ################
# prediction: 1 true label: 1
# ['enjoy', 'still', 'discover', 'new']
# ################
# prediction: 1 true label: 1
# ['able', 'add', 'speaker', 'plus', 'take', 'deck', 'outside', 'love', 'big', 'bedroom']
# ################
# prediction: 1 true label: 1
# ['excellent', 'device', 'work', 'great', 'not_problem', 'concern']
# ################
# prediction: 1 true label: 1
# ['pretty', 'fun', 'nice', 'speaker', 'respond', 'question', 'not_understand', 'command', 'time']
# ################
# prediction: 1 true label: 1
# ['like', 'hand', 'free', 'operation', 'tap', 'use', 'control', 'smart', 'plug']
# ################
# prediction: 1 true label: 1
# ['love', 'actually', 'throughout', 'house', 'favorite', 'function', 'list', 'great', 'time', 'management', 'course', 'music']
# ################
# prediction: 1 true label: 1
# ['product', 'easy', 'use', 'entertaining', 'yet', 'hook', 'light', 'look', 'forward']
# ################
# prediction: 1 true label: 1
# ['work', 'great', 'speaker', 'not_the', 'good', 'music', 'need', 'get', 'bluetooth', 'speaker']
# ################
# prediction: 1 true label: 1
# ['outstanding', 'product', 'easy', 'use', 'work', 'great']
# ################
# prediction: 1 true label: 1
# ['six', 'throughout', 'home', 'great', 'time', 'music', 'talk', 'happens', 'randomly', 'may', 'sensitive', 'listen', 'option', 'change', 'name', 'engagement', 'command', 'computer', 'little', 'annoy', 'color', 'black', 'white', 'would', 'also', 'good', 'thing']
# ################
# prediction: 1 true label: 1
# ['use', 'product', 'music', 'great']
# ################
# prediction: 1 true label: 1
# ['easy', 'set', 'use']
# ################
# prediction: 1 true label: 1
# ['work', 'great']
# ################
# prediction: 1 true label: 1
# ['like', 'device', 'house', 'sale', 'price', 'day', 'tempting']
# ################
# prediction: 1 true label: 1
# ['phenomenal']
# ################
# prediction: 1 true label: 1
# ['love', 'exactly', 'say']
# ################
# prediction: 1 true label: 1
# ['use', 'control', 'smart', 'home', 'device', 'work', 'great']
# ################
# prediction: 1 true label: 1
# ['convenient']
# ################
# prediction: 0 true label: 1
# ['product', 'arrive', 'within', 'week', 'run', 'odor', 'lose', 'essence', 'smell', 'alcohol']
# ################
# prediction: 1 true label: 1
# ['easy', 'set', 'ready', 'use', 'minute']
# ################
# prediction: 0 true label: 1
# ['barry']
# ################
# prediction: 1 true label: 1
# ['three', 'year', 'old', 'love', 'good', 'basic', 'household', 'task', "'re", 'add', 'smart', 'outlet', 'bulb']
# ################
# prediction: 1 true label: 1
# ['awesome', 'device', 'wish', 'buy', 'one', 'age', 'ago']
# ################
# prediction: 1 true label: 1
# ['perfect', 'kid', 'adult', 'everyone']
# ################
# prediction: 1 true label: 1
# ['listen', 'music', 'search', 'location', 'check', 'time', 'look', 'weather', 'many', 'task', 'learn', 'simple', 'set']
# ################
# prediction: 1 true label: 1
# ['love', 'thing', 'run', 'entire', 'home', 'light', 'thermostat', 'front', 'door', 'dead', 'bolt', 'camera', 'love', 'listen', 'npr', 'thing', 'well', 'worth', 'value', 'really', 'shine', 'stat', 'add', 'smart', 'device', 'control', 'entire', 'home', 'like', 'right', 'trek', 'name', 'mine', 'computer', 'get', 'feel', 'amazing', 'device', 'smart', 'system']
# ################
# prediction: 1 true label: 1
# ['complaint', 'sound', 'quality', 'not_great', 'mostly', 'use', 'command', 'though', 'another', 'hook', 'stereo', 'system', 'play', 'music', 'couple', 'friends', 'forget', 'audio', 'quality', "'re", 'bother', 'kind', 'thing', 'full', 'size', 'make', 'sure', 'hook', 'large', 'speaker']
# ################
# prediction: 1 true label: 1
# ['nice', 'little', 'unit', 'recall']
# ################
# prediction: 1 true label: 1
# ['easy', 'set', 'use', 'help', 'provide', 'music', 'etc', 'small', 'space', 'look']
# ################

# %%
stringa = """Awful experience, not recommend. The sound quality is bad and it's difficult to set up"""
x = tokenize_list_of_text([stringa], custom_stopwords, False, 2)[1]
scoring_functionV4(x, target_pos, target_neg, w2v_model.wv, threshold=0.03)
# Out:
# total number of types extracted is: 8
# awful : -0.437518946085277
# experience : -0.0017466939248616737
# not_recommend : -0.10725275237774456
# sound : 0.08728140535524974
# quality : 0.058605065462636136
# bad : -0.3222348857971328
# difficult : -0.0026027480483543073
# set : 0.12453535259016155
# [0]

# %%
w2v_model.wv.relative_cosine_similarity("love", "disappoint")
# Out:
# -0.007805441963332647

# %%
c = 0
new_vec = np.zeros(100, )
for vec in w2v_model.wv.vectors:
    new_vec += vec
    c+=1
new_vec = new_vec/c

# %%
dim_sum = 0
for dim in new_vec ** 2:
    dim_sum+=dim

import math

print(math.sqrt(dim_sum))
# Out:
# 0.9969718925245288
